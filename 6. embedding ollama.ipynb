# %%
import ollama

f = open("data/embeddings/keys.txt", "r")
keys = f.read().split()
f.close()

# %%
import pandas as pd

# df, each row is a key
df = pd.DataFrame(columns=['key', 'embedding'])
df['key'] = keys

for i, row in df.iterrows():
    print(i, row['key'])
    e = ollama.embed(
        model='mxbai-embed-large',
        input=row['key']
    )
    df.at[i, 'embedding'] = e.embeddings
# Out:
# 0 ai>incorrect
# 1 ai|controlled
# 2 ai|seamful
# 3 co|recommendation
# 4 ai>alignment
# 5 human>#stereotype
# 6 human|comic
# 7 ai|chain
# 8 co|factor_structure
# 9 co|policy
# 10 ai|bayesian
# 11 ai|gpt_2
# 12 ai>anthropomorphic
# 13 co|misuse
# 14 human|author
# 15 ai|decision
# 16 human>#intelligence
# 17 ai>two_way
# 18 co|publication
# 19 ai|virtualassistant
# 20 ai|gpt4
# 21 co|barrier
# 22 ai>risk
# 23 human>exposure
# 24 ai>accident
# 25 ai>value
# 26 ai>steerability
# 27 co|design_ideation
# 28 ai>competency
# 29 human|parent
# 30 ai|autochemplete
# 31 ai|trustworthy
# 32 co|maxim
# 33 co|quantization
# 34 co|documentation
# 35 human|consumer
# 36 ai|enabled
# 37 ai>combination
# 38 ai>transparency
# 39 ai|language_model
# 40 ai|social_design
# 41 ai|gpt
# 42 ai|devilsadvocate
# 43 co|cognitive_social
# 44 human|driver
# 45 co|chemistry
# 46 co>interaction
# 47 ai>treatment
# 48 ai>error
# 49 co|interface
# 50 ai>credibility
# 51 co|ban
# 52 human>decision
# 53 co|infrastructure
# 54 co|option
# 55 human|technical
# 56 co|code
# 57 co|explanation
# 58 human>falsememory
# 59 co|delegation
# 60 co|resource
# 61 ai|neural_network
# 62 ai|incontext
# 63 ai|temporal
# 64 human|african_american
# 65 human|crowd_worker
# 66 human|level_designer
# 67 co|coding
# 68 co|workout
# 69 human>bias
# 70 ai|interpretability
# 71 ai|classification
# 72 human>writing
# 73 co|dialogue
# 74 co|access
# 75 co|gender
# 76 co|card
# 77 ai|writing
# 78 human|nonexpert
# 79 ai>control
# 80 human|accountant
# 81 human>#conceptualization
# 82 co|teaching
# 83 ai|tutorial
# 84 ai|llm
# 85 ai>bias
# 86 human|interlocutor
# 87 human|video_editor
# 88 co|misinformation
# 89 ai|answer
# 90 ai>response
# 91 co|prompt
# 92 ai>violation
# 93 ai>accuracy
# 94 co|planning
# 95 ai|unknown
# 96 co|hai
# 97 ai|decision_aid
# 98 co|ux
# 99 co|move
# 100 human>#expectation
# 101 ai>complacency
# 102 ai>#utility
# 103 co|ui
# 104 human>outperform
# 105 ai|gemma
# 106 human|decisionmaker
# 107 ai>multimodal
# 108 human>#value
# 109 ai>trustworthiness
# 110 human>goal
# 111 ai|dapper
# 112 ai|video
# 113 ai|research_tool
# 114 co|explainability
# 115 ai>tuning
# 116 human>competence
# 117 human|high_performing
# 118 ai|hades
# 119 co|keyboard
# 120 ai|combined
# 121 co|crowd
# 122 co|need
# 123 ai|image_processing
# 124 co|accident
# 125 ai|stress_management
# 126 ai>communication
# 127 ai|text_classification
# 128 human|health_worker
# 129 ai|avatar
# 130 human>#disruption
# 131 human|visually_impaired
# 132 human>use
# 133 ai>personality
# 134 human|travelcounsellor
# 135 co|distribution
# 136 human|audience
# 137 ai|memoanalyzer
# 138 co|ui_component
# 139 co|hiring
# 140 ai|monitoring
# 141 ai|code
# 142 ai>#explainability
# 143 ai|tutoring
# 144 ai|interaction
# 145 ai|softaibot
# 146 human>awareness
# 147 human>prompt
# 148 ai>confidence
# 149 ai>detection
# 150 ai|virtual
# 151 human|personality
# 152 co|paper
# 153 co|meeting
# 154 ai|co_performer
# 155 co|rating
# 156 ai>responsible
# 157 ai|machine_translation
# 158 co|literacy
# 159 ai|virtualagent
# 160 human|recruiter
# 161 human|elderly
# 162 co|aesthetics
# 163 ai|prototyping
# 164 co|problem
# 165 ai|anthropomorphic
# 166 ai|counterfactual
# 167 ai>simulated
# 168 co|organizational
# 169 co|brainstorming
# 170 ai|database
# 171 ai>prosocial
# 172 human|coder
# 173 ai|demonstration
# 174 human|us
# 175 co|guidelines
# 176 human>blame
# 177 co|measure
# 178 ai|super_policy
# 179 ai|interactive
# 180 co|framework
# 181 co|inclusivity
# 182 ai|promptiverse
# 183 human>social
# 184 ai>human_centered_intelligence
# 185 ai|diagnostic
# 186 ai>output
# 187 ai>integration
# 188 human>alignment
# 189 human>misconception
# 190 co|strategy
# 191 co|accountability
# 192 co|instruction
# 193 ai>dialogue
# 194 ai|active_learning
# 195 ai|service_robot
# 196 ai>closed_form
# 197 ai|auditing
# 198 human|surgeon
# 199 human>verification
# 200 ai|constraint_specification
# 201 human|artist
# 202 ai|co_orchestration
# 203 ai>similarity
# 204 ai|assistant
# 205 ai|study
# 206 co|interpretation
# 207 human|accounting
# 208 human|pathologist
# 209 human>overreliance
# 210 ai|sentence_compression
# 211 co|decision
# 212 human>#autonomy
# 213 ai|digitalassistant
# 214 ai>code
# 215 human>frustration
# 216 co|residential
# 217 ai>usefulness
# 218 ai>counterfactual
# 219 ai|natural_language
# 220 ai>attribution
# 221 co|aviation
# 222 ai>feedback
# 223 human|pilot
# 224 co|competency
# 225 co|engagement
# 226 co|roi
# 227 ai|co_learning
# 228 ai|event_gated
# 229 ai|choreography
# 230 ai>role_assignment
# 231 co|paradigm
# 232 co|dataset
# 233 ai|gpt_4v
# 234 ai>decision
# 235 ai>architecture
# 236 ai|siri
# 237 human>querying
# 238 ai|contrastive
# 239 ai|explanatory
# 240 human>agreement
# 241 co|guide
# 242 ai|compression
# 243 co|artifact
# 244 co|productivity
# 245 human>prayer
# 246 ai|alert
# 247 co|mapping
# 248 ai|virtual_influencer
# 249 human>crafting
# 250 ai>generalization
# 251 human|stakeholder
# 252 co|delay
# 253 ai>storytelling
# 254 ai>effectiveness
# 255 human>identification
# 256 co|industry
# 257 co|defamiliarization
# 258 human>confidence
# 259 ai>acoustic
# 260 ai|dermatologist
# 261 co|output
# 262 human|subject
# 263 co|mechanism
# 264 co|travelogue
# 265 ai|music_generation
# 266 co|culture
# 267 ai|time_management
# 268 human>calibration
# 269 ai|mediator
# 270 co|simulation
# 271 ai|visual_language
# 272 ai>latency
# 273 ai>chaining
# 274 ai|contextdet
# 275 co|definition
# 276 co|review
# 277 co|adoption
# 278 human|trainer
# 279 human|decision_subject
# 280 co|face
# 281 ai>participation
# 282 ai|in_context
# 283 human|researcher
# 284 co|retrosynthesis
# 285 ai|therapist
# 286 human>perspective
# 287 ai|coding
# 288 ai|advanced
# 289 co|cultural
# 290 co|optimality_gap
# 291 human>communication
# 292 co|representation
# 293 human>explanation
# 294 ai|human_sensor
# 295 co|modeling
# 296 human>rule
# 297 human>algorithmic
# 298 human>mind
# 299 co|knowledge
# 300 ai>decision_support
# 301 human|ophthalmologist
# 302 human>usage
# 303 co|accident_anticipation
# 304 ai|mobile_health
# 305 co|greyarea
# 306 ai|selective
# 307 human>deliberation
# 308 ai|localization
# 309 co|monitoring
# 310 ai|model_driven
# 311 ai|chain_of_thought
# 312 human|young
# 313 co|mof
# 314 ai>reminder
# 315 human|focusgroup
# 316 co|lead
# 317 human>theory
# 318 ai>visualization
# 319 human|annotator
# 320 ai|computer_vision
# 321 ai|personalization
# 322 co|eeg_bci
# 323 ai|moderator
# 324 ai|exercise
# 325 human|citizen
# 326 human>exploration
# 327 ai>performance
# 328 ai|email
# 329 ai>brainstorming
# 330 co|dehazing
# 331 ai>reliance
# 332 co|game
# 333 human>#belief
# 334 human>efficiency
# 335 human|actor
# 336 co|determination
# 337 ai>initiation
# 338 co|authority
# 339 co|direction
# 340 ai|diagnostic_support
# 341 ai|simulated
# 342 co|mooc
# 343 co|intelligence
# 344 ai|algorithmic
# 345 ai|ml
# 346 ai|integration
# 347 human|producer
# 348 ai|heuristic
# 349 co|interaction_paradigm
# 350 co|time
# 351 ai>#responsibility
# 352 ai|heuristics
# 353 co|belief
# 354 human>evaluation
# 355 ai|writing_assistant
# 356 co|device_model
# 357 ai|existing
# 358 ai>action
# 359 co|guidance
# 360 ai>warmth
# 361 ai|predecessor
# 362 co|visualization
# 363 ai>routineness
# 364 human|journalist
# 365 human>concern
# 366 co|trajectory
# 367 human>#awareness
# 368 ai>invocation
# 369 ai|self_driving
# 370 ai>testing
# 371 ai|fg_t2m++
# 372 co|request
# 373 ai|mixed_initiative
# 374 co|healthcare
# 375 ai>potential
# 376 co|interaction
# 377 ai|steering
# 378 co|perspective
# 379 ai|textsummarization
# 380 ai|finance
# 381 co|coaching
# 382 ai|logic
# 383 co|saliency_map
# 384 co|integration
# 385 human|student
# 386 co|script
# 387 human|coach
# 388 ai|pretrained
# 389 ai>intent
# 390 ai>fusion
# 391 co|uncertainty
# 392 co|media
# 393 ai|fashion_recommender
# 394 ai|meme
# 395 human|child
# 396 co|guideline
# 397 human>#usability
# 398 ai>emotion
# 399 ai|chatgpt
# 400 ai|fedhumor
# 401 ai>interactive
# 402 co|rehabilitation
# 403 ai|humor
# 404 co|clinical_pathway
# 405 co|solution
# 406 human|community
# 407 ai|anatomysketch
# 408 ai|trust
# 409 human|performer
# 410 human>#competence
# 411 human>judgment
# 412 human|veterinary_radiologist
# 413 ai|evaluation
# 414 human|judge
# 415 co|development
# 416 ai>decision_making
# 417 ai>explainability
# 418 ai>fairness
# 419 ai>impact
# 420 ai|digital
# 421 ai|assisted
# 422 ai|autonomous_driving
# 423 human|nurse
# 424 co|evaluation
# 425 ai>conceptualization
# 426 ai|concept_induction
# 427 human|civil_servant
# 428 co|privacy
# 429 co|idea
# 430 ai|baseline
# 431 co|hazard
# 432 human|low_performing
# 433 ai|projection
# 434 ai|implicature
# 435 co|acoustic
# 436 co|command_configuration
# 437 ai|automated
# 438 co|prototype
# 439 ai>satisfaction
# 440 ai>viability
# 441 co|support
# 442 ai|open_source
# 443 co|goal
# 444 human>following
# 445 co|vehicle
# 446 ai|cooperative
# 447 ai>#credibility
# 448 co>design
# 449 co|conflict
# 450 ai|text_generation
# 451 ai|gpt_builder
# 452 ai|workbook
# 453 co|attack
# 454 co|coordination
# 455 co|process
# 456 co|response
# 457 ai>clarity
# 458 co|diversity
# 459 co|structure
# 460 ai>reinforce
# 461 ai|global_south
# 462 ai|medpalm2
# 463 co|supply_chain
# 464 ai>cardset
# 465 co|analysis
# 466 co|dilemma
# 467 human>foresight
# 468 ai|personalized
# 469 ai|sketch_recognition
# 470 ai>interpretability+feedback
# 471 ai|bot
# 472 human>control
# 473 ai|diagnosis
# 474 ai|assistance
# 475 ai>certainty+interpretability
# 476 human|poet
# 477 co|college_admission
# 478 human|professional
# 479 co|criteria
# 480 co|meta_analysis
# 481 ai|loan
# 482 ai|gif
# 483 co|humor
# 484 human>#cooperativity
# 485 human|candidate
# 486 human|icu
# 487 ai|mobile
# 488 ai|wham
# 489 co|trust
# 490 ai|rationale
# 491 ai>translation
# 492 ai|subtitling
# 493 co|tutorial
# 494 ai|guided
# 495 human|endoscopist
# 496 co|ontology
# 497 human|user
# 498 co|brain
# 499 co|assessment
# 500 ai|probing
# 501 human>css
# 502 co|medicine
# 503 ai|suggestion
# 504 human>mismatch
# 505 human>reflection
# 506 co|trend
# 507 ai>prime
# 508 co|asthma_care
# 509 human|mushroom_picker
# 510 human|art_historian
# 511 ai|explainable
# 512 co|surgical
# 513 human>draft
# 514 ai|tutor
# 515 co|production
# 516 ai>ease_of_use
# 517 ai|visual_search
# 518 ai|stepwise
# 519 human>heed
# 520 ai|interface
# 521 human|administrator
# 522 co|video
# 523 co|diagnostic
# 524 ai|search
# 525 ai|forecasting
# 526 co|protocol
# 527 human>#evaluation
# 528 ai>constraints
# 529 ai|voice
# 530 co|image
# 531 co|stakeholder
# 532 co|embodiment
# 533 co|community
# 534 co|clinical_decision_management
# 535 ai|eco_cascade
# 536 human>ownership
# 537 ai>analysis
# 538 human|worker
# 539 human|group
# 540 ai>collaboration
# 541 ai|pathology
# 542 co|transition
# 543 ai>documentation
# 544 ai|memory_one
# 545 co|computation
# 546 co|specification
# 547 ai|editing
# 548 co|bias
# 549 human>#ownership
# 550 co|correlation
# 551 human>viewing
# 552 human|respondent
# 553 human|mentor
# 554 ai|ar
# 555 ai|system
# 556 ai>representation
# 557 human|deaf
# 558 ai|learning
# 559 co|tracking
# 560 co|network
# 561 co|objectification
# 562 co|writing_process
# 563 ai>image
# 564 ai>approach
# 565 ai>encrypted
# 566 ai>initiative
# 567 co|creative
# 568 ai|adaptive
# 569 ai|attention
# 570 human|creator
# 571 ai|metric
# 572 ai|adoption
# 573 co|temporal
# 574 human>gaze
# 575 human>#praise
# 576 human>belief
# 577 ai|co_creation
# 578 ai|auto_suggest
# 579 co|boundingbox
# 580 ai|chess
# 581 ai|reconstruction
# 582 ai>defective
# 583 ai>modeling
# 584 co|personality
# 585 ai>simplification
# 586 ai|high_risk
# 587 ai>navigation
# 588 ai|medical
# 589 human|information_worker
# 590 ai|gpt_4
# 591 human>#respect
# 592 ai|segmentation
# 593 co|reasoning
# 594 human>#privacyconcern
# 595 ai|artifact
# 596 co|procedure
# 597 ai|gamchanger
# 598 ai|newsdiscovery
# 599 co|company
# 600 ai|reconciliation
# 601 ai>#empathy
# 602 human>steering
# 603 human>#agreement
# 604 human>engagement
# 605 human>algorithm
# 606 human>#benevolence
# 607 ai>stability
# 608 ai|sensor
# 609 human>expectation
# 610 human|ml_practitioner
# 611 ai|legal
# 612 co|visual
# 613 co|bug
# 614 human>indebtedness
# 615 co|ethics
# 616 co|example
# 617 human>instruction
# 618 ai>#harsh_judgment
# 619 ai|video_editing
# 620 human>#authorship
# 621 ai|storytelling
# 622 ai|reminder
# 623 human|decision_maker
# 624 ai>intervention
# 625 co|instrument
# 626 ai|llama
# 627 human|applicant
# 628 ai>edit
# 629 human>#confidence
# 630 co|ml_label_set
# 631 co|negotiation
# 632 ai>vigilance
# 633 ai>enable
# 634 ai|retrospective
# 635 human|operator
# 636 co|stress
# 637 human>#acceptance
# 638 ai|analysis
# 639 co|flashcards
# 640 ai|creativity
# 641 co|condition
# 642 ai|partner
# 643 co|digital_transformation
# 644 ai|attention_management
# 645 co|transparency
# 646 ai|expert
# 647 ai|uav
# 648 co|experiment
# 649 ai|ecgtext
# 650 ai|training
# 651 human|pharmacist
# 652 co|social
# 653 co
# 654 ai|fine_tuning
# 655 ai|image_labeling
# 656 human|specialist
# 657 human>trust
# 658 ai|state_of_art
# 659 ai|diffusion
# 660 ai|digital_learning
# 661 ai|sentiment
# 662 human>adherence
# 663 ai|integrity
# 664 co|management
# 665 ai>delegation
# 666 human|adolescent
# 667 co|survey
# 668 ai|sepsis
# 669 co|presentation
# 670 co|training
# 671 human>expression
# 672 ai>relationship
# 673 co|question_bank
# 674 ai|auto_generated
# 675 co|moderation
# 676 human|dancer
# 677 co|wellbeing
# 678 co|context
# 679 ai>behavior
# 680 co|conversation
# 681 human>#fairness
# 682 co|politics
# 683 ai|water_management
# 684 ai|deeplearning
# 685 human|teammate
# 686 ai>classification
# 687 ai|program_synthesizer
# 688 ai|healthcare
# 689 ai|innovation
# 690 co|error
# 691 co|criterion
# 692 human>#satisfaction
# 693 ai|accident_prediction
# 694 ai|sentiment_analysis
# 695 co|ui_design
# 696 ai|symbiotic
# 697 co|quality
# 698 ai|human_centered
# 699 human>indistinguishability
# 700 co|psychology
# 701 ai|bard
# 702 co|collision
# 703 ai|active
# 704 human>oversight
# 705 human>#transparency,#understanding
# 706 human>judgement
# 707 ai|sam
# 708 ai>suggestion
# 709 ai|affective
# 710 ai|game
# 711 ai|keyword_spotting
# 712 ai>model
# 713 ai|semantic
# 714 human>edit
# 715 ai>style
# 716 ai|promptcharm
# 717 co|validation
# 718 ai>fault
# 719 ai|responsible
# 720 ai|reciprocal
# 721 co|group_decision_making
# 722 co|motion_generation
# 723 co|sentiment
# 724 ai>enablement
# 725 co|commission
# 726 human>learning
# 727 ai|gallery
# 728 co|msme
# 729 human>performance
# 730 co|usability
# 731 co|recommender
# 732 co|sme
# 733 ai|fact_checking
# 734 co|understanding
# 735 ai>synchronization
# 736 human|guest
# 737 ai|creature
# 738 co|reconstruction
# 739 ai>configurability
# 740 ai|financial
# 741 ai|gradientdescent
# 742 human|brain
# 743 human|judicial
# 744 co|forecasting
# 745 ai|flan_palm
# 746 human>assessment
# 747 co|assumption
# 748 human>willingness
# 749 human>intuition
# 750 human|knowledge
# 751 human|healthcare_team
# 752 co|cue
# 753 ai>facilitation
# 754 ai>design
# 755 ai|non_diegetic
# 756 ai>presentation
# 757 ai>limitation
# 758 co|issue
# 759 co|language
# 760 ai|tangible
# 761 ai|continuous
# 762 human>trait
# 763 human|participant
# 764 co|ai_literacy_scale
# 765 ai|few_shot
# 766 human>#robot
# 767 ai|educational
# 768 ai>diagnostic
# 769 co|agreement
# 770 human|labeler
# 771 ai|text_to_image
# 772 co|tool
# 773 co|collective_risk
# 774 co|care_pathway
# 775 ai>disclosure
# 776 human>discern
# 777 co|partner
# 778 ai|neuroadaptive
# 779 human|employee
# 780 human>research
# 781 ai>presence
# 782 co|accuracy
# 783 co|calibration
# 784 co|metric
# 785 ai|gan
# 786 co|interactive
# 787 human|amateur
# 788 co|decision_making
# 789 human>self_reflection
# 790 ai>reasoning
# 791 co>responsiveness
# 792 ai>deployment
# 793 ai>judgmental_forecast_adjustment_accuracy
# 794 ai|nearest_neighbor
# 795 ai|unsupervised
# 796 ai|autograder
# 797 ai>embodiment
# 798 co|relationship
# 799 human>input
# 800 co|course
# 801 human|contributor
# 802 ai|strategy
# 803 ai>narrative
# 804 human
# 805 human|expert
# 806 ai|manipulative
# 807 human|novice
# 808 co|event
# 809 co|visual_story
# 810 ai|design_tool
# 811 ai|saliency
# 812 co|competition
# 813 co|accessibility
# 814 ai|virtualinfluencer
# 815 co|pregnancy_care
# 816 human|sighted
# 817 ai|machine_reading
# 818 ai|decision_making
# 819 ai>explanation
# 820 co|human
# 821 ai|knowledgegraph
# 822 ai|lexical_simplification
# 823 co|failure
# 824 ai|robotic
# 825 human|intervention
# 826 co|treatment_planning
# 827 co|design
# 828 ai|explanation
# 829 co|news
# 830 human|crowdworker
# 831 co|catalog
# 832 co|partnership
# 833 ai>incorporation
# 834 co|robot
# 835 ai>question
# 836 ai>system
# 837 ai|client
# 838 human|community_health_worker
# 839 human>#concern
# 840 ai|speech
# 841 human>#sentiment
# 842 co|pattern
# 843 ai|scoring_rubric
# 844 co|algorithm
# 845 co|startup
# 846 co|cluster
# 847 human>aversion
# 848 ai>sensitivity
# 849 co|fear
# 850 human|industrial
# 851 ai|actuation
# 852 ai|interlocutor
# 853 human>experience
# 854 co|principle
# 855 ai>accountability
# 856 ai|strength_estimator
# 857 co>selective
# 858 ai>externalization
# 859 ai|robot
# 860 human>prediction
# 861 human>quantification
# 862 human|legal
# 863 human>detection
# 864 human>#moral_opposition
# 865 ai>engagement
# 866 ai|workshop
# 867 human|deaf_hard_of_hearing
# 868 ai|control
# 869 co|display
# 870 human|gender
# 871 human>privacy
# 872 ai>emphasis
# 873 human|older
# 874 ai|evolutionary
# 875 human|developer
# 876 ai|collision_prediction
# 877 ai|dashboard
# 878 co|expression
# 879 human|reader
# 880 ai|cognitive
# 881 human>riskaverse
# 882 co|oilspill_detection
# 883 co|imitation
# 884 ai|experiential
# 885 human|multidisciplinary
# 886 ai>#favored
# 887 ai|reasoning
# 888 ai>outcome
# 889 ai>optimization
# 890 ai|conversation
# 891 co|label
# 892 ai|clinical_decision_support
# 893 human>#consciousness
# 894 ai|planning
# 895 ai>empathy
# 896 human|storywriter
# 897 ai|flatcolorization
# 898 human>personalization
# 899 ai|text
# 900 ai|design
# 901 co|equilibrium
# 902 human>personality
# 903 ai|risk_detection
# 904 ai|ppm
# 905 human|physician
# 906 human|domain_expert
# 907 human|man
# 908 ai|failure_exploration
# 909 co|risk
# 910 co|domain
# 911 co|challenge
# 912 ai|mapping
# 913 ai|technology
# 914 ai|communication
# 915 co|role
# 916 ai|gpt_3
# 917 ai|optimization
# 918 co|animation
# 919 co|communication
# 920 human>#empowerment
# 921 co|aqi
# 922 ai|federated
# 923 human>#distrust
# 924 ai|transparent
# 925 ai>interface
# 926 co|image_classification
# 927 ai|randomizedcontrolledtrial
# 928 human|public_defender
# 929 ai|code_generation
# 930 co|vision
# 931 ai|emergency_management
# 932 ai>compliance
# 933 human>facial
# 934 human>request
# 935 human|designer
# 936 human|clinician
# 937 ai|wellbeing
# 938 ai|ui
# 939 ai|voice_assistant
# 940 human>overestimation
# 941 human>#transparency
# 942 ai>#trust
# 943 ai|negotiation
# 944 co|scale
# 945 human>familiarization
# 946 ai|ultrasound
# 947 co|regulation
# 948 ai|gp_tsm
# 949 ai|lipreading
# 950 human|language_learner
# 951 ai|text_simplification
# 952 ai|no_rejection
# 953 human|crowd
# 954 co|triage
# 955 ai|recruitment
# 956 human|passenger
# 957 human>craft
# 958 ai|verification
# 959 co|test
# 960 ai|sensing
# 961 ai|plugin
# 962 ai|product
# 963 co|control
# 964 ai|coaching
# 965 ai|personality
# 966 ai|codegeneration
# 967 co|evaluation_method
# 968 ai|video_adaptation
# 969 ai|gpt_4o
# 970 ai|sales_forecasting
# 971 co|participatory
# 972 ai|prompt
# 973 co|individual
# 974 ai>capability
# 975 co|content
# 976 ai|toolkit
# 977 ai|defect_quantification
# 978 co|utility
# 979 human|autistic
# 980 human>attribution
# 981 ai|analogical
# 982 human|layperson
# 983 human|instructional_designer
# 984 co|blockedit
# 985 ai>label
# 986 ai>recognition
# 987 ai|classifier
# 988 ai|update
# 989 ai>experience
# 990 ai|matterchat
# 991 ai>preselection
# 992 ai|bird_identification
# 993 human|sysadmin
# 994 co|anthropomorphism
# 995 human>motivation
# 996 co|ideation
# 997 co|intervention
# 998 co|disclosure
# 999 co|object
# 1000 ai|ethical
# 1001 ai>expression
# 1002 co|organization
# 1003 ai>adjust
# 1004 co|concept
# 1005 co|liability
# 1006 co|workshop
# 1007 ai>low
# 1008 ai|research
# 1009 human>#preference
# 1010 co|message
# 1011 co|vhpu
# 1012 human>ambiguity
# 1013 ai>understanding
# 1014 co|design_process
# 1015 human|teenager
# 1016 ai>read
# 1017 ai|pearl
# 1018 human>demographic
# 1019 human|power_user
# 1020 ai|expressiveness
# 1021 human|partner
# 1022 human|musician
# 1023 ai>overlap
# 1024 co|smartphone
# 1025 ai|fashion
# 1026 human>#efficiency
# 1027 co|limitation
# 1028 ai|grad_cam
# 1029 ai>prompt
# 1030 ai>uncertainty
# 1031 ai|tool
# 1032 ai|smart_speaker
# 1033 co|production_planning
# 1034 ai>invariant
# 1035 co|judgment
# 1036 co|tradeoff
# 1037 ai|chatbot
# 1038 co|creation
# 1039 human>reapplication
# 1040 co|method
# 1041 human|follower/nonfollower
# 1042 co|software_engineering
# 1043 human|deaf_hardofhearing
# 1044 co|legal
# 1045 ai>inducing
# 1046 co|balance
# 1047 ai|image
# 1048 ai>data
# 1049 ai|prediction
# 1050 human|information
# 1051 co|answer
# 1052 co|rule
# 1053 human|customer
# 1054 ai|decision_support
# 1055 co|stylometry
# 1056 co|model
# 1057 co|program
# 1058 ai|teaching
# 1059 co|explanation_design
# 1060 human|radiologist
# 1061 ai|conversational
# 1062 human>adoption
# 1063 human>#frustration
# 1064 ai|output
# 1065 human>cognitive
# 1066 ai>low_transparency
# 1067 human|evaluation
# 1068 human|public
# 1069 co|setting
# 1070 ai|charisma
# 1071 co|comparison
# 1072 human>speed
# 1073 co|smart_speaker
# 1074 human>understanding
# 1075 human|writer
# 1076 co|ideology
# 1077 ai|supportive
# 1078 ai>acceptance
# 1079 ai|dialogue
# 1080 human|family
# 1081 ai|synthesizer
# 1082 co|teaming
# 1083 ai>processing
# 1084 co|assignment
# 1085 co|praxis
# 1086 ai|agent
# 1087 human>response
# 1088 ai|expressedit
# 1089 ai|onboarding
# 1090 ai|takeover
# 1091 ai|wizard_of_oz
# 1092 ai|musical
# 1093 ai|cnn
# 1094 ai|alphago
# 1095 ai>generation
# 1096 ai>assistive
# 1097 co|prediction
# 1098 ai|cockpitassistant
# 1099 ai>usage
# 1100 co>deviation
# 1101 co|transportation
# 1102 human|learner
# 1103 ai|dehazing
# 1104 ai|attribution
# 1105 co|stereotype
# 1106 co|cockpit
# 1107 ai>advice
# 1108 co|priming
# 1109 ai|feedback
# 1110 ai>arrangement
# 1111 co|factor
# 1112 co|benefit
# 1113 ai>policy
# 1114 ai|deep_learning
# 1115 human|graduate
# 1116 ai|keyword
# 1117 ai>coding
# 1118 ai>support
# 1119 ai>inference
# 1120 co|narrative_map
# 1121 human|engineer
# 1122 human|holistic
# 1123 co|dashboard
# 1124 human>productivity
# 1125 ai|narrative
# 1126 ai|collaborative
# 1127 co|biomarker
# 1128 ai|proposal
# 1129 human|bank
# 1130 co|functionality
# 1131 human|agent
# 1132 ai|riskdetection
# 1133 ai|gaze_estimation
# 1134 ai|model
# 1135 co|mask
# 1136 ai>language
# 1137 ai|framework
# 1138 co|governance
# 1139 human|visuallyimpaired
# 1140 human|navigator
# 1141 ai|teachable
# 1142 ai|risk
# 1143 ai>dapper
# 1144 human|caregiver
# 1145 human|optometrist
# 1146 ai|phasewise
# 1147 ai|emotion_sensing
# 1148 co|hindustani
# 1149 human|safety_driver
# 1150 human|leveldesigner
# 1151 co|constraint
# 1152 co|consistency
# 1153 co|visual_idea
# 1154 co|annotation
# 1155 ai|deep
# 1156 co|exploitation
# 1157 ai|experience_based
# 1158 ai|rewriting
# 1159 co|outcome
# 1160 human|comicprofessional
# 1161 ai|question_generation
# 1162 ai|drl
# 1163 ai|devil's_advocate
# 1164 co|data_analysis
# 1165 co|awareness
# 1166 human>ethical
# 1167 human|social_worker
# 1168 human|male
# 1169 ai|symptom_checker
# 1170 co|benchmark
# 1171 ai>task
# 1172 ai>use
# 1173 ai|annotation
# 1174 co|authorship
# 1175 ai|hybrid
# 1176 human|leader
# 1177 human>sensemaking
# 1178 human|datascientist
# 1179 human>cooperation
# 1180 ai|gameplay
# 1181 human|preschooler
# 1182 human|smart_speaker_user
# 1183 ai|workflow
# 1184 ai|health
# 1185 ai>retrieval
# 1186 human>#enjoyment
# 1187 human|entrepreneur
# 1188 ai|visual
# 1189 human|novice_programmer
# 1190 ai|metacognitive
# 1191 ai|toy_playing
# 1192 co|reporting
# 1193 co|censorship
# 1194 ai|facial
# 1195 human>depiction
# 1196 human|responder
# 1197 human>time
# 1198 co|drawing
# 1199 ai|startup
# 1200 co|result
# 1201 co|theory
# 1202 human|creativewriter
# 1203 co|video_editing
# 1204 co|data
# 1205 ai|extension
# 1206 co|diagnosis
# 1207 co|influence
# 1208 co|signal
# 1209 human|travel_counsellor
# 1210 ai|deferral
# 1211 ai>prompting
# 1212 human|patient
# 1213 ai|machine_learning
# 1214 co|cdis
# 1215 co|feature
# 1216 ai|variance_based
# 1217 co|institution
# 1218 ai>statistical
# 1219 ai>saliency
# 1220 ai|med_palm2
# 1221 co|misrepresentation
# 1222 ai|chatspot
# 1223 co|personal_statement
# 1224 co|computing
# 1225 co|processing
# 1226 co|search
# 1227 co|mental_model
# 1228 ai|assessment
# 1229 ai|delegation
# 1230 co|adaptation
# 1231 human|editor
# 1232 co|practice
# 1233 ai|music
# 1234 co|configuration
# 1235 ai>evaluation
# 1236 human|enterprise
# 1237 ai|algorithm
# 1238 human>#trust+satisfaction
# 1239 human|demographic
# 1240 human>#trust
# 1241 human>#humanness
# 1242 human|middleaged
# 1243 human>#reliance
# 1244 ai|generator
# 1245 co|creativity
# 1246 human|traveler
# 1247 ai>automation
# 1248 human|defender
# 1249 ai|generated
# 1250 ai|method
# 1251 ai>appearance
# 1252 ai|disentanglement
# 1253 ai|cloning
# 1254 ai>autonomy
# 1255 co|inference
# 1256 co|experience
# 1257 co|consulting
# 1258 co|education
# 1259 ai>confirmatory
# 1260 ai|virtualization
# 1261 co|taxonomy
# 1262 ai>talkative
# 1263 co|query
# 1264 co|reference
# 1265 human>metaphor
# 1266 ai|labeling
# 1267 co|attribution
# 1268 ai>signal
# 1269 human|evaluator
# 1270 co|explainability_design
# 1271 co|algorithmic_decision_review
# 1272 ai|se_mcts
# 1273 ai|platform
# 1274 ai>tracking
# 1275 co|fairness
# 1276 co|modelcard
# 1277 human>perceived_learning
# 1278 ai|fine_tuned
# 1279 ai|selfconsistency
# 1280 ai|detection
# 1281 human|individual
# 1282 ai|colonoscopy
# 1283 ai>learning
# 1284 co|child_welfare
# 1285 ai>diagnosis
# 1286 ai|generative
# 1287 ai|embodied
# 1288 ai|implicit
# 1289 human>emotional
# 1290 ai|automation
# 1291 ai>indicator
# 1292 human>#risk
# 1293 ai>removal
# 1294 ai|procedure_tracking
# 1295 human>autonomy
# 1296 co|team
# 1297 co|attitude
# 1298 co|elements
# 1299 ai|lstm
# 1300 co|identity
# 1301 ai|exploration
# 1302 co|consensus
# 1303 co|quiz
# 1304 co|game_development
# 1305 co|patient_care
# 1306 co|collaboration
# 1307 ai>cad
# 1308 ai>prediction
# 1309 human|client
# 1310 co|transformation
# 1311 ai>cooperation
# 1312 co|application
# 1313 ai|recommender
# 1314 co|toolkit
# 1315 co|boundary_object
# 1316 human>social_expectation
# 1317 co|robotic
# 1318 human|undergraduate
# 1319 human|teacher
# 1320 human|ux
# 1321 co|variation
# 1322 ai|screening
# 1323 human|team
# 1324 co|graph_neural_network
# 1325 ai>information_transfer
# 1326 ai|clinical
# 1327 ai|developer
# 1328 ai|language
# 1329 human|dater
# 1330 ai>usability
# 1331 co>complexity
# 1332 co|mission
# 1333 ai|navigation
# 1334 co|impression
# 1335 co|study
# 1336 ai>interaction
# 1337 ai>interpretation
# 1338 ai|end_user
# 1339 ai|forensic
# 1340 human|non_radiologist
# 1341 ai|sketch
# 1342 co|radiology
# 1343 co|legislation
# 1344 ai|assist
# 1345 co|mindmap
# 1346 ai>societal
# 1347 ai|neural
# 1348 co|sociocultural
# 1349 ai|configuration
# 1350 co|learning
# 1351 ai|symptomchecker
# 1352 co|design_space
# 1353 human>effort
# 1354 human>reliance
# 1355 ai>biased
# 1356 ai>information
# 1357 human|sounddesigner
# 1358 ai>annotation
# 1359 co|heuristic
# 1360 human|auditor
# 1361 ai|ensemble
# 1362 human>internalization
# 1363 ai|persona
# 1364 co|code_sample
# 1365 co|spatial
# 1366 co|technique
# 1367 ai|intervention
# 1368 ai|predictive
# 1369 ai|code_review
# 1370 ai>shap
# 1371 co|emotion
# 1372 ai|bigdata
# 1373 co|workflow
# 1374 ai>conversion
# 1375 ai|personal_assistant
# 1376 ai|male_labelled
# 1377 human|identity
# 1378 ai>verification
# 1379 human>tailoring
# 1380 ai|animation
# 1381 human|educator
# 1382 human|jobapplicant
# 1383 ai>fine_tuning
# 1384 human>compulsion
# 1385 co|reliability
# 1386 co|activity
# 1387 ai|supervisor
# 1388 human|player
# 1389 ai|visualization
# 1390 co|task_switch
# 1391 ai|advice
# 1392 co|global_south
# 1393 co|approach
# 1394 co|literature
# 1395 co|detection
# 1396 co|usage
# 1397 ai>theme
# 1398 co|performance
# 1399 human>loss
# 1400 human>outcome
# 1401 ai|recommendation
# 1402 ai>customization
# 1403 human>#perception
# 1404 co|score
# 1405 ai>trust
# 1406 human>decision_making
# 1407 ai>assistance
# 1408 ai>method
# 1409 ai|autonomous
# 1410 ai|co_creative
# 1411 human>vulnerability
# 1412 human>comprehension
# 1413 ai|recruitment_chatbot
# 1414 human|social
# 1415 human>#understanding
# 1416 human>association
# 1417 ai|human_in_the_loop
# 1418 ai|display
# 1419 co|political
# 1420 ai|vision_transformer
# 1421 ai|emotional_management
# 1422 ai>instruction
# 1423 human|assistant
# 1424 co|innovation
# 1425 co|effect
# 1426 human|consultant_client
# 1427 human|japanese
# 1428 co|parameter
# 1429 human|non_expert
# 1430 co|question
# 1431 co|optimization
# 1432 ai|app
# 1433 ai|deepfake
# 1434 ai|prescriptive
# 1435 ai|reinforcement
# 1436 co|defect
# 1437 co|research
# 1438 ai|modelcard
# 1439 human>preference
# 1440 human>choice
# 1441 human>self_reported
# 1442 co|distinction
# 1443 co|alignment
# 1444 co|writing
# 1445 human>knowledge
# 1446 co|imaging
# 1447 co|examination
# 1448 human>heuristic_bias
# 1449 ai>influence
# 1450 ai|explainability
# 1451 human|instructor
# 1452 co|psychological
# 1453 human>self_care
# 1454 human>behavior
# 1455 co|group_decision
# 1456 co|conversational_agent
# 1457 ai|streaming
# 1458 ai|vision_language
# 1459 ai>ethics
# 1460 ai>metacognition
# 1461 co|trial
# 1462 ai>response_generation
# 1463 ai
# 1464 co|text
# 1465 ai|rephrasing
# 1466 human>attitude
# 1467 human|analyst
# 1468 ai|machinelearning
# 1469 co|phenomenon
# 1470 human>rejection
# 1471 human>reasoning
# 1472 co|sandbox
# 1473 ai|limeade
# 1474 ai|replicative
# 1475 ai>perceived
# 1476 co|feedback
# 1477 co|motion
# 1478 co|information
# 1479 co|discussion
# 1480 ai>blame
# 1481 ai|artinter
# 1482 ai>reliability
# 1483 human>cognition
# 1484 ai|teammate
# 1485 ai|audience_selection
# 1486 ai>hallucination
# 1487 ai>stewardship
# 1488 human>mentalmodel
# 1489 human|end_user
# 1490 human>interpretation
# 1491 co|therapy
# 1492 human>focus
# 1493 co|task
# 1494 ai|transparency
# 1495 human>#engagement
# 1496 co|rubric
# 1497 co>oversurveillance
# 1498 ai|multimodal
# 1499 ai>spillover
# 1500 ai|assembly
# 1501 co|firm
# 1502 ai>reconstruction
# 1503 human>override
# 1504 ai|virtual_agent
# 1505 co|gameplay
# 1506 ai|application
# 1507 ai|multi_wizard
# 1508 ai>social
# 1509 ai|programming
# 1510 co|cost
# 1511 co|measurement
# 1512 co|guidebook
# 1513 human>accuracy
# 1514 ai|ghostwriting
# 1515 human>perception
# 1516 human|buyer
# 1517 ai>involvement
# 1518 human|therapist
# 1519 ai>detail
# 1520 human>satisfaction
# 1521 ai|personalassistant
# 1522 human|non_power
# 1523 ai>role
# 1524 co|scenario
# 1525 human>intention
# 1526 human|practitioner
# 1527 ai|armath
# 1528 human|provider
# 1529 ai|riskassessment
# 1530 human>interaction
# 1531 co|tension
# 1532 ai|simulation
# 1533 ai|prototype
# 1534 co|impact
# 1535 co|revision
# 1536 human>underreliance
# 1537 ai>convergence
# 1538 ai|metaphorical
# 1539 co|road_safety
# 1540 co|identification
# 1541 co|trust_scale
# 1542 ai|support
# 1543 ai>recommendation

# %%
df.to_csv("data/embeddings/all.csv", index=False)
