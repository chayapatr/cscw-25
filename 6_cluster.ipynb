# %%
import pandas as pd
import ast

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from kneed import KneeLocator
from sklearn.metrics.pairwise import cosine_similarity

def get_cluster_representatives(embeddings, words, cluster_labels, cluster_id, n=10):
    cluster_indices = np.where(cluster_labels == cluster_id)[0]
    cluster_embeddings = embeddings[cluster_indices]
    
    centroid = np.mean(cluster_embeddings, axis=0)
    similarities = cosine_similarity(cluster_embeddings, centroid.reshape(1, -1)).flatten()
    
    top_indices = np.argsort(similarities)[-n:][::-1]
    return [words[cluster_indices[i]] for i in top_indices]

def cluster_and_visualize(keyword_embeddings):
    embeddings_array = np.array(list(keyword_embeddings.values()))
    words = list(keyword_embeddings.keys())
    
    inertias = []
    k_range = range(1, min(20, len(embeddings_array)))
    
    for k in k_range:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(embeddings_array)
        inertias.append(kmeans.inertia_)
    
    kneedle = KneeLocator(k_range, inertias, curve='convex', direction='decreasing', S=1.0)
    optimal_k = kneedle.elbow
    
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    clusters = kmeans.fit_predict(embeddings_array)
    
    tsne = TSNE(n_components=2, random_state=42)
    embeddings_2d = tsne.fit_transform(embeddings_array)
    
    plt.figure(figsize=(16, 12))
    scatter = plt.scatter(embeddings_2d[:, 0], embeddings_2d[:, 1], c=clusters, cmap='tab10', alpha=0.6)
    
    plt.legend(*scatter.legend_elements(),
                        title="Clusters",
                        loc="center left",
                        bbox_to_anchor=(1, 0.5))
    
    # Add 3 random labels for each cluster
    for cluster_id in range(optimal_k):
        cluster_mask = clusters == cluster_id
        cluster_points = embeddings_2d[cluster_mask]
        cluster_words = np.array(words)[cluster_mask]
        
        if len(cluster_points) > 0:
            n_samples = min(3, len(cluster_points))
            random_indices = np.random.choice(len(cluster_points), n_samples, replace=False)
            
            for idx in random_indices:
                plt.annotate(cluster_words[idx][:50] + '...' if len(cluster_words[idx]) > 50 else cluster_words[idx], 
                           (cluster_points[idx, 0], cluster_points[idx, 1]),
                           fontsize=8)
    
    plt.title(f'Keyword Clusters (k={optimal_k})')
    plt.show()
    
    # Print representatives for each cluster
    print("\nTop 10 representatives for each cluster:")
    for cluster_id in range(optimal_k):
        representatives = get_cluster_representatives(embeddings_array, words, clusters, cluster_id)
        print(f"\nCluster {cluster_id}:")
        print("- "+"\n- ".join(representatives))
    
    return clusters, optimal_k

# %%
# statements
x = pd.read_csv('result/embedding-stmt.csv')
x['0'] = x['0'].apply(lambda x: ast.literal_eval(x))

embedding = {}
for i in range(len(x)):
    r = x.iloc[i]
    embedding[r[0]] = r[1]
# Out:
# /var/folders/bw/64y3yr9n6v50fgm86wtx236c0000gn/T/ipykernel_61475/1187244378.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   embedding[r[0]] = r[1]

# %%
clusters, k = cluster_and_visualize(embedding)
# Out:
# Top 10 representatives for each cluster:
#
# Cluster 0:
# - AI methods assist users in aligning algorithmic outputs with their specific goals and needs.
# - AI-driven interactive dialogues improve both subjective and objective understanding of anxiety assessment mechanisms.
# - AI explanations improve coding F-score by 10% for novice sensemakers.
# - AI-based platforms improve decision-making by enhancing human-AI interaction in course credit equivalency decisions.
# - AI documentation systems enhance user satisfaction with computational notebooks.
# - AI-powered decision support systems that enhance intrinsic motivation improve decision-making performance compared to existing paradigms.
# - AI collaboration tools enhance dialogues and task delegation between humans and AI.
# - AI explanations enhance the effectiveness of conditional delegation in content moderation tasks.
# - The HAICS framework enhances AI performance by improving classification accuracy through interactive sensemaking with human feedback.
# - AI-assisted data analysis tools facilitated easier intervention, correction, and verification for users.
#
# Cluster 1:
# - Human-like AI explanations enhance trust in high-accuracy models.
# - Normative AI explanations enhance user understanding and perceived system capability.
# - AI system explanations for non-experts in healthcare enhance user trust perceptions.
# - Interactive AI explanations enhance the perceived usefulness of AI assistance.
# - AI explanation techniques enhance user understanding of model behavior and trust calibration.
# - AI algorithm traceability affects user trust and satisfaction with explanations.
# - Interactive AI explanations improve perceived usefulness and performance of human+AI teams.
# - Insufficiently designed AI explanations can decrease system acceptance among users.
# - Example-based AI explanations improve decision-makers' performance and help achieve complementary human-AI performance.
# - Explainable AI in interface design enhances perceived usefulness, trust, satisfaction, and intention to use in art therapy assessments.
#
# Cluster 2:
# - AI embodiment in a robot interface closely resembles human-human collaboration, influencing participant perceptions.
# - AI partners following human initiative are perceived as warmer and more collaborative.
# - AI as a teammate in interactive paradigms maximizes job meaningfulness.
# - AI-enhanced user interactions increase engagement by integrating task context and user perceptions.
# - AI-to-human communication enhances user engagement and collaborative experience in co-creative systems.
# - AI agents perceived as human increase rapport and likeability in cooperative games.
# - AI as play expands current notions of human-AI interaction beyond productivity-based models.
# - AI explanations influence how human decision makers understand and utilize AI decision aids.
# - AI interaction modalities affect the perceived role of AI in co-creative processes.
# - Users perceive co-creative AI as more reliable, personal, and intelligent when the AI communicates with them.
#
# Cluster 3:
# - Users' perception of AI performance relative to their own impacts the effectiveness of AI recommendations in decision-making.
# - Workers' beliefs about AI capabilities influence their reliance on AI-assisted decision-making.
# - Participants' beliefs about AI versus human performance influence their likelihood of following AI advice.
# - Users selectively trusted the AI system, avoiding its adoption in high-stakes scenarios.
# - User overreliance on AI is a key predictor of behavior, affecting the choice and use of different AI assistance types.
# - Human-AI trust factors vary depending on the stakeholder involved.
# - AI systems' unpredictable errors negatively impact user experience and may lead to undesired societal consequences.
# - Participants perceive AI systems as more capable but less morally trustworthy than humans.
# - Users tend to under-rely on AI systems due to overestimating their own problem-solving abilities, despite understanding system accuracy.
# - Human decision makers in AI-assisted decision making are influenced by their own judgement and confidence.
#
# Cluster 4:
# - Community perceptions influence user preferences in AI bot teaching methods, emphasizing transparency and feedback orientation.
# - Users show increased reliance on conversational AI over the course of tasks, indicating automation complacency.
# - Chatbots with high perceived moral agency increase trust, likeability, and perceived safety in mental health applications.
# - Voice assistants introduced as learners or collaborators increase user willingness to provide feedback.
# - Despite low ratings in predictability and controllability, users enjoy interacting with the AI during creative tasks.
# - Human-centered recruitment chatbots improve acceptability among users.
# - SoftAIBot, an optimized LLM, outperformed the baseline LLM in software guidance tasks, yet users showed low task completion rates due to challenges in understanding prompt-based interactions.
# - Participants prefer selecting from multiple AI-generated suggestions over using non-diegetic prompts.
# - Learning Engagement mechanisms improve users' positive perceptions of the robot.
# - User-initiated feedback instructions reduce perceived disruptiveness in voice assistant interactions.
#
# Cluster 5:
# - Patchview enables users to steer AI-generated elements by interacting with visual metaphors.
# - Designers develop innovative uses of DesignPrompt for creating elaborate multimodal prompts.
# - Direct interaction with ML models allows UX practitioners to enhance end-user interactions by composing affordances.
# - Machine learning methods automate mundane UX research tasks, enhancing efficiency.
# - VIVID enables efficient selection and revision of pedagogical dialogues by instructors.
# - Using Marco, users complete sensemaking tasks 16% more quickly without compromising accuracy.
# - Interactive experimentation with ML enables UX practitioners to align ML capabilities with user goals.
# - Adaptive interventions enhance comprehension of Magazine-Style Narrative Visualizations for users with lower visualization literacy by guiding attention to salient components.
# - ChatGPT enhances perceptions of productivity and accomplishment by enabling greater creative output and tool satisfaction.
# - AutoChemplete supports multiple annotation styles, enhancing user engagement and providing skill-appropriate assistance.
#
# Cluster 6:
# - DeepLens increases user confidence in detecting out-of-distribution issues by 22% through interactive features.
# - Transparent AI models enable users to improve performance by interacting with incorrect predictions.
# - LIMEADE improves accuracy in image classification by integrating human advice into opaque models.
# - CNN engineers using DeepFuse improved model accuracy and reasonability compared to the current state-of-the-art.
# - People rely more on machine learning models when making decisions on out-of-distribution data than on in-distribution data.
# - DeepLens enables users to identify nearly twice as many out-of-distribution issues in text corpora accurately.
# - Agreement among non-expert crowd workers further improves precision by 8% and recall by almost 5% beyond pure ML performance.
# - Interactive machine learning enhances rehabilitation assessment by improving prediction accuracy for upper-limb exercises from 0.8279 to 0.9116 average F1-scores.
# - Increasing awareness of possible performance disparities in machine learning models decreases over-reliance under covariate shift.
# - SenseMate's AI-generated recommendations increase intercoder reliability by 29%.
#
# Cluster 7:
# - Generative AI systems serve as both augmenting tools and autonomous collaborators in creative co-production.
# - Generative AI models enhance emotional storytelling by creating metaphorical images and text depictions.
# - Generative AI tools provide creative writers with an alternative support source, complementing peer and mentor assistance.
# - AI music generation enhances creative practice by providing video creators with interactive tools to regenerate and mix music.
# - Generative AI tools like ChatGPT and Midjourney enhance children's creative expression by facilitating visual storytelling.
# - Generative AI in ID.8 enables inclusive storytelling by simplifying content creation and allowing customization.
# - Generative AI and human-in-the-loop interaction enhance the diversity and creativity of music synthesis.
# - AI-generated texts enrich writing by introducing unexpected elements that enhance creativity.
# - AI augments human creativity in design collaborations.
# - Generative AI supports self-care by providing personalized advice and enhancing creativity for reflection.

# %%
# keywords
x = pd.read_csv('result/embedding-keywords.csv')
x['0'] = x['0'].apply(lambda x: ast.literal_eval(x))

embedding = {}
for i in range(len(x)):
    r = x.iloc[i]
    embedding[r[0]] = r[1]
# Out:
# /var/folders/bw/64y3yr9n6v50fgm86wtx236c0000gn/T/ipykernel_61475/2713030699.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   embedding[r[0]] = r[1]

# %%
clusters, k = cluster_and_visualize(embedding)
# Out:
# Top 10 representatives for each cluster:
#
# Cluster 0:
# - creative collaboration
# - collaborative work
# - co-creativity
# - co-creative process
# - creative co-production
# - team collaboration
# - creative practices
# - collaborative actions
# - co-creation
# - creative practice
#
# Cluster 1:
# - user perceptions
# - social perceptions
# - user perception
# - interaction paradigms
# - cognitive interaction
# - social interaction
# - social sensemaking
# - social interactions
# - user attitudes
# - user mental models
#
# Cluster 2:
# - interface design
# - interactive design
# - user interface design
# - interaction design
# - user interfaces
# - design practices
# - user interaction
# - interactive interfaces
# - design framework
# - design process
#
# Cluster 3:
# - model evaluation
# - user evaluation
# - data analysis
# - model improvement
# - evaluation technique
# - model performance
# - evaluation techniques
# - performance optimization
# - model performance feedback
# - decision accuracy
#
# Cluster 4:
# - ai development
# - ai assessment
# - ai definition
# - ai innovation
# - ai expectations
# - ai models
# - ai interface
# - ai design
# - ai education
# - ai technology
#
# Cluster 5:
# - human-ai interactions
# - human-ai interaction
# - human-ai collaboration
# - human-centred ai
# - ai implementation
# - human-ai teams
# - ai-powered technologies
# - human-centered ai
# - ai-powered applications
# - ai-powered collaboration
#
# Cluster 6:
# - interactive machine learning
# - human-machine collaboration
# - intelligent assistants
# - artificial autonomous agents
# - human-machine computing
# - human-machine interaction
# - machine learning
# - human-in-the-loop systems
# - conversational interfaces
# - service robots
#
# Cluster 7:
# - education
# - online learning
# - media production
# - learning
# - e-learning
# - healthcare
# - professional practice
# - online education
# - higher education
# - clinical practice
#
# Cluster 8:
# - ethical concerns
# - ethical governance
# - ethical tensions
# - ethical considerations
# - ethical ai
# - ethical dimensions
# - ethical implications
# - ethical frameworks
# - ethical issues
# - ethical challenges
