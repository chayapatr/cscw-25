# %%
import pandas as pd
import ast
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

load_dotenv()
API_KEY = os.getenv('API_KEY')

df = pd.read_csv('27-oct-extracted.csv')
kw = df['summaries'].to_list()
kw = [ast.literal_eval(items) for items in kw]
kw = [item for sublist in kw for item in sublist]

# %%
embedding = {}

openai_key = ""
from openai import OpenAI
client = OpenAI(api_key=API_KEY)

def get_embedding(text, model="text-embedding-3-large"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
import concurrent.futures
from typing import Set, Dict, Any

def process_item(item: str) -> tuple[str, Any]:
    print(f"Processing item: {item}")
    embedding = get_embedding(item)
    return (item, embedding)

def get_concurrent_embeddings(kw_set: Set[str], max_workers: int = 5) -> Dict[str, Any]:
    embeddings = {}
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_item = {
            executor.submit(process_item, item): item 
            for item in kw_set
        }
        
        for future in concurrent.futures.as_completed(future_to_item):
            try:
                item, embedding = future.result()
                embeddings[item] = embedding
            except Exception as e:
                print(f"Error processing {future_to_item[future]}: {str(e)}")
    
    return embeddings

embedding = get_concurrent_embeddings(kw)
# Out:
# Processing item: AI interaction guidelines enhance user experience when adhered to during optimal AI performance.
# Processing item: AI systems provoke deep reflections by engaging users in evaluative processes.
# Processing item: AI systems create indirect communities by celebrating user goals and behaviors.
# Processing item: Explainable AI facilitates trust by providing human-level explanations and can be processed affectively.
# Processing item: Information presentation beyond explanations moderates trust formation during human-AI interactions.
# Processing item: AI products adhering to HAI guidelines are generally more inclusive of diverse problem-solving styles.
# Processing item: AI products offering more user control tend to be more inclusive.
# Processing item: AI products' inclusivity is influenced by whether they learn from individual or collective data.
# Processing item: The AI music application prototypes exhibit distinct user control levels in intermittent, continuous, and proactive interaction paradigms.
# Processing item: End-users prefer XAI explanations that provide practical, actionable information over technical system details.
# Processing item: XAI explanations are used by end-users for tasks such as calibrating trust, improving skills, and giving feedback.
# Processing item: Part-based XAI explanations, resembling human reasoning, are favored by end-users.
# Processing item: AI in games reveals misconceptions about AI systems by integrating interactions from other domains.
# Processing item: Social AI games facilitate discussions that evolve users' mental models of AI.
# Processing item: AI-enhanced pervasive sensing platforms create breakdowns in patient journeys by focusing on either consumers or physicians.
# Processing item: Designers of AI platforms in healthcare demonstrate system effectiveness one metric at a time, leading to unintended design consequences.
# Processing item: Chaining LLM steps improves task outcomes by enhancing system transparency and controllability.
# Processing item: Users develop new interaction methods with LLMs through Chains, such as calibrating model expectations and debugging outputs.
# Processing item: Interactive AI tools enhance prediction accuracy by incorporating user knowledge in marathon planning.
# Processing item: Coaches interacting with AI models show increased trust and acceptance in predictions.
# Processing item: AI agents perceived as human increase rapport and likeability in cooperative games.
# Processing item: AI communication direction affects perceived intelligence and game outcomes.
# Processing item: Polyadic conversational agents enhance human-human connection by facilitating communication and engagement.
# Processing item: Designing polyadic conversational agents with social boundaries, such as privacy and disclosure, is crucial for ethical interactions.
# Processing item: HAI interactions designed following AI interaction guidelines may not align with ethical guidelines for trustworthy AI and vice versa.
# Processing item: AI decision support systems with interactive forward reasoning improve management of output uncertainty.
# Processing item: AI-to-human communication enhances user engagement and collaborative experience in co-creative systems.
# Processing item: Users perceive co-creative AI as more reliable, personal, and intelligent when the AI communicates with them.
# Processing item: Students' perception of the AI teaching assistant's anthropomorphism and intelligence changed significantly over time.
# Processing item: Linguistic verbosity, readability, sentiment, diversity, and adaptability reflect student perception of the AI teaching assistant.
# Processing item: AI systems' unpredictable errors negatively impact user experience and may lead to undesired societal consequences.
# Processing item: Uncertainty surrounding AI's capabilities and output complexity presents distinctive design challenges for human-AI interaction.
# Processing item: Optimization using AI preferential choices lacks mechanisms to handle inconsistent human judgments.
# Processing item: AI machine outcomes influence future user inputs through heuristic biases and loss aversion.
# Processing item: Power users trust AI systems more when framed as help-seekers.
# Processing item: Non-power users prefer AI systems that are both help-seekers and help-providers.
# Processing item: Employees perceive six types of burdens—emotional, mental, bias, manipulation, privacy, and social—related to AI in human resource management.
# Processing item: Transparency, interpretability, and human intervention can mitigate perceived burdens of AI in human resource management.
# Processing item: Behavior Trees (BTs) generated from human video demonstrations enable robots to learn tasks without pre-programming.
# Processing item: Automated feature selection methods improve the accuracy of extracting action conditions for BT generation in robotic tasks.
# Processing item: Defamiliarization of AI supports creative interpretation of ambiguous metaphors.
# Processing item: Explicit metaphorical thinking scaffolds participants' use of ambiguity as a resource.
# Processing item: Self-voice alarms increase task completion and repetition more than beep sound alarms.
# Processing item: Self-voice alarms elicit higher alertness and uncomfortable feelings compared to beep sound alarms.
# Processing item: Both self-voice and other-voice alarms enhance users' perceived usefulness of the alarm system.
# Processing item: AI agents that adjust their autonomy based on the situation enhance team performance in shared workspaces.
# Processing item: Users perceive AI agents with situation-dependent autonomy as more intelligent.
# Processing item: AI interaction guidelines must integrate banking-specific elements like customer experience principles and agent personas.
# Processing item: Stakeholder dynamics within companies are crucial for effective AI interaction design.
# Processing item: People expect AI agents' performance to be significantly better on average than human performance.
# Processing item: AI agents' performance is perceived to have less variation across different types of problems.
# Processing item: HINT framework captures distinct user behavior patterns across various AI performance modalities using AI-based feature prototypes.
# Processing item: HINT supports practitioners in evaluating human-AI interaction experiences before deployment.
# Processing item: Students with special educational needs (SEN) use text-to-image AI to transform ideas into digital images, aiding those with fine motor skill challenges.
# Processing item: Text-to-image AI interaction enhances students' ability to convey ideas in writing and develop conceptualization skills.
# Processing item: High-accuracy AI models significantly increase trust in decision-making tasks.
# Processing item: Human-like AI explanations enhance trust in high-accuracy models.
# Processing item: AI as play expands current notions of human-AI interaction beyond productivity-based models.
# Processing item: AI-empowered co-creative tools predominantly support the generation and execution of ideas in creative processes.
# Processing item: Haze type classification followed by specialized dehazing improves image clarity by 2.41% in PSNR, 17.14% in SSIM, and 10.2% in MSE.
# Processing item: ResNet50 and AlexNet achieve 92.75% and 92.50% accuracy, respectively, in haze type classification using the HazeSpace2M dataset.
# Processing item: AI-based expert support system, AlphaDAPR, increases art therapists' willingness to use drawing assessments by 64.06%.
# Processing item: Explainable AI in interface design enhances perceived usefulness, trust, satisfaction, and intention to use in art therapy assessments.
# Processing item: Safety drivers mitigate risks from defective AI algorithms during AV testing.
# Processing item: Safety drivers face limited self-development opportunities in the AV industry.
# Processing item: AI assistants' values influence the ideation process by reflecting in the generated ideas.
# Processing item: AI assistants affect users' feelings of ownership over ideas, highlighting the need for careful design.
# Processing item: Generative AI models facilitate rapid ideation by producing diverse and novel dance sequences.
# Processing item: An AI-based choreography-support system enables iterative digital dance prototyping through an interactive web-based interface.
# Processing item: Personalized AI models in chess improve prediction accuracy of individual player moves.
# Processing item: AI systems using personalized models can perform stylometry, predicting the player based on move patterns.
# Processing item: Creative exploration of tangible AI helps designers gain new perspectives beyond anthropomorphic forms.
# Processing item: AI agents that sincerely apologize and accept blame for errors are perceived as more intelligent and likeable.
# Processing item: Sincere apologies by AI agents enhance the perceived effectiveness in error recovery.
# Processing item: Generative AI supports self-care by providing personalized advice and enhancing creativity for reflection.
# Processing item: Generative AI facilitates self-care through social simulation and therapeutic self-expression.
# Processing item: ExpressEdit enhances novice video editors' ability to express and implement editing ideas through natural language and sketching.
# Processing item: ExpressEdit enables more efficient video editing by interpreting and implementing multimodal edit commands.
# Processing item: Safety-guaranteed AI systems for robot agents provide adaptive solutions for unforeseen scenarios.
# Processing item: AI-DEC supports workers in designing explanations that meet performance and autonomy needs.
# Processing item: The interactive system RELIC helps users verify the reliability of text generated by Large Language Models by identifying semantic-level variations.
# Processing item: Users can recognize and correct potentially inaccurate information in LLM-generated text using RELIC.
# Processing item: GP-TSM enhances reading efficiency by enabling participants to answer GRE questions more efficiently.
# Processing item: Participants prefer GP-TSM over existing text rendering methods for reading comprehension tasks.
# Processing item: Proactive actuation strategies enhance visual AI sensors' inference accuracy in smart homes.
# Processing item: AI-to-Human Actuation (AHA) improves AI robustness against unfavorable conditions by inducing more favorable monitoring scenarios.
# Processing item: Open-ended AI systems enhance capability extension in blind children by providing continuous, real-time information.
# Processing item: AI systems' effectiveness in supporting social sensemaking depends on human-AI interaction rather than AI capabilities alone.
# Processing item: GP-TSM enhances reading efficiency by guiding user gaze through visual cues.
# Processing item: GP-TSM enables coherent skimming and revisiting of skipped details during reading.
# Processing item: The Seamful XAI design process enables users to foresee AI harms and identify underlying reasons.
# Processing item: Seamful XAI improves user agency by leveraging seamful information to enhance explainability.
# Processing item: ProactiveAgent uses large language models to offer context-aware, personalized suggestions based on real-time environmental data and user interactions.
# Processing item: ProactiveAgent integrates visual and spoken interactions into memory storage to enhance decision support by understanding user intent.
# Processing item: FINER improves explanation quality for risk detection by fine-tuning classifiers with an explanation-guided multi-task learning strategy.
# Processing item: FINER outperforms a state-of-the-art tool in facilitating malware analysis by providing high-fidelity and intelligible explanations.
# Processing item: Large language models reduce authors' burden by assisting in creating QA-style articles.
# Processing item: Large language models help researchers understand readers' perspectives in QA-style articles.
# Processing item: Virtual reality enhances the teleoperation of semi-autonomous robotic boats by integrating live sensor data for monitoring and control.
# Processing item: Developers use community-shared experiences to evaluate AI tool suggestions, fostering informed trust.
# Processing item: Community features can enhance user trust in AI code generation systems by providing relevant social signals.
# Processing item: Presenting AI recommendations with a second opinion reduces decision-makers' over-reliance on AI.
# Processing item: Allowing decision-makers to solicit peer second opinions can mitigate over-reliance without increasing under-reliance in some cases.
# Processing item: AI explanations generally increase clinician confidence in treatment recommendations for sepsis.
# Processing item: Clinicians engage in a negotiation process with AI recommendations, selectively following, rejecting, or delaying them.
# Processing item: Generative agents autonomously coordinate social events, such as a Valentine's Day party, by spreading invitations and arranging attendance.
# Processing item: The architecture of generative agents significantly enhances the believability of simulated human behavior through observation, planning, and reflection.
# Processing item: First-person expressions of uncertainty in AI responses decrease user confidence and agreement with the AI, while increasing user accuracy.
# Processing item: General expressions of uncertainty in AI responses have weaker effects on user confidence and are not statistically significant.
# Processing item: AI assistants enhance convergent and divergent thinking in players.
# Processing item: AI assistants interfere with the formation of team mental models.
# Processing item: AI assistants weaken social connections within teams but strengthen them across teams.
# Processing item: GANCollage enhances creativity support by integrating AI-generated visual ideas into the ideation phase.
# Processing item: The AI-driven interactive tagging system in GANCollage enables effective exploration of StyleGAN generations.
# Processing item: Participants find GANCollage enjoyable and explicit for exploring AI-generated visual ideas.
# Processing item: Presenting AI model uncertainty in a frequency format helps users adjust their reliance and reduces confirmation bias.
# Processing item: User demographics, including age and familiarity with probability, influence human-AI collaborative decision-making.
# Processing item: Generative AI systems enhance music-based reminiscence by generating conversations and images for older adults.
# Processing item: Generative machine learning in LingoLand creates personalized language missions, enhancing learner engagement.
# Processing item: AI-driven interactions in LingoLand provide instant feedback, improving language skill acquisition.
# Processing item: TutoAI achieves higher or similar quality in mixed-media tutorial creation compared to baseline models.
# Processing item: AI tools improve self-efficacy in older adults by providing essential financial information.
# Processing item: Older adults express interest in using AI for managing retirement planning, education expenses, and healthcare costs.
# Processing item: Explicit AI-generated Takeover Requests enhance driver comfort by clearly indicating conflict situations.
# Processing item: AI-powered code generation tools require improved affordances for effective trust evaluation by developers.
# Processing item: Design concepts such as suggestion quality indicators, usage stats, and control mechanisms aid developers in making trust judgments about AI tools.
# Processing item: Ambiguity in AR games reduces perceived errors by leveraging the probabilistic nature of AI object detection.
# Processing item: AI transparency in AR games enhances user experience by providing clear system explanations.
# Processing item: Controllability in AR games allows users to manage uncertainties, improving overall gameplay satisfaction.
# Processing item: WaitGPT enhances error detection in LLM data analysis by providing interactive visual code representations.
# Processing item: WaitGPT increases user confidence in LLM-generated analysis by enabling real-time monitoring and control.
# Processing item: Feature-based AI explanations increase decision-makers' overreliance on AI systems when the AI is incorrect.
# Processing item: Example-based AI explanations improve decision-makers' performance and help achieve complementary human-AI performance.
# Processing item: Human-AI co-dancing creates hybrid movement aesthetics by integrating live dancers with AI-powered virtual partners.
# Processing item: AI models dynamically alter dance movements by manipulating animation keyframes and joint motions in real-time.
# Processing item: AI-driven voice control allows participants to adjust virtual dance choreography, enhancing interactive dance experiences.
# Processing item: Accurate AI confidence signals increase trust metrics without leading to over-reliance.
# Processing item: Practitioners use the People + AI Guidebook for AI design challenges, education, and cross-functional communication.
# Processing item: Practitioners desire more support for early phase ideation and problem formulation to prevent AI product failures.
# Processing item: LIMEADE improves accuracy in image classification by integrating human advice into opaque models.
# Processing item: LIMEADE enhances user control, trust, and satisfaction in neural recommender systems for scientific papers.
# Processing item: AI personas provide on-demand feedback that inspires text revisions by offering diverse perspectives.
# Processing item: People are less accurate at identifying the truthfulness of synthetic face images generated by newer algorithms.
# Processing item: People demonstrate different gazing behaviors when viewing and rating real faces compared to those generated by older machine learning algorithms.
# Processing item: Participants are more likely to follow AI suggestions when given longer final decision time.
# Processing item: Participants exhibit greater agency and logical engagement in tasks, despite a tendency to adhere to initial responses.
# Processing item: AI-based living memories enhance learning effectiveness and motivation when learning about historical figures.
# Processing item: The AI system AlgoBo's questions led to knowledge-dense conversations, enhancing learner engagement with an effect size of 0.71.
# Processing item: The AI prompting pipeline effectively configured AlgoBo's problem-solving performance, allowing it to simulate misconceptions and unawareness.
# Processing item: Generative AI models enhance emotional storytelling by creating metaphorical images and text depictions.
# Processing item: The AI interface Metamorpheus aids in vivid dream recall and meaningful self-reflection.
# Processing item: EvalLM helps developers create more diverse criteria for prompt evaluation.
# Processing item: EvalLM enables examination of twice as many outputs compared to manual evaluation.
# Processing item: EvalLM reduces the number of prompt revisions by 59%.
# Processing item: Computational tools enhance science journalists' user agency by providing contextual and collaborative notions of newsworthiness.
# Processing item: RUBICON achieves higher accuracy and yield rates than existing baselines in differentiating conversation quality.
# Processing item: Participants felt negatively towards content creators when AI was perceived to be involved in the creation process.
# Processing item: Assigned creator type, whether human or AI, did not influence the judgment of the content quality.
# Processing item: Computational notebooks enable multidisciplinary learning by providing interactive data visualizations.
# Processing item: Young adults, carers, and clinicians use computational notebooks to anticipate the benefits and harms of ML models in diabetes care.
# Processing item: Fictional feature importance plots in computational notebooks highlight specific care needs in diabetes management.
# Processing item: Multimodal prompt input encourages designers to explore and express themselves more effectively.
# Processing item: Designers develop innovative uses of DesignPrompt for creating elaborate multimodal prompts.
# Processing item: Participants perceived the AI-based bird identification app as trustworthy but verified outputs before acceptance.
# Processing item: Users selectively trusted the AI system, avoiding its adoption in high-stakes scenarios.
# Processing item: Domain knowledge and context significantly influenced trust-related decision-making with the AI app.
# Processing item: Vision-language models generate accurate radiology findings from medical images.
# Processing item: Vision-language models effectively answer visual questions in radiology, such as identifying nodules in chest X-rays.
# Processing item: AI-generated mood boards enhance the exploration of visual ideas by providing a semantically-enriched experience.
# Processing item: The AI-driven game 'Language Urban Odyssey' significantly boosts interest and proficiency in language learning by leveraging ChatGPT 3.5 for immersive experiences.
# Processing item: Users experienced greater control with the Stepwise and Phasewise systems compared to a conversational baseline.
# Processing item: AI-assisted data analysis tools facilitated easier intervention, correction, and verification for users.
# Processing item: Groups rely more on AI models than individuals, regardless of AI correctness.
# Processing item: Groups exhibit higher confidence in overturning incorrect AI recommendations.
# Processing item: Groups achieve fairer decisions than individuals based on the accuracy equality criterion.
# Processing item: AI-powered commission-support systems enhance artist-client communication by concretizing boundary objects.
# Processing item: Artinter's AI features facilitate concept definition with artifacts, improving mutual understanding in art commissions.
# Processing item: Local and global AI explanations together enhance user understanding of how to improve recommendations.
# Processing item: Global AI explanations alone are more efficient for identifying false positive and negative recommendations.
# Processing item: AI-powered decision support systems that enhance intrinsic motivation improve decision-making performance compared to existing paradigms.
# Processing item: Fostering intrinsic motivation in decision-makers leads to a better subjective experience when using AI decision support tools.
# Processing item: Social media data provided by patient participants serves as boundary objects, facilitating stakeholder collaboration in mental health AI research.
# Processing item: Generative AI and human-in-the-loop interaction enhance the diversity and creativity of music synthesis.
# Processing item: Optometrists' risk-averse tendencies significantly influence their interpretation of AI clinical decision support system outputs.
# Processing item: ML-based teaching systems enable cost-effective knowledge transfer from experts to novices in organizations.
# Processing item: LLooM's AI-generated concepts improve data coverage and quality over traditional topic models.
# Processing item: AI-driven concept induction reveals new insights in familiar datasets, such as identifying attacks on out-party stances in political social media.
# Processing item: Metrics influence fairness perception by affecting which models practitioners deem fair.
# Processing item: Practitioners assess model fairness by focusing on risks of underpredicting or overpredicting.
# Processing item: Fairness assessment involves using personal experiences and forming identity token groups.
# Processing item: The LLM-based chatbot app enhances user motivation by proactively recommending actions towards personal goals based on contextual factors.
# Processing item: Feature-based AI explanations do not reliably improve distributive fairness in AI-assisted decisions.
# Processing item: AI explanations that highlight task-irrelevant features can prompt overrides of AI recommendations that align with gender stereotypes.
# Processing item: Task-relevant AI explanations may induce reliance on stereotype-aligned errors, affecting distributive fairness.
# Processing item: Eye gaze duration on AI suggestions strongly correlates with user agreement and perceived reliance.
# Processing item: User agency is maintained when tasks are easy and AI performance is low or inconsistent.
# Processing item: AI-generated texts enrich writing by introducing unexpected elements that enhance creativity.
# Processing item: Human writers experience joyful and inspirational interactions when engaging with AI-generated content.
# Processing item: Human-like physical bodies in AI systems significantly increase moral consideration towards them.
# Processing item: AI prosociality, including emotion expression and cooperation, leads to higher moral consideration from users.
# Processing item: XAI nudges users towards forming uniform judgments of news veracity, indicating reliance on AI explanations.
# Processing item: Players develop mental models of adversarial AI based on focus (top-down vs. bottom-up) and style (systematic vs. reactive).
# Processing item: AI-generated analyses require thorough validation to ensure alignment with analyst intent.
# Processing item: Analysts use diverse verification approaches influenced by their programming and analysis backgrounds.
# Processing item: AI and human responses together provide richer responses for emergent users.
# Processing item: LLM-powered devil's advocates that challenge AI recommendations promote appropriate reliance on AI in group decision making.
# Processing item: Interactive LLM-powered devil’s advocates are perceived as more collaborative and of higher quality without increasing perceived workload.
# Processing item: The interactive system, Luminate, enhances creative potential by enabling structured exploration of design space with large language models.
# Processing item: Professional writers using Luminate reported increased inspiration and idea generation during creative tasks.
# Processing item: AI-framed Questioning significantly enhances human ability to discern logically flawed statements.
# Processing item: Recruitment chatbots enhance user experience by integrating human-centered design principles.
# Processing item: Human-centered recruitment chatbots improve acceptability among users.
# Processing item: AI systems outperforming humans lead to feelings of inferiority and reduced agency.
# Processing item: Participants exhibited less positive attitudes towards AI systems when outperformed by them.
# Processing item: Judges in Pennsylvania overwhelmingly ignore AI-based sentence risk assessment instruments, labeling them as ineffective.
# Processing item: Organizational factors, including county norms and information dissemination issues, significantly influence judges' resistance to AI-based tools.
# Processing item: Pearl, an AI-based system, enables users to gain insights into workplace wellbeing by visualizing personal data and tagging regions of interest.
# Processing item: Machine assistance in Pearl supports personalized self-reflection, allowing users to explore their calendar data related to wellbeing goals.
# Processing item: Users prefer AI bots to learn through demonstration methods over sorting and categorizing.
# Processing item: Community perceptions influence user preferences in AI bot teaching methods, emphasizing transparency and feedback orientation.
# Processing item: AI explanations enhance perceived understandability and transparency in user-adaptive in-vehicle features.
# Processing item: Insufficiently designed AI explanations can decrease system acceptance among users.
# Processing item: PrISM-Tracker improves procedure tracking accuracy by incorporating graph-based representations and user interaction.
# Processing item: The AI system's transition graphs enhance step tracking in procedures like latte-making and wound care.
# Processing item: Simulated human input boosts the AI model's performance in recognizing procedural steps.
# Processing item: Speech and gaze interfaces enable robots to reliably infer task parameters in real-world scenarios.
# Processing item: AI agents can achieve human-like behavior in 3D video game navigation tasks, as evidenced by human judges' inability to distinguish between AI and human navigators.
# Processing item: AI-powered symptom checkers automate patient urgency assessment but exclude vulnerable patient groups.
# Processing item: AI systems can enhance telenurses' decision-making by suggesting questions during patient calls.
# Processing item: Token representation methods influence audience satisfaction in AI-generated music.
# Processing item: Characteristics of deep learning models impact subjective satisfaction with music composition.
# Processing item: Grounded abstraction matching improves end-users' understanding of the scope and capabilities of the AI code-generating model.
# Processing item: Grounded abstraction matching enhances users' ability to effectively use natural language queries for code generation.
# Processing item: Algorithmic decision-making in ride-pooling services reduces predictability and control for passengers.
# Processing item: Language models enhance story development by providing varied writing suggestions that writers integrate into their narratives.
# Processing item: AI-based credibility indicators align people's belief in news veracity with AI predictions, affecting misinformation detection accuracy.
# Processing item: AI-based credibility indicators have limited impact on news engagement when social influence is present.
# Processing item: The effects of AI-based credibility indicators on misinformation detection and spread are enhanced by social influence.
# Processing item: GenAI systems enhance professional workflows by enabling new forms of human–AI co-creation.
# Processing item: Time pressure influences the effectiveness of AI assistance, making certain AI assistances more beneficial compared to no-time-pressure scenarios.
# Processing item: User overreliance on AI is a key predictor of behavior, affecting the choice and use of different AI assistance types.
# Processing item: AI assistances exhibit varying accuracy-time tradeoffs in time-pressured settings, suggesting the need for adaptable AI assistance strategies.
# Processing item: Photo Steward's validation workflow encourages deliberation among users when making photo ID decisions.
# Processing item: Photo Steward's stewardship visualizations assist users in accurately assessing photo ID information, fostering diverse stigmergic collaboration.
# Processing item: AI recommender systems face tensions in value interpretation between users and practitioners, impacting design effectiveness.
# Processing item: AI-driven recommendation quality, privacy, transparency, fairness, and trustworthiness are crucial for user satisfaction and system trust.
# Processing item: UI levels of initiative and control affect perceived authorship in AI-assisted text writing.
# Processing item: Human-AI collaborative editing systems improve the efficiency of producing descriptive alt text for scientific figures.
# Processing item: Interactive suggestions in the AI system prompt more iterations and enhance the quality of alt text descriptions without increasing cognitive load.
# Processing item: AI-powered chatbots enhance informed consent by improving consent form reading in online studies.
# Processing item: AI-powered chatbots promote participants' feelings of agency, closing the power gap between participants and researchers.
# Processing item: The proposed algorithm reduces decision inaccuracies in college admissions by increasing agreement to ground-truth by 2%.
# Processing item: The algorithm improves product preference agreement by 5% in a crowd-sourced study.
# Processing item: A real-time procedure reduces anchoring bias and increases agreement to ground-truth by 7% in decision-making.
# Processing item: AI-embedded tools in retail are perceived as useful but can also provoke concerns about societal change.
# Processing item: ML-assisted UI elevates precision and recall in oil spill detection by over 11% and increases efficiency by 29% compared to non-assisted UI.
# Processing item: Agreement among non-expert crowd workers further improves precision by 8% and recall by almost 5% beyond pure ML performance.
# Processing item: Teachable machine learners enhance perceived usefulness for crowdworkers through a learning by teaching approach.
# Processing item: AI agents build trust with crowd workers by facilitating teacher-learner interactions.
# Processing item: Users lack adequate information to assess machine translation quality, leading to potential misunderstandings.
# Processing item: Inaccurate machine translations can have social consequences, as users struggle to discern intent from disfluency.
# Processing item: AI-based apps can lead to a loss of personal autonomy when user privacy or identity is threatened.
# Processing item: Users desire mechanisms for providing intelligibility and control over AI to mitigate loss of autonomy.
# Processing item: Users' perceived learning about facial recognition strengths and limitations improved after using the AI-based Civil War Twin application.
# Processing item: The AI design of Civil War Twin successfully met users' ethical standards, enhancing transparency and inclusivity.
# Processing item: End-users personalize AI recommender systems through teaching, resisting, and repurposing to achieve desired experiences.
# Processing item: Sensecape enables users to explore more topics by externalizing levels of abstraction.
# Processing item: Sensecape empowers users to structure their knowledge hierarchically during complex information tasks.
# Processing item: Trust in AI is influenced by the openness level of the human annotator.
# Processing item: Trust in AI is affected by the importance level of input features in the decision-making process.
# Processing item: High confidence human-model agreement increases reliance on AI models when performance information is absent.
# Processing item: The availability of aggregate-level model performance data alters the impact of human-model agreement on reliance.
# Processing item: Families creatively meld generative AI and traditional art materials to externalize ideas and feelings in storymaking sessions.
# Processing item: Generative AI as expressive materials in therapy enhances family communication by facilitating creative expression.
# Processing item: The AI Playbook encourages product teams to prioritize both ideal and failure scenarios in AI prototyping.
# Processing item: The AI Playbook standardizes the articulation of AI failures from a user experience perspective.
# Processing item: The AI Playbook acts as a boundary object between user experience designers, data scientists, and engineers.
# Processing item: Large language models (LLMs) should help users identify the 'right questions to ask' rather than providing definitive legal judgments.
# Processing item: Experts highlight novel legal considerations for LLMs, including unauthorized practice of law, confidentiality, and liability for inaccurate advice.
# Processing item: People rely more on machine learning models when making decisions on out-of-distribution data than on in-distribution data.
# Processing item: Increasing awareness of possible performance disparities in machine learning models decreases over-reliance under covariate shift.
# Processing item: Visualizing data distributions and model performance does not reduce reliance on machine learning models.
# Processing item: Interactive AI tutorials help high-performing individuals reduce over-reliance on ML models by aligning tutorial content with specific ML models.
# Processing item: Low-performing individuals' reliance on ML models remains unchanged despite the presence or type of AI tutorial.
# Processing item: People find interactive AI tutorials more understandable and slightly more useful.
# Processing item: The ESCAPE system enables users to identify and address AI blindspots by facilitating the recognition of spurious associations.
# Processing item: AI statistical approaches, including relative concept association, help quantify and mitigate biased associations in classification models.
# Processing item: First impressions of an AI system significantly influence trust formation.
# Processing item: User trust in AI systems develops slowly over multiple interactions.
# Processing item: Participant age and technology affinity affect trust in AI systems.
# Processing item: AI systems enhance patient treatment by analyzing patient-generated health data for risk profiling and predicting deterioration.
# Processing item: Healthcare providers desire AI to support a co-dependent collaboration, improving clinical practice through human-AI enrichment.
# Processing item: Non-expert users improved understanding of aleatoric and epistemic uncertainty by using larger or more varied training sets.
# Processing item: Participants did not improve classifier training or outcome prediction by relying solely on uncertainty measures.
# Processing item: Participants successfully identified aleatoric versus epistemic uncertainty in three specific card placement scenarios.
# Processing item: Time between AI recommendation and clinical assessment is significantly longer for incorrect assessments.
# Processing item: Type of medical content displayed significantly affects decision time.
# Processing item: Participant's clinical role significantly influences perception of clinical AI support systems.
# Processing item: AI-based decision systems significantly influence fairness perceptions based on group favoritism rather than unbiased treatment.
# Processing item: Decision subjects' retention in AI systems is driven by personal prospects of favorable outcomes rather than fairness perceptions.
# Processing item: Fairness perceptions are complexly influenced by how AI systems treat individuals in different groups.
# Processing item: SHAP has a 92% success rate in generating sensible explanations for smart home activity recognition.
# Processing item: Users in 83% of scenarios preferred natural language explanations over simple activity labels.
# Processing item: Some XAI methods increase user confidence in activity recognition accuracy, while others decrease it.
# Processing item: Sketch sequencing significantly impacts AI model performance during early training stages.
# Processing item: Simple operations on drawings enhance user understanding of the AI system.
# Processing item: Inherent properties of Deep Neural Networks cause user confusion during training.
# Processing item: AI-generated text reduces users' sense of authorship and ownership, known as the AI Ghostwriter Effect.
# Processing item: Higher participant influence on AI-generated texts increases their sense of ownership.
# Processing item: Users attribute more ownership to human ghostwriters than AI ghostwriters, highlighting an ownership-authorship discrepancy.
# Processing item: Responders prefer human opponents over AI systems in ultimatum bargaining, demanding higher compensation from AI.
# Processing item: Responders prioritize economic self-interest when engaging with human proposers, maximizing expected value.
# Processing item: Responders avoid AI systems even when predicting income maximization, overriding economic self-interest.
# Processing item: AI agents in Hanabi perform worse than first-time human players due to limitations in coordination play and role establishment.
# Processing item: Human-agent teams outperform human-only teams in emergency response tasks.
# Processing item: High spatial awareness enhances team mental model similarity in human-agent teams.
# Processing item: ARMath engages children in math learning by turning everyday objects into interactive math tools.
# Processing item: Failures in AI within ARMath provide learning opportunities for children.
# Processing item: AI assistants enhance decision making by providing planning suggestions that align with analysts' goals.
# Processing item: False positives in AI grading harm learning by reducing students' engagement with feedback.
# Processing item: False negatives in AI grading harm learning primarily for students with lower engagement, highlighting the protective role of active participation.
# Processing item: Medical experts desire information about the AI assistant's strengths, limitations, and design objectives before integrating it into practice.
# Processing item: Clinicians seek upfront knowledge of the AI's subjective perspective and how it aligns with their diagnostic patterns.
# Processing item: Pilots prefer AI decision support tools that provide directability and continuous support rather than focusing solely on trust calibration.
# Processing item: AI-steering tools enhance users' trust and control over musical compositions.
# Processing item: Semantic Sliders increase users' sense of collaboration and self-efficacy in AI music creation.
# Processing item: Voice Lanes and Example-Based Sliders improve users' ownership of compositions.
# Processing item: The AI chatbot Wander generates science-fiction travelogues using text messages on platforms like Discord and WeChat.
# Processing item: Wander creates real-time interactive maps with text, images, and global coordinates based on real-world locations.
# Processing item: Wander employs defamiliarization to offer new perspectives through everyday communication.
# Processing item: Non-human metaphors in conversational agents increase worker engagement in crowdsourcing tasks.
# Processing item: Conversational agents using non-human metaphors reduce perceived cognitive load among workers.
# Processing item: Non-human metaphorical representations of conversational agents enhance intrinsic motivation and trust among workers.
# Processing item: Storywriters prioritize emotional values over AI-generated productivity when writing.
# Processing item: Writers with high self-confidence distrust AI in complex tasks like character and dialogue creation.
# Processing item: AI control mechanisms often mismatch storywriters' personal writing strategies.
# Processing item: Agents with higher value similarity to users increase trust levels in AI systems.
# Processing item: Digital AI assistants in cars are preferred to operate with higher transparency, offering users insights into their actions.
# Processing item: Deep learning-based tools increase the diagnostic utility of retrieved medical images by aligning them with pathologists' needs.
# Processing item: Refinement tools enhance user trust in image retrieval algorithms without compromising diagnostic accuracy.
# Processing item: Pathologists adopt new strategies using AI refinement tools to understand and correct ML algorithm errors.
# Processing item: Dynamic audience selection (DAS) controls increase user confidence in content sharing by enhancing expressiveness and customizability.
# Processing item: Participants perceive DAS as intrusive due to low transparency and distrust in algorithmic inferences.
# Processing item: Silly rules increase the legibility of normative systems for AI systems by providing clearer distinctions within complex rule structures.
# Processing item: Saliency maps produced by the LRP algorithm help users identify specific image features that CNNs are sensitive to.
# Processing item: AI level design tools prompt designers to alter their design practices.
# Processing item: Designers perceive AI tools as having potential value in their design process, depending on their desired role for the AI.
# Processing item: Users employ tactics to trick algorithms, avoiding censoring and protecting privacy.
# Processing item: Encrypted messages are perceived as more trustworthy and authentic in online review communities.
# Processing item: The hybrid AI model achieves comparable performance to a Neural Network in assessing stroke rehabilitation exercises.
# Processing item: The hybrid AI model provides explanations for its predictions, enhancing interpretability in stroke rehabilitation assessments.
# Processing item: The hybrid AI model allows for user-specific rule integration, enabling personalized stroke rehabilitation assessments.
# Processing item: ChatGPT increases frustration levels in students during software engineering tasks.
# Processing item: ChatGPT's violations of AI interaction guidelines lead to seven negative consequences for users.
# Processing item: AI clones exploit and displace individual identities, causing negative emotional reactions.
# Processing item: Creating AI clones threatens cohesive self-perception and unique individuality.
# Processing item: Interacting with AI clones of known individuals risks misrepresentation and over-attachment.
# Processing item: AI explanations enhance trust calibration in machine teaching by providing insights into the model's reasoning.
# Processing item: AI explanations enable richer teaching feedback by allowing machine teachers to understand and correct model mistakes.
# Processing item: AI explanations may inadvertently cause an anchoring effect, leading teachers to rely too heavily on model judgments.
# Processing item: AI decision support systems enhance therapist assessment accuracy, increasing agreement from 0.66 to 0.71 F1-scores.
# Processing item: AI-generated patient-specific analysis boosts therapist usage intent compared to traditional systems ($p < 0.05$).
# Processing item: Reinforcement learning-based AI systems reduce therapist effort in patient motion assessment ($p < 0.10$).
# Processing item: AI-led moderation allows community members to collaboratively develop explanations for automated decisions.
# Processing item: Normative AI explanations enhance user understanding and perceived system capability.
# Processing item: Comparative AI explanations may expose algorithm limitations, affecting user perception.
# Processing item: Principal component analysis identifies two dimensions of AI: human involvement and AI autonomy.
# Processing item: AI mediators are assessed most favorably, while AI tools are assessed least favorably by laypeople.
# Processing item: Rule-based AI agents differ from reinforcement learning-based agents in perceived cooperativity and teaming perception.
# Processing item: Students overestimated the AI autograder's likelihood of marking correct answers as wrong, leading to dissatisfaction and perceived unfairness.
# Processing item: Generative AI models enhance sound design by offering creative support tools for professionals.
# Processing item: AI models using Facebook data can predict relapse in schizophrenia patients.
# Processing item: AI predictions can foster collaboration between schizophrenia patients and their support systems.
# Processing item: AI models encourage self-reflection among schizophrenia patients.
# Processing item: Embodied AI perceived as expert increases trust, acceptance, warmth, and competence.
# Processing item: AI's perceived competence and embodiment congruence to the environment enhance acceptance.
# Processing item: DuetDraw enhances user satisfaction by providing detailed instructions during collaborative drawing tasks.
# Processing item: Users prefer AI explanations to be available on demand, allowing them to lead the creative process.
# Processing item: Despite low ratings in predictability and controllability, users enjoy interacting with the AI during creative tasks.
# Processing item: AI-generated responses are preferred by young people for topics related to relationships, self-expression, and physical health.
# Processing item: Human responses are favored by young people when addressing sensitive topics, such as suicidal thoughts.
# Processing item: Interactive machine learning enhances rehabilitation assessment by improving prediction accuracy for upper-limb exercises from 0.8279 to 0.9116 average F1-scores.
# Processing item: Machine learning models with feature selection provide kinematic feature-based analysis as AI explanations for expert knowledge integration.
# ...
# Processing item: ForSense enhances online research by integrating multiple stages of the process.
# Processing item: ForSense accelerates online research using neural-driven machine reading.
# Processing item: Thought Bubbles reveal how disruption location affects mental model development.
# Processing item: Thought Bubbles demonstrate that information availability influences decision-making.
# Processing item: Generative AI tools provide creative writers with an alternative support source, complementing peer and mentor assistance.
# Processing item: AI-enabled co-orchestration technology supports dynamic student pairing during class sessions.
# Processing item: Students prefer more control over dynamic transitions than teachers are willing to allow.
# Processing item: AI-driven classroom solutions reveal design implications for personalized smart classrooms.
# Processing item: Interactive model cards enhance model documentation by improving understandability and interpretability for non-expert analysts.
# Processing item: Design elements such as language, visual cues, and warnings facilitate interactivity and accessibility of AI model documentation.
# Processing item: Carefully designed interactive features in AI documentation support trust and safety among non-expert users.
# Processing item: AI role cards facilitate exploration of Intelligent Personal Assistant roles by categorizing them into confidant, teammate, task performer, and expert.
# Processing item: Text-to-image AI tools reduce design fixation by providing diverse reference images.
# Processing item: 3DALL-E enhances design workflows by integrating AI-generated inspirations with CAD software.
# Processing item: Crowdsourcing enables the creation and validation of geographically tailored bias tests.
# Processing item: The web-based tool effectively surfaces implicit user biases on custom themes.
# Processing item: The AI-assisted method allows for the adaptation of bias tests to evolving cultural contexts.
# Processing item: Workers anticipate that wellbeing sensing technologies may disrupt organizational culture and interpersonal relationships.
# Processing item: Participants foresee potential harms from technical limitations and misaligned notions of 'worker wellbeing' in AI-driven workplace technologies.
# Processing item: Functional factors such as usefulness, content credibility, and quality of service significantly influence trust in healthcare voice AI assistants.
# Processing item: Security and privacy risks, along with personal stance on technology, are critical determinants of trust in healthcare voice AI assistants.
# Processing item: AI contributes to group decision-making but remains secondary due to its limited ability to follow dynamic discussions.
# Processing item: AI-generated confidence highlighting aids software engineers in detecting errors in generated source code.
# Processing item: Alternate translations provided by generative AI models enhance software engineers' understanding of code translation tasks.
# Processing item: The AI system recognizes unvoiced utterances using ultrasound imaging sensors, enabling control of smart speakers without vocalization.
# Processing item: Users can adjust their oral movements to improve the accuracy of AI-driven voice recognition.
# Processing item: Matcha improves the accuracy of Google Play data safety labels by detecting user data accesses and transmissions.
# Processing item: Developers prefer Matcha for its accuracy benefits over Google's official tool.
# Processing item: Computer-Assisted Protected Time increases self-reported performance and job resources among workers.
# Processing item: Workers using Computer-Assisted Protected Time show reduced overall work activity by rearranging tasks.
# Processing item: The Value Cards toolkit enhances students' understanding of technical definitions and trade-offs of performance metrics in real-world contexts.
# Processing item: The Value Cards toolkit enables students to recognize the importance of considering diverse social values in algorithmic system development.
# Processing item: UX designers frequently work with pre-trained models but lack support for UX-led ideation.
# Processing item: UX designers need model transparency information to understand AI limitations.
# Processing item: Cloud-based sentiment analysis tools show moderate agreement with each other but do not align well with human ratings.
# Processing item: Current cloud-based sentiment analysis services are not sufficiently accurate for effective human-agent interaction.
# Processing item: Stylette reduces the learning curve for web styling by enabling users to perform changes 35% faster than traditional developer tools.
# Processing item: Stylette facilitates user experimentation with CSS by suggesting multiple alternatives for a single styling goal.
# Processing item: Automated speech recognition tools significantly increase subtitling efficiency and effectiveness for novice users.
# Processing item: AI-augmented subtitling processes are perceived as more demanding by users.
# Processing item: Risk assessment algorithms overlook systemic risk factors, leading to biased decision-making in child welfare.
# Processing item: The AI system's reliance on casenotes introduces biases, affecting the accuracy of NLP-based systems.
# Processing item: Voice assistants introduced as learners or collaborators increase user willingness to provide feedback.
# Processing item: User-initiated feedback instructions reduce perceived disruptiveness in voice assistant interactions.
# Processing item: The AI tool xPath improves workflow integration in pathology by aligning with pathologists' examination processes.
# Processing item: xPath enhances AI integration into pathology practice as confirmed by evaluations and sessions with 12 medical professionals.
# Processing item: Machine learning methods automate mundane UX research tasks, enhancing efficiency.
# Processing item: Machine learning enriches UX research by providing insights into users' emotional experiences.
# Processing item: Participants preferred textual presentation to express precise receptivity statuses, especially at high and low extremes.
# Processing item: Graphical and numeric presentations were favored when self-perceived receptivity levels were ambiguous.
# Processing item: AI visualization tools improve designers' ability to understand and manage algorithmic trade-offs.
# Processing item: AI methods assist users in aligning algorithmic outputs with their specific goals and needs.
# Processing item: CL exploitation strategies enhance appropriate human trust in AI compared to relying solely on AI confidence.
# Processing item: AI-driven text prompts enable rapid ideation of diverse shape-changing behaviors in pin-based displays.
# Processing item: DeepFuse enables CNN engineers to create more accurate models by systematically addressing unreasonable local explanations.
# Processing item: CNN engineers using DeepFuse improved model accuracy and reasonability compared to the current state-of-the-art.
# Processing item: Example-based guidance at service-onboarding improves initial task performance in task-oriented chatbots.
# Processing item: Rule-based guidance after failure enhances users' learning outcomes in task-oriented chatbots.
# Processing item: Human review processes enhance perceived fairness in algorithmic decision-making by allowing participation.
# Processing item: Timely review outcomes improve acceptance of algorithmic decisions by affected individuals.
# Processing item: Human involvement in reviews increases the likelihood of favorable outcomes and maintains dignity.
# Processing item: Critical reflection is a core prerequisite for meaningful human-AI collaboration in humanities research contexts.
# Processing item: Computer vision tools require intentional design to actively scaffold and support critical reflection during interaction.
# Processing item: AI-driven self-diagnosis apps are likely to be used by more than half of the participants, particularly when integrated into general practitioner care.
# Processing item: Users prefer AI systems with high perceived warmth over those with high competence.
# Processing item: AI systems' warmth perception influences user choice even when competence is lacking.
# Processing item: The Mindless Attractor intervention helps learners refocus attention by perturbing video voice without requiring conscious awareness.
# Processing item: The AI-driven sensing module effectively activates the intervention without frustrating users, even with false-positive attentive state detections.
# Processing item: DHH adults perceive a benefit from lexical simplification when reading English texts.
# Processing item: DHH adults prefer on-demand lexical simplification systems over automatic simplification.
# Processing item: AI-enhanced learning analytics interfaces communicate insights on team performance in nursing simulations.
# Processing item: AI-driven data storytelling prototypes highlight concerns about accountability and automated insights discovery in educational settings.
# Processing item: GPT-3 assists creative and argumentative writing by enhancing ideation and collaboration.
# Processing item: AI decision support tools in social work need to integrate contextual knowledge to enhance decision-making.
# Processing item: The AI-based visual search framework achieves a mean Average Precision of 76.39% in UI detection.
# Processing item: The AI framework effectively retrieves visually similar design examples by modeling UI context and hierarchical structure.
# Processing item: The AI sketching tool facilitates ideation and helps overcome design fixation.
# Processing item: Conceptual similarity in AI responses is more associated with transformational creativity.
# Processing item: Visual similarity in AI responses is prevalent during detailed design stages, aligning with combinatorial creativity.
# Processing item: XAIR framework enhances AI design by providing clear guidelines for effective AI explanations in Augmented Reality environments.
# Processing item: AI explanations enhance trustworthiness in healthcare by promoting organisational accountability.
# Processing item: Confidence scores help calibrate human trust in AI models during decision making.
# Processing item: Trust calibration alone is insufficient for improving AI-assisted decision making outcomes.
# Processing item: Local explanations may not effectively aid AI-assisted decision making, suggesting a need for new explainability approaches.
# Processing item: AI-embedded coding systems enhance documentation accuracy by auto-suggesting codes from Electronic Healthcare Records.
# Processing item: Clinical Documentation Integrity Specialists improve documentation quality through flexible AI integration and human control.
# Processing item: AI systems foster learning and reflection by allowing experimentation and supporting sensemaking.
# Processing item: Automated documentation generation reduces time for writing documentation in computational notebooks.
# Processing item: AI-driven documentation tools remind data scientists to document code they would have ignored.
# Processing item: AI documentation systems enhance user satisfaction with computational notebooks.
# Processing item: AI-driven Promptiverse increases prompt diversity by 40 times compared to manual methods.
# Processing item: AI annotation tool Grannotate enables efficient creation of high-quality scaffolding prompts.
# Processing item: Participants who frequently win the cooperative word guessing game have more accurate estimates of the AI agent's abilities.
# Processing item: AI-driven tool FlatMagic reduces real and perceived effort in comic flat colorization.
# Processing item: AI automation in FlatMagic identifies and addresses flatting as a bottleneck in the comic creation process.
# Processing item: Clinical Decision Support Systems (CDSSs) enhance ICU care by facilitating collaboration among healthcare professionals.
# Processing item: CDSSs in ICUs must adapt their interfaces to accommodate varying user goals and contextual factors.
# Processing item: Voicemoji reduces emoji entry time by 91.2% for blind or low vision users.
# Processing item: All participants preferred Voicemoji over the Apple iOS keyboard for emoji entry.
# Processing item: AI fact-checking systems enhance user accuracy when model predictions are correct.
# Processing item: Exposure to incorrect AI predictions can decrease user accuracy in claim assessment.
# Processing item: Transparent AI models enable users to improve performance by interacting with incorrect predictions.
# Processing item: Conditional delegation improves model performance by allowing humans to create rules for trustworthy AI decision-making regions.
# Processing item: AI explanations enhance the effectiveness of conditional delegation in content moderation tasks.
# Processing item: Users' competence is influenced by their knowledge of the AI capabilities and the effectiveness of the conversation.
# Processing item: Users' autonomy is impacted by the flexibility of the AI conversation, personalization of experiences, and control over user data.
# Processing item: Users express concerns about integrating social features into AI conversational agents, affecting their sense of relatedness.
# Processing item: Human players paired with an implicature AI are 71% more likely to perceive their partner as human compared to those paired with a non-implicature AI.
# Processing item: Teams with an implicature AI achieve game performance comparable to other state-of-the-art methods.
# Processing item: AI prediction algorithms enhance self-reflection by identifying stress patterns in users' daily activities.
# Processing item: AI explanations of stress levels assist in recalling past stress patterns, aiding in coping strategies.
# Processing item: Computational text analysis of casenotes reveals patterns of street-level discretionary work and latent power structures, informing AI algorithm design.
# Processing item: Personalized AI predictions influence user judgment on social media content, with the effect increasing over time.
# Processing item: The influence of AI predictions on user judgment decreases when users provide reasoning for their assessments.
# Processing item: Experience-based causality learning models outperform traditional text-based methods in identifying causal relationships in text.
# Processing item: Intelligent agents using experience information achieve higher accuracy in causality understanding compared to conventional approaches.
# Processing item: The proposed taxonomy of social errors in Human-Robot Interaction encourages the development of user-centered systems that enhance interaction experiences.
# Processing item: AI fitness instructor apps provide valuable feedback and motivation through visual and dialogue interactions.
# Processing item: AI systems in fitness apps adapt to user needs, enhancing personalization and engagement.
# Processing item: Partial automation allows players with motor impairments to engage in digital games by delegating control of inaccessible inputs to an AI partner.
# Processing item: Six participants with varying motor abilities successfully played rehabilitative games using AI-assisted partial automation.
# Processing item: AI in HRM faces tensions due to divergent perspectives on fairness among stakeholders.
# Processing item: AI's accuracy is a significant concern in HRM, impacting trust and usability.
# Processing item: AI transparency is essential for understanding its decision-making process in HRM.
# Processing item: Computer vision technologies enhance RSA systems by improving navigation for people with visual impairments.
# Processing item: Agent voice plays a significant social role in human-agent interaction by influencing user perceptions and behaviors.
# Processing item: There is a generational shift in perceptions and reactions to agent voice, aligning with the rise of mobile voice assistants.

# %%
# Import required libraries
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from kneed import KneeLocator
from typing import Dict, List, Tuple
import seaborn as sns

def determine_optimal_k(embeddings: np.ndarray, max_k: int = 20) -> int:
    """
    Determine optimal number of clusters using elbow method
    
    Args:
        embeddings: numpy array of embeddings
        max_k: maximum number of clusters to try
    
    Returns:
        optimal number of clusters
    """
    inertias = []
    k_values = range(1, max_k + 1)
    
    # Calculate inertia for different k values
    for k in k_values:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(embeddings)
        inertias.append(kmeans.inertia_)
    
    # Use knee locator to find the optimal k
    kneedle = KneeLocator(
        k_values, 
        inertias, 
        S=1.0, 
        curve="convex", 
        direction="decreasing"
    )
    
    # If no clear elbow is found, use square root of n/2
    if kneedle.elbow is None:
        optimal_k = int(np.sqrt(len(embeddings) / 2))
    else:
        optimal_k = kneedle.elbow
        
    return optimal_k

def perform_clustering(embedding_dict: Dict[str, List[float]]) -> Tuple[np.ndarray, np.ndarray, list]:
    """
    Perform K-means clustering on embeddings
    
    Args:
        embedding_dict: dictionary mapping statements to their embeddings
    
    Returns:
        tuple of (reduced embeddings, cluster labels, statements)
    """
    # Convert dictionary to arrays
    statements = list(embedding_dict.keys())
    embeddings = np.array([embedding_dict[stmt] for stmt in statements])
    
    # Determine optimal number of clusters
    optimal_k = determine_optimal_k(embeddings)
    print(f"Optimal number of clusters: {optimal_k}")
    
    # Perform K-means clustering
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    cluster_labels = kmeans.fit_predict(embeddings)
    
    # Perform t-SNE dimensionality reduction
    tsne = TSNE(n_components=2, random_state=42)
    reduced_embeddings = tsne.fit_transform(embeddings)
    
    return reduced_embeddings, cluster_labels, statements

def visualize_clusters(reduced_embeddings: np.ndarray, 
                      cluster_labels: np.ndarray, 
                      statements: list,
                      figsize: tuple = (12, 8)) -> None:
    """
    Visualize clusters using scatter plot
    
    Args:
        reduced_embeddings: t-SNE reduced embeddings
        cluster_labels: cluster assignments
        statements: original statements
        figsize: figure size
    """
    plt.figure(figsize=figsize)
    
    # Create scatter plot
    scatter = plt.scatter(
        reduced_embeddings[:, 0],
        reduced_embeddings[:, 1],
        c=cluster_labels,
        cmap='tab20',
        alpha=0.6
    )
    
    # Add legend
    legend1 = plt.legend(*scatter.legend_elements(),
                        title="Clusters",
                        loc="center left",
                        bbox_to_anchor=(1, 0.5))
    # plt.addartist(legend1)
    
    # Add labels and title
    plt.title('t-SNE Visualization of Clusters')
    plt.xlabel('t-SNE Component 1')
    plt.ylabel('t-SNE Component 2')
    
    # Add annotations for a few points from each cluster
    unique_clusters = np.unique(cluster_labels)
    for cluster in unique_clusters:
        # Get indices for current cluster
        cluster_idx = np.where(cluster_labels == cluster)[0]
        # Sample up to 3 points from cluster
        sample_idx = np.random.choice(cluster_idx, 
                                    size=min(3, len(cluster_idx)), 
                                    replace=False)
        
        for idx in sample_idx:
            plt.annotate(statements[idx][:50] + '...' if len(statements[idx]) > 50 else statements[idx],
                        (reduced_embeddings[idx, 0], reduced_embeddings[idx, 1]),
                        xytext=(5, 5), textcoords='offset points',
                        fontsize=8, alpha=0.7)
    
    plt.tight_layout()
    plt.show()

# Example usage
# Replace this with your actual embedding dictionary
example_dict = {
    "statement1": [0.1, 0.2, 0.3],
    "statement2": [0.2, 0.3, 0.4],
    # ... more statements and embeddings
}

# Perform clustering and visualization
reduced_emb, labels, stmts = perform_clustering(embedding)
visualize_clusters(reduced_emb, labels, stmts)

# Additional Analysis: Cluster Statistics
def analyze_clusters(statements: list, cluster_labels: np.ndarray) -> None:
    """
    Print statistics about the clusters
    """
    unique_clusters = np.unique(cluster_labels)
    print("\nCluster Statistics:")
    print("-" * 50)
    
    for cluster in unique_clusters:
        cluster_statements = [stmt for i, stmt in enumerate(statements) 
                            if cluster_labels[i] == cluster]
        print(f"\nCluster {cluster}:")
        print(f"Number of statements: {len(cluster_statements)}")
        print("Sample statements:")
        for stmt in cluster_statements[:3]:  # Show first 3 statements
            print(f"- {stmt[:100]}...")
            
# Run cluster analysis
analyze_clusters(stmts, labels)

# Save results to CSV
def analyze_cluster_content(statements: list, 
                        embeddings: np.ndarray,
                        cluster_labels: np.ndarray,
                        kmeans_model: KMeans,
                        n_keywords: int = 10,
                        n_samples: int = 5) -> Dict[int, dict]:
    """
    Analyze and explain the content of each cluster
    
    Args:
        statements: list of original statements
        embeddings: original embeddings array
        cluster_labels: cluster assignments
        kmeans_model: fitted KMeans model
        n_keywords: number of keywords to extract per cluster
        n_samples: number of representative samples to show
        
    Returns:
        Dictionary containing analysis for each cluster
    """
    from sklearn.feature_extraction.text import TfidfVectorizer
    import nltk
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    nltk.download('punkt')
    nltk.download('stopwords')
    
    # Initialize stop words
    stop_words = set(stopwords.words('english'))
    
    cluster_analysis = {}
    unique_clusters = np.unique(cluster_labels)
    
    for cluster in unique_clusters:
        # Get cluster-specific data
        cluster_mask = cluster_labels == cluster
        cluster_statements = np.array(statements)[cluster_mask]
        cluster_embeddings = embeddings[cluster_mask]
        
        # Calculate distances to cluster centroid
        centroid = kmeans_model.cluster_centers_[cluster]
        distances = np.linalg.norm(cluster_embeddings - centroid, axis=1)
        
        # Get representative samples (closest to centroid)
        closest_indices = np.argsort(distances)[:n_samples]
        representative_samples = cluster_statements[closest_indices]
        
        # Extract keywords using TF-IDF
        vectorizer = TfidfVectorizer(
            stop_words='english',
            max_features=n_keywords,
            ngram_range=(1, 2)
        )
        
        # Combine statements for better keyword extraction
        combined_text = ' '.join(cluster_statements)
        
        # Basic text preprocessing
        tokens = word_tokenize(combined_text.lower())
        tokens = [token for token in tokens if token.isalnum() and token not in stop_words]
        processed_text = ' '.join(tokens)
        
        # Get TF-IDF scores
        try:
            tfidf_matrix = vectorizer.fit_transform([processed_text])
            feature_names = vectorizer.get_feature_names_out()
            scores = tfidf_matrix.toarray()[0]
            keywords = [feature_names[i] for i in scores.argsort()[-n_keywords:][::-1]]
        except ValueError:
            keywords = []
        
        # Calculate basic statistics
        avg_length = np.mean([len(stmt.split()) for stmt in cluster_statements])
        
        # Store analysis results
        cluster_analysis[cluster] = {
            'size': len(cluster_statements),
            'keywords': keywords,
            'representative_samples': representative_samples.tolist(),
            'avg_statement_length': avg_length,
            'coherence_score': -np.mean(distances)  # Higher score = more coherent
        }
    
    return cluster_analysis

def explain_clusters(cluster_analysis: Dict[int, dict], 
                    min_similarity_threshold: float = 0.5) -> None:
    """
    Print human-readable explanations of cluster characteristics
    
    Args:
        cluster_analysis: output from analyze_cluster_content
        min_similarity_threshold: threshold for considering clusters similar
    """
    print("Cluster Analysis Report")
    print("=" * 50)
    
    # Sort clusters by size
    sorted_clusters = sorted(cluster_analysis.items(), 
                           key=lambda x: x[1]['size'], 
                           reverse=True)
    
    for cluster_id, analysis in sorted_clusters:
        print(f"\nCluster {cluster_id} Analysis")
        print("-" * 30)
        
        # Basic statistics
        print(f"Size: {analysis['size']} statements")
        print(f"Average statement length: {analysis['avg_statement_length']:.1f} words")
        print(f"Coherence score: {analysis['coherence_score']:.3f}")
        
        # Keywords
        print("\nKey themes and phrases:")
        for keyword in analysis['keywords']:
            print(f"  • {keyword}")
        
        # Representative samples
        print("\nRepresentative examples:")
        for i, sample in enumerate(analysis['representative_samples'], 1):
            if len(sample) > 100:
                sample = sample[:100] + "..."
            print(f"{i}. {sample}")
        
        print("\nInterpretation:")
        # Generate interpretation based on keywords and samples
        if analysis['coherence_score'] > min_similarity_threshold:
            print("This is a highly coherent cluster with clear common themes.")
        else:
            print("This cluster shows more diversity in its content.")
        
        # Additional insights based on statistics
        if analysis['avg_statement_length'] > 50:
            print("Statements in this cluster tend to be longer and more detailed.")
        elif analysis['avg_statement_length'] < 20:
            print("Statements in this cluster are typically brief and concise.")
        
        print("-" * 50)

def save_results(statements: list, 
                cluster_labels: np.ndarray, 
                reduced_embeddings: np.ndarray,
                cluster_analysis: Dict[int, dict],
                filename: str = 'clustering_results.csv') -> None:
    """
    Save clustering results to CSV file
    """
    results_df = pd.DataFrame({
        'statement': statements,
        'cluster': cluster_labels,
        'tsne_1': reduced_embeddings[:, 0],
        'tsne_2': reduced_embeddings[:, 1]
    })
    
    # Add cluster analysis information
    results_df['cluster_size'] = results_df['cluster'].map(
        lambda x: cluster_analysis[x]['size'])
    results_df['cluster_keywords'] = results_df['cluster'].map(
        lambda x: ', '.join(cluster_analysis[x]['keywords']))
    results_df['cluster_coherence'] = results_df['cluster'].map(
        lambda x: cluster_analysis[x]['coherence_score'])
    
    results_df.to_csv(filename, index=False)
    print(f"\nResults saved to {filename}")

# Perform clustering and analysis
reduced_emb, labels, stmts = perform_clustering(embedding)
embeddings = np.array([embedding[stmt] for stmt in stmts])

# Get the KMeans model
optimal_k = determine_optimal_k(embeddings)
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(embeddings)

# Analyze clusters
cluster_analysis = analyze_cluster_content(
    statements=stmts,
    embeddings=embeddings,
    cluster_labels=labels,
    kmeans_model=kmeans
)

# Print cluster explanations
explain_clusters(cluster_analysis)

# Save the results with cluster analysis
save_results(stmts, labels, reduced_emb, cluster_analysis)
# Out:
# Optimal number of clusters: 11
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 140
#     133 example_dict = {
#     134     "statement1": [0.1, 0.2, 0.3],
#     135     "statement2": [0.2, 0.3, 0.4],
#     136     # ... more statements and embeddings
#     137 }
#     139 # Perform clustering and visualization
# --> 140 reduced_emb, labels, stmts = perform_clustering(embedding)
#     141 visualize_clusters(reduced_emb, labels, stmts)
#     143 # Additional Analysis: Cluster Statistics
#
# Cell In[20], line 72, in perform_clustering(embedding_dict)
#      70 # Perform t-SNE dimensionality reduction
#      71 tsne = TSNE(n_components=2, random_state=42)
# ---> 72 reduced_embeddings = tsne.fit_transform(embeddings)
#      74 return reduced_embeddings, cluster_labels, statements
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1176, in TSNE.fit_transform(self, X, y)
#    1173     self._max_iter = self.max_iter
#    1175 self._check_params_vs_input(X)
# -> 1176 embedding = self._fit(X)
#    1177 self.embedding_ = embedding
#    1178 return self.embedding_
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1044, in TSNE._fit(self, X, skip_num_points)
#    1038 # Degrees of freedom of the Student's t-distribution. The suggestion
#    1039 # degrees_of_freedom = n_components - 1 comes from
#    1040 # "Learning a Parametric Embedding by Preserving Local Structure"
#    1041 # Laurens van der Maaten, 2009.
#    1042 degrees_of_freedom = max(self.n_components - 1, 1)
# -> 1044 return self._tsne(
#    1045     P,
#    1046     degrees_of_freedom,
#    1047     n_samples,
#    1048     X_embedded=X_embedded,
#    1049     neighbors=neighbors_nn,
#    1050     skip_num_points=skip_num_points,
#    1051 )
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:1112, in TSNE._tsne(self, P, degrees_of_freedom, n_samples, X_embedded, neighbors, skip_num_points)
#    1110     opt_args["momentum"] = 0.8
#    1111     opt_args["n_iter_without_progress"] = self.n_iter_without_progress
# -> 1112     params, kl_divergence, it = _gradient_descent(obj_func, params, **opt_args)
#    1114 # Save the final number of iterations
#    1115 self.n_iter_ = it
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:403, in _gradient_descent(objective, p0, it, max_iter, n_iter_check, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, verbose, args, kwargs)
#     400 # only compute the error when needed
#     401 kwargs["compute_error"] = check_convergence or i == max_iter - 1
# --> 403 error, grad = objective(p, *args, **kwargs)
#     405 inc = update * grad < 0.0
#     406 dec = np.invert(inc)
#
# File ~/.venv/lib/python3.12/site-packages/sklearn/manifold/_t_sne.py:284, in _kl_divergence_bh(params, P, degrees_of_freedom, n_samples, n_components, angle, skip_num_points, verbose, compute_error, num_threads)
#     281 indptr = P.indptr.astype(np.int64, copy=False)
#     283 grad = np.zeros(X_embedded.shape, dtype=np.float32)
# --> 284 error = _barnes_hut_tsne.gradient(
#     285     val_P,
#     286     X_embedded,
#     287     neighbors,
#     288     indptr,
#     289     grad,
#     290     angle,
#     291     n_components,
#     292     verbose,
#     293     dof=degrees_of_freedom,
#     294     compute_error=compute_error,
#     295     num_threads=num_threads,
#     296 )
#     297 c = 2.0 * (degrees_of_freedom + 1.0) / degrees_of_freedom
#     298 grad = grad.ravel()
#
# KeyboardInterrupt:
