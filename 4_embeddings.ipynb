# %%
import pandas as pd
import ast
import os
from dotenv import load_dotenv
from openai import OpenAI
import pandas as pd

load_dotenv()
API_KEY = os.getenv('API_KEY')

df = pd.read_csv('result/triplets.csv')
cause = [k.lower().split("|")[0] for k in df['cause'].to_list()]
effect = [k.lower().split("|")[0] for k in df['effect'].to_list()]

pool = set(cause + effect)

# %%
embedding = {}

from openai import OpenAI
client = OpenAI(api_key=API_KEY)

def get_embedding(text, model="text-embedding-3-large"):
   text = text.replace("\n", " ")
   return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
import concurrent.futures

def process_item(item):
    print(f"Processing item: {item}")
    embedding = get_embedding(item)
    return (item, embedding)

def get_concurrent_embeddings(kw_set, max_workers=None):
    embeddings = {}
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_item = {
            executor.submit(process_item, item): item 
            for item in kw_set
        }
        
        for future in concurrent.futures.as_completed(future_to_item):
            try:
                item, embedding = future.result()
                embeddings[item] = embedding
            except Exception as e:
                print(f"Error processing {future_to_item[future]}: {str(e)}")
    
    return embeddings

# %%
embedding = get_concurrent_embeddings(pool)
# Out:
# Processing item: ai:xpath
# Processing item: co:software_engineering
# Processing item: co:creative
# Processing item: ai:liplearner
# Processing item: ai:visualization
# Processing item: co:basic
# Processing item: ai:language-model
# Processing item: co:transparency
# Processing item: ai:deep_neural_network
# Processing item: ai:feature-based
# Processing item: ai:lexicon
# Processing item: ai:example-based
# Processing item: human:middle-aged
# Processing item: human:domain-knowledgeable
# Processing item: human:practitioner
# Processing item: ai:participatory
# Processing item: co:mid-roll
# Processing item: ai:jitai
# Processing item: ai:steering
# Processing item: co:ai_trust_score
# Processing item: human:young
# Processing item: co:segmentation
# Processing item: human:community
# Processing item: human:emergent
# Processing item: co:procedure
# Processing item: co:user-ai
# Processing item: ai:recommender
# Processing item: co:rhetorical
# Processing item: ai:sensemate
# Processing item: ai:decision_support
# Processing item: ai:virtual
# Processing item: human:crowdworker
# Processing item: ai:integrity
# Processing item: human:#variation
# Processing item: co:fairness
# Processing item: ai:decision
# Processing item: human:group
# Processing item: co:explanation:planning
# Processing item: co:pde
# Processing item: co:personalization
# Processing item: co:agreement
# Processing item: ai:retrolens
# Processing item: ai:analogy
# Processing item: co:project
# Processing item: co:momentum
# Processing item: co:training_data
# Processing item: co:principles:ethics
# Processing item: human:live-coder
# Processing item: ai:dapper
# Processing item: human:hrm
# Processing item: ai-led
# Processing item: ai:generated
# Processing item: ai:synthetic
# Processing item: ai:segmentation
# Processing item: co:time2stop
# Processing item: human:clinical_staff
# Processing item: co:specification
# Processing item: ai:das
# Processing item: co:society
# Processing item: human:graduate
# Processing item: human:end-user
# Processing item: co:social
# Processing item: ai:mobile
# Processing item: co:generative_audio
# Processing item: ai:ganravel
# Processing item: ai:civil_war_twin
# Processing item: co:association
# Processing item: human:learner
# Processing item: ai:cdss
# Processing item: human:chinese
# Processing item: co:swipe
# Processing item: co:documentation
# Processing item: human:#autonomy
# Processing item: ai:readingquizmaker
# Processing item: co:processing
# Processing item: ai:annotation
# Processing item: ai:embedded
# Processing item: co:prompt
# Processing item: ai:response
# Processing item: co:collaboration
# Processing item: ai:softaibot
# Processing item: human:ux_practitioner
# Processing item: human:developer
# Processing item: ai:choreography-support
# Processing item: ai:translation
# Processing item: co:empathy
# Processing item: ai:neural_network
# Processing item: human:instructor
# Processing item: ai:fictional
# Processing item: co:interface
# Processing item: co:pathology
# Processing item: ai:co-creative
# Processing item: ai:automation
# Processing item: ai:semantic
# Processing item: ai:tutoai
# Processing item: human:responder
# Processing item: co:designprompt
# Processing item: ai:opinionated
# Processing item: co:smart_water_system
# Processing item: ai:toolkit
# Processing item: human:composer
# Processing item: ai:restyle-musicvae
# Processing item: co:medical
# Processing item: human:engineer:novice
# Processing item: ai:aggregate
# Processing item: human-agent
# Processing item: ai:lrp
# Processing item: co:neuroimaging
# Processing item: human:sighted
# Processing item: ai:personalized
# Processing item: human:ai
# Processing item: ai:algorithmic
# Processing item: co:gift
# Processing item: co:fairness:distribution
# Processing item: co:comic
# Processing item: co:time
# Processing item: co:ml
# Processing item: ai:sepsislab
# Processing item: ai:robot
# Processing item: human:team
# Processing item: ai:tutor
# Processing item: human:participant
# Processing item: ai:graph
# Processing item: human:nursing_team
# Processing item: ai:prism-tracker
# Processing item: ai:sentence
# Processing item: ai:deep
# Processing item: co:visual
# Processing item: co:av
# Processing item: human:programmer
# Processing item: human:designer
# Processing item: ai:musical
# Processing item: co:training
# Processing item: ai:3d
# Processing item: ai:limeade
# Processing item: human:researcher:novice
# Processing item: co:clinical_care
# Processing item: ai:empathic
# Processing item: human:decision
# Processing item: co:house
# Processing item: ai:car
# Processing item: ai:vr
# Processing item: ai:psai
# Processing item: human:student:design
# Processing item: ai:finer
# Processing item: ai:chatbot
# Processing item: ai:gam_changer
# Processing item: co:code
# Processing item: co:explainability
# Processing item: co:quality
# Processing item: co:socio-cultural
# Processing item: human:dhh
# Processing item: human:college_admission
# Processing item: co:collaboration:asynchronous
# Processing item: co:immersive
# Processing item: human:writer
# Processing item: co:dance
# Processing item: ai:tangible
# Processing item: co:encrypted
# Processing item: ai:defective_algorithm
# Processing item: ai:partner
# Processing item: ai:breadth-first
# Processing item: co-creation
# Processing item: human:non-tech
# Processing item: ai:writing
# Processing item: human:video_creator
# Processing item: co:google_play
# Processing item: ai:photo-steward
# Processing item: ai:non-personalized
# Processing item: human:women
# Processing item: human:clinician
# Processing item: co:query
# Processing item: co:ui
# Processing item: ai:gif
# Processing item: ai:experience-based
# Processing item: human:power-user
# Processing item: human:crowd_worker
# Processing item: co:human-ai
# Processing item: human:users
# Processing item: ai:gpt-creating
# Processing item: ai:optimization
# Processing item: co:object
# Processing item: ai:detector
# Processing item: ai:fitness
# Processing item: ai:transparent
# Processing item: awareness
# Processing item: co:resource-constrained
# Processing item: ai:expressedit
# Processing item: ai:hybrid
# Processing item: human:#perception:agent_voice
# Processing item: co:performance
# Processing item: ai:mindless
# Processing item: ai:tutorial
# Processing item: co:nlp
# Processing item: human:author
# Processing item: ai:cobot
# Processing item: ai:llm-based
# Processing item: co:automation
# Processing item: co:graph
# Processing item: human:annotator
# Processing item: idea
# Processing item: ai:xai
# Processing item: ai-enhanced
# Processing item: ai:algobo
# Processing item: co:outcome
# Processing item: ai:fashion
# Processing item: ai:model:improvement
# Processing item: human:non-expert
# Processing item: ai:generative
# Processing item: human:artist-client
# Processing item: co:literature
# Processing item: human:artist
# Processing item: co:information
# Processing item: ai:ml-assisted
# Processing item: co:workflowProcessing item: ai:soundwatch
#
# Processing item: co:scenario
# Processing item: co:interaction
# Processing item: co:domain
# Processing item: human:indian
# Processing item: human:surgeon
# Processing item: human:ml_practitioner
# Processing item: human:ai_professional
# Processing item: co:mixed-media
# Processing item: ai:voice
# Processing item: co:risks
# Processing item: human:owner
# Processing item: human:senior
# Processing item: co:haics
# Processing item: human:participants
# Processing item: co:symptom-disease
# Processing item: co:data
# Processing item: ai:stylette
# Processing item: co:knowledge
# Processing item: ai:recruitment
# Processing item: human:comic
# Processing item: ai:service
# Processing item: ai:part-based
# Processing item: co:educational
# Processing item: ai:luminate
# Processing item: co:interpretability
# Processing item: human:software-engineer
# Processing item: ai:intelligent
# Processing item: co:algorithmic
# Processing item: ai:roomdreaming
# Processing item: co:strategy
# Processing item: human:safety_driver
# Processing item: ai:dehazing
# Processing item: ai:game
# Processing item: ai:gpt
# Processing item: human:creative
# Processing item: ai:multimodal
# Processing item: ai:lloom
# Processing item: human:beginner
# Processing item: human:information_worker
# Processing item: co:alt_text
# Processing item: human:physician
# Processing item: human:analyst
# Processing item: ai:teaching
# Processing item: co:intercoder
# Processing item: co:xair
# Processing item: co:textual
# Processing item: human+ai
# Processing item: ai:text
# Processing item: human:user
# Processing item: ai:polyadic
# Processing item: ai:model
# Processing item: human:child
# Processing item: co:cooperative
# Processing item: co:bias
# Processing item: co:scaffolding
# Processing item: ai:machine
# Processing item: ai:metaphorical
# Processing item: human:community_health_workers
# Processing item: co:research
# Processing item: ai:rubicon
# Processing item: ai:detection:accuracy
# Processing item: ai:explainable
# Processing item: ai:behavior_tree
# Processing item: co:agency
# Processing item: documentation
# Processing item: ai:assistance
# Processing item: human:proposer
# Processing item: co:controllability
# Processing item: ai:grad-cam
# Processing item: co:consent
# Processing item: human:aligned
# Processing item: human:#utility
# Processing item: ai:computational
# Processing item: ai:matcha
# Processing item: human:judge
# Processing item: co:labeling
# Processing item: co:taxonomy
# Processing item: ai:dynamiclabels
# Processing item: ai:logic
# Processing item: co:hci
# Processing item: co:community
# Processing item: human:child:blind
# Processing item: human:coach
# Processing item: ai-generated
# Processing item: ai:embodied
# Processing item: ai:deepfuse
# Processing item: ai:powered
# Processing item: ai-cdss
# Processing item: human:security:operations
# Processing item: human:social_worker
# Processing item: ai:hearhere
# Processing item: ai:agent
# Processing item: co:cultural
# Processing item: co:3d_model
# Processing item: ai:carousel
# Processing item: co:annotation
# Processing item: ai:multi-task
# Processing item: human:stakeholder
# Processing item: human:expert
# Processing item: human:patient
# Processing item: co:keyframe
# Processing item: human:student
# Processing item: ai:level
# Processing item: human:enthusiast
# Processing item: ai:needsplanner
# Processing item: ai:patchview
# Processing item: co:initial
# Processing item: human:child_welfare
# Processing item: co:review
# Processing item: ai:deep_learning
# Processing item: co:prediction
# Processing item: co:social_event
# Processing item: human:men
# Processing item: ai:ml
# Processing item: ai:system
# Processing item: human:european_american_chinese
# Processing item: ai:large-language
# Processing item: co:legal
# Processing item: ai:simple
# Processing item: ai:pandalens
# Processing item: co:generational
# Processing item: human:#usefulness
# Processing item: human:#decision
# Processing item: ai:pre-trained_model
# Processing item: ai-augmentedProcessing item: ai:lipreading
#
# Processing item: ai:interpretability
# Processing item: co:guideline
# Processing item: co:subfloor
# Processing item: co:ethical
# Processing item: human:#estimate:ai_ability
# Processing item: robot
# Processing item: human:cnn-engineer
# Processing item: co:receptivity
# Processing item: human:mobile_learner
# Processing item: ai:nlp
# Processing item: human:speaker
# Processing item: co:subtitling
# Processing item: ai:batch
# Processing item: ai:ml-based
# Processing item: human:player
# Processing item: human:operator
# Processing item: co:toolkit
# Processing item: ai:escape
# Processing item: ai:snapper
# Processing item: co:resource
# Processing item: ai:implicature
# Processing item: co:hai
# Processing item: human:individual
# Processing item: human:older_adult
# Processing item: ai:conversational
# Processing item: ai:speech
# Processing item: co:robotics
# Processing item: ai:workplace
# Processing item: co:trust_scale
# Processing item: ai:gpt-3
# Processing item: ai:debiased
# Processing item: co:human-machine
# Processing item: ai:libpubl
# Processing item: human:decision-makers
# Processing item: ai-based
# Processing item: ai:assistant
# Processing item: ai:calliope
# Processing item: human:therapy
# Processing item: co:collaboration:future
# Processing item: ai:collaborative
# Processing item: co:organization
# Processing item: co:chains
# Processing item: ai:competencies
# Processing item: co:product_team
# Processing item: ai:photo
# Processing item: co:alarm
# Processing item: human:professional
# Processing item: ai:deeplens
# Processing item: co:management
# Processing item: co:syntax
# Processing item: ai:gnn
# Processing item: ai:large
# Processing item: ai:llm
# Processing item: co:trust
# Processing item: co:breakdown
# Processing item: human:teacher
# Processing item: human:storyteller
# Processing item: ai:algorithm
# Processing item: co:stylometry
# Processing item: co:banking
# Processing item: human:#misinformation:detection
# Processing item: ai:stepwise
# Processing item: co:collaborative
# Processing item: ai:voicemoji
# Processing item: ai:design
# Processing item: ai:classifier
# Processing item: co:stakeholder
# Processing item: ai:vision-language
# Processing item: ai:grounded
# Processing item: co:autocratic
# Processing item: co:challenges
# Processing item: co:llm
# Processing item: co:thinking
# Processing item: human:ux-practitioner
# Processing item: human:laypeople
# Processing item: ai:seamful
# Processing item: human:deaf
# Processing item: ai:promptcharm
# Processing item: co:search
# Processing item: ai:video
# Processing item: co:guidebook
# Processing item: co:system
# Processing item: ai:gancollage
# Processing item: human:dating_app_user
# Processing item: human:pathologist
# Processing item: human:ux_designer
# Processing item: co:news
# Processing item: human:ai_background
# Processing item: ai:to-human
# Processing item: ai:enhanced
# Processing item: human:#fairness
# Processing item: ai:visual
# Processing item: ai:clear
# Processing item: human:mentor
# Processing item: co:accuracy
# Processing item: ai:voice_recognition
# Processing item: human:defender
# Processing item: ai:conversation
# Processing item: co:3d:augmentation
# Processing item: human:musician
# Processing item: ai:temporal
# Processing item: co:team
# Processing item: co:sketch
# Processing item: ai:assembly
# Processing item: co
# Processing item: co:organizational
# Processing item: ai:reinforcement
# Processing item: co:diagnostic
# Processing item: ai:autochemplete
# Processing item: co:profile
# Processing item: co:simulated
# Processing item: ai:sam
# Processing item: human:novice
# Processing item: co:computation
# Processing item: human:medical
# Processing item: co:image
# Processing item: co:assessment
# Processing item: human:researcher
# Processing item: ai:smart
# Processing item: co:consistency
# Processing item: human:labeler
# Processing item: ai:support
# Processing item: ai:chatgpt
# Processing item: co:notebook
# Processing item: ai:proactive
# Processing item: ai:dynamic_audience_selection
# Processing item: ai:computer_vision
# Processing item: human:#ownership:ideas
# Processing item: co:regulation
# Processing item: co:product
# Processing item: ai:audilens
# Processing item: co:communication
# Processing item: human:#trust:ai-integrated
# Processing item: ai:time2stop
# Processing item: ai:sensecape
# Processing item: ai-assisted
# Processing item: co:social_media
# Processing item: co:social_computing
# Processing item: ai:marco
# Processing item: co:radiology
# Processing item: human:legal
# Processing item: co:delegation
# Processing item: human:#racial:bias
# Processing item: ai:mirror
# Processing item: co:visualization
# Processing item: ai:contrastive
# Processing item: co:video
# Processing item: ai:vivid
# Processing item: human:end_user
# Processing item: co:issues
# Processing item: co:ai
# Processing item: co:rsa
# Processing item: ai:assisted
# Processing item: human:older_adults
# Processing item: ai:text-to-image
# Processing item: ai:arimax
# Processing item: ai:gremobot
# Processing item: co:tutorial
# Processing item: ai:risk_assessment
# Processing item: human:non-power
# Processing item: ai:wellbeing
# Processing item: human:data_scientist
# Processing item: ai:sharp
# Processing item: ai:local
# Processing item: human:#transparency
# Processing item: ai:baseline
# Processing item: ai:narratron
# Processing item: human:engineer
# Processing item: co:haze
# Processing item: co:story
# Processing item: co:script
# Processing item: ai:web-based
# Processing item: ai:speech:gaze
# Processing item: human:#cooperativity
# Processing item: ai:social
# Processing item: ai:music
# Processing item: co:game
# Processing item: ai:credibility
# Processing item: ai:adatest++
# Processing item: ai:refinement
# Processing item: co:robot
# Processing item: ai-driven
# Processing item: human:amateur
# Processing item: human:decision-maker
# Processing item: co:confirmation
# Processing item: ai-embedded
# Processing item: human:audience
# Processing item: ai-powered
# Processing item: co:route
# Processing item: ai:llm-powered
# Processing item: ai:gp-tsm
# Processing item: co:decision
# Processing item: co:accessibility
# Processing item: human:worker
# Processing item: co:protocol
# Processing item: human:#collaboration
# Processing item: ai:trauma-informed
# Processing item: ai:recommendation
# Processing item: human:storywriter
# Processing item: ai:program
# Processing item: ai:bird_identification
# Processing item: ai:waitgpt
# Processing item: co:perspective
# Processing item: co:crowd
# Processing item: co:model_documentation
# Processing item: co:task
# Processing item: human
# Processing item: co:recommendations
# Processing item: co:patient
# Processing item: ai:artinter
# Processing item: ai
# Processing item: human:agreement
# Processing item: human:blind
# Processing item: human:young_adult
# Processing item: co:gameplay
# Processing item: ai:eval
# Processing item: co:alignment
# Processing item: co:cofi
# Processing item: co:teleoperation
# Processing item: ai:shap
# Processing item: ai:talkative
# Processing item: ai:proactiveagent
# Processing item: human:#performance
# Processing item: co:failure_modes
# Processing item: co:wellbeing_assessment
# Processing item: human:therapist
# Processing item: ai:ir-gan
# Processing item: co:self-voice
# Processing item: co:intervention
# Processing item: co:symbiosis
# Processing item: ai:forsense
# Processing item: ai:teachable
# Processing item: ai:self-voice
# Processing item: ai:self-diagnosis
# Processing item: human:executive
# Processing item: ai:wander
# Processing item: ai:cl
# Processing item: ai:interactive
# Processing item: ai:pcr-chain
# Processing item: ai:bias-aware
# Processing item: human:children
# Processing item: ai:fitvid
# Processing item: ai:reelframer
# Processing item: human:telenurse
# Processing item: ai:tool
# Processing item: ai:ensemble
# Processing item: co:mental_health
# Processing item: human:subject
# Processing item: co:version_control
# Processing item: ai:automated
# Processing item: co:ai_product
# Processing item: ai:driven
# Processing item: co:safety
# Processing item: ai:rule-based
# Processing item: human:chemist
# Processing item: co:gender
# Processing item: human:privacy
# Processing item: human:family
# Processing item: co:nearest-neighbor
# Processing item: co:control
# Processing item: ai:statistical
# Processing item: ai:cloud
# Processing item: ai:fact-checking
# Processing item: #trust:ai
# Processing item: ai:dermatologist
# Processing item: co:design
# Processing item: co:thought_bubbles
# Processing item: co:decision_making
# Processing item: human:optometrist
# Processing item: human:#trust
# Processing item: ai:gen
# Processing item: co:startup
# Processing item: human:driver
# Processing item: co:perception
# Processing item: human:healthcare
# Processing item: co:group
# Processing item: ai:creative
# Processing item: co:silly
# Processing item: ai:cass
# Processing item: co:engagement
# Processing item: human:#perception:partner_human
# Processing item: ai:open-ended
# Processing item: ai:evallm
# Processing item: ai:mix3d
# Processing item: co:correctness
# Processing item: co:ai-assisted
# Processing item: ai:find_my_things
# Processing item: ai:language
# Processing item: co:framework
# Processing item: human:journalist
# Processing item: human:low-performing
# Processing item: ai:empowered
# Processing item: ai:computer
# Processing item: ai:analogilead
# Processing item: human:icu
# Processing item: co:accountability
# Processing item: co:ux
# Processing item: co:marginalized_community
# Processing item: ai-enabled
# Processing item: ai:id.8
# Processing item: co:intrinsic
# Processing item: co:music
# Processing item: co:creation
# Processing item: co:expectation
# Processing item: co:therapy
# Processing item: human:african_american
# Processing item: human:high-performing
# Processing item: ai:safety-guaranteed
# Processing item: human:pilot
# Processing item: ai:transparency
# Processing item: ai:aar
# Processing item: co:icu
# Processing item: co:technique
# Processing item: ai:prompting
# Processing item: co:narrative
# Processing item: co:value_cards
# Processing item: ai:deepfake
# Processing item: ai:platform
# Processing item: ai:hint
# Processing item: ai:google_home
# Processing item: human:perception
# Processing item: co:operation
# Processing item: co:audio
# Processing item: human:lay
# Processing item: ai:gpt-4
# Processing item: ai:startups
# Processing item: human-model
# Processing item: ai:autonomous
# Processing item: human:hr
# Processing item: co:development
# Processing item: human:interviewer
# Processing item: ai:symptom
# Processing item: human:healthcare_provider
# Processing item: co:lgbtq
# Processing item: human:passenger
# Processing item: human:evaluator
# Processing item: ai:surgment
# Processing item: ai:peanut
# Processing item: ai:adaptive
# Processing item: co:computer-assisted

# %%
x = pd.DataFrame({k: str(embedding[k]) for k in embedding}, index=[0]).T
x.to_csv("result/embedding-triplets-keys.csv")

# %%
import ast

df2 = pd.read_csv('result/analyze.csv')
kw = [si.lower() for i in df2['keywords'].to_list() for si in ast.literal_eval(i) ]

kw_embedding = get_concurrent_embeddings(kw)
# Out:
# Processing item: theory of mindProcessing item: human-ai interaction
#
# Processing item: social intelligence
# Processing item: human-ai interaction
# Processing item: user experience
# Processing item: design guidelines
# Processing item: human-ai interaction
# Processing item: user values
# Processing item: prayer experiences
# Processing item: clinical decision-making
# Processing item: patient-centered care
# Processing item: ai interaction models
# Processing item: explainable ai
# Processing item: trust formation
# Processing item: human-ai interactions
# Processing item: user burden
# Processing item: sexual assault reporting
# Processing item: algorithmic evaluation resistance
# Processing item: appropriate trust
# Processing item: human-ai interaction
# Processing item: research opportunities
# Processing item: inclusivity
# Processing item: problem-solving diversity
# Processing item: demographic diversity
# Processing item: human-ai interaction
# Processing item: interaction paradigms
# Processing item: system design
# Processing item: human-ai interaction
# Processing item: user experience
# Processing item: music application
# Processing item: explainable ai
# Processing item: user needs
# Processing item: human-ai collaboration
# Processing item: placebo effect
# Processing item: user studies
# Processing item: artificial intelligence
# Processing item: mind perception
# Processing item: human-ai interaction
# Processing item: design solutions
# Processing item: ai systems understanding
# Processing item: game-based learning
# Processing item: user mental models
# Processing item: design guidelines
# Processing item: human-ai interaction
# Processing item: user interface design
# Processing item: ecological thinking
# Processing item: human-ai interactions
# Processing item: sustainable future
# Processing item: decision making
# Processing item: explainable ai
# Processing item: interface design
# Processing item: trust
# Processing item: human-ai interaction
# Processing item: scoping review
# Processing item: healthcare
# Processing item: mental health technologies
# Processing item: societal risks
# Processing item: large language models
# Processing item: task outcomes
# Processing item: system transparency
# Processing item: sports coaching
# Processing item: marathon prediction
# Processing item: user interaction
# Processing item: human-ai collaboration
# Processing item: social perceptions
# Processing item: cooperative games
# Processing item: conversational agents
# Processing item: social interactions
# Processing item: user experience
# Processing item: ai acceptance
# Processing item: ethics guidelines
# Processing item: human-ai interaction
# Processing item: decision support systems
# Processing item: output uncertainty
# Processing item: interactive design
# Processing item: co-creativity
# Processing item: user engagement
# Processing item: ai communication
# Processing item: online education
# Processing item: student perception
# Processing item: conversational agents
# Processing item: human-ai interaction
# Processing item: design challenges
# Processing item: user experience
# Processing item: human-in-the-loop
# Processing item: 3d model processing
# Processing item: user interaction
# Processing item: software architecture
# Processing item: ai-powered applications
# Processing item: bidirectional interaction
# Processing item: privacy concerns
# Processing item: user trust
# Processing item: personalized services
# Processing item: human resource management
# Processing item: employee perception
# Processing item: algorithmic management
# Processing item: human-robot interaction
# Processing item: task learning
# Processing item: behavior trees
# Processing item: ai design
# Processing item: metaphors
# Processing item: participatory design
# Processing item: daily goal achievement
# Processing item: voice alarm systems
# Processing item: behavioral change
# Processing item: human-ai teams
# Processing item: team performance
# Processing item: autonomy adaptation
# Processing item: older adults
# Processing item: cognitive impairment
# Processing item: human-ai interaction
# Processing item: user experience
# Processing item: financial services
# Processing item: ai interaction guidelines
# Processing item: generative ai
# Processing item: metacognition
# Processing item: usability challenges
# Processing item: human-ai teams
# Processing item: performance expectations
# Processing item: perception modeling
# Processing item: human-ai interaction
# Processing item: user behavior patterns
# Processing item: ai performance modalities
# Processing item: special education
# Processing item: ai learning
# Processing item: text-to-image interaction
# Processing item: trust development
# Processing item: human-ai interaction
# Processing item: decision-making
# Processing item: games
# Processing item: player-ai interaction
# Processing item: ux design
# Processing item: ai-empowered tools
# Processing item: creative processes
# Processing item: human-ai interaction
# Processing item: image clarity
# Processing item: haze type classification
# Processing item: dehazing algorithms
# Processing item: art therapy
# Processing item: ai in psychological assessment
# Processing item: user intention
# Processing item: autonomous vehicles
# Processing item: safety drivers
# Processing item: human-ai interaction
# Processing item: ai-based virtual assistants
# Processing item: ideation process
# Processing item: user perception
# Processing item: choreography
# Processing item: generative ai
# Processing item: dance prototyping
# Processing item: chess
# Processing item: human-ai interaction
# Processing item: predictive models
# Processing item: workplace ai integration
# Processing item: human-ai interaction
# Processing item: future of work
# Processing item: continuous interaction
# Processing item: user input
# Processing item: ai adaptation
# Processing item: design research
# Processing item: user experience
# Processing item: tangible ai
# Processing item: art-technology intersections
# Processing item: language taboos
# Processing item: censorship
# Processing item: error mitigation
# Processing item: user perception
# Processing item: ai apologies
# Processing item: trust
# Processing item: user perception
# Processing item: ai systems
# Processing item: self-care
# Processing item: generative ai
# Processing item: therapeutic self-expression
# Processing item: video editing
# Processing item: multimodal interfaces
# Processing item: efficiency
# Processing item: context-adaptive ai
# Processing item: user adoption
# Processing item: embodied agents
# Processing item: ai explanations
# Processing item: user-centered design
# Processing item: workplace integration
# Processing item: interactive system
# Processing item: text reliability
# Processing item: semantic variations
# Processing item: reading comprehension
# Processing item: text saliency
# Processing item: grammar-preserving
# Processing item: smart home
# Processing item: visual ai sensors
# Processing item: proactive actuation
# Processing item: generative ai
# Processing item: interactive computing
# Processing item: human-computer interaction
# Processing item: social sensemaking
# Processing item: blind assistance
# Processing item: design challenges
# Processing item: reading efficiency
# Processing item: text rendering
# Processing item: user experience
# Processing item: data analytics
# Processing item: mixed reality
# Processing item: decision-making
# Processing item: explainable ai
# Processing item: user empowerment
# Processing item: responsible ai
# Processing item: personalized assistance
# Processing item: context-aware recommendations
# Processing item: user decision-making
# Processing item: risk detection
# Processing item: explanation fidelity
# Processing item: malware analysis
# Processing item: research promotion
# Processing item: large language models
# Processing item: qa-style articles
# Processing item: teleoperation system
# Processing item: robotic boats
# Processing item: virtual reality
# Processing item: software development
# Processing item: user trust
# Processing item: community engagement
# Processing item: ai-assisted decision-making
# Processing item: human-ai collaboration
# Processing item: decision-maker behavior
# Processing item: healthcare
# Processing item: clinician acceptance
# Processing item: sepsis treatment
# Processing item: workplace stress
# Processing item: therapeutic art
# Processing item: emotion regulation
# Processing item: generative agents
# Processing item: interactive applications
# Processing item: believable behavior
# Processing item: ai-powered social computing
# Processing item: ethical frameworks
# Processing item: research collaboration
# Processing item: large language models
# Processing item: user trust
# Processing item: medical questions
# Processing item: cognitive enhancement
# Processing item: social dynamics
# Processing item: hybrid boardgames
# Processing item: creativity support
# Processing item: generative ai
# Processing item: design ideation
# Processing item: human-ai collaboration
# Processing item: decision-making
# Processing item: model uncertainty
# Processing item: older adults
# Processing item: music-based reminiscence
# Processing item: generative ai
# Processing item: language learning
# Processing item: immersive environments
# Processing item: cultural understanding
# Processing item: mixed-media tutorials
# Processing item: ai-assisted creation
# Processing item: cross-domain framework
# Processing item: digital banking
# Processing item: older adults
# Processing item: financial management
# Processing item: shared autonomy
# Processing item: autonomous driving
# Processing item: conflict situations
# Processing item: trust evaluation
# Processing item: software engineering
# Processing item: ai code generation
# Processing item: augmented reality
# Processing item: user experience
# Processing item: game design
# Processing item: data analysis
# Processing item: user interfaces
# Processing item: error detection
# Processing item: decision-making
# Processing item: ai explanations
# Processing item: intuition
# Processing item: traditional dance
# Processing item: choreography
# Processing item: cultural heritage
# Processing item: conversational recommender systems
# Processing item: trust metrics
# Processing item: user interaction
# Processing item: user experience
# Processing item: ai design guidelines
# Processing item: industry practitioners
# Processing item: image classification
# Processing item: text recommendation
# Processing item: user trust
# Processing item: writing feedback
# Processing item: ai personas
# Processing item: audience engagement
# Processing item: synthetic images
# Processing item: truthfulness perception
# Processing item: face generation
# Processing item: decision support tools
# Processing item: time pressure
# Processing item: human-ai collaboration
# Processing item: digital mementos
# Processing item: historical figures
# Processing item: learning effectiveness
# Processing item: learning by teaching
# Processing item: algorithm learning
# Processing item: teachable agents
# Processing item: emotional storytelling
# Processing item: generative ai
# Processing item: mindfulness
# Processing item: large language models
# Processing item: prototype refinement
# Processing item: model evaluation
# Processing item: science journalism
# Processing item: news discovery
# Processing item: user agency
# Processing item: artificial general intelligence
# Processing item: human-computer interaction
# Processing item: sociotechnical research
# Processing item: software engineering
# Processing item: conversation quality
# Processing item: evaluation technique
# Processing item: content perception
# Processing item: user satisfaction
# Processing item: ai-assisted creation
# Processing item: diabetes care
# Processing item: end user engagement
# Processing item: computational notebooks
# Processing item: generative ai
# Processing item: design
# Processing item: multimodal prompts
# Processing item: trust
# Processing item: computer vision
# Processing item: end-user interaction
# Processing item: radiology
# Processing item: vision-language models
# Processing item: clinical utility
# Processing item: creativity support tools
# Processing item: generative ai models
# Processing item: design space exploration
# Processing item: language learning
# Processing item: game-based learning
# Processing item: ai-driven characters
# Processing item: data analysis programming
# Processing item: user control
# Processing item: ai-assisted tools
# Processing item: ai-assisted decision making
# Processing item: group dynamics
# Processing item: fairness in ai
# Processing item: visual art commission
# Processing item: ai-powered collaboration
# Processing item: artistic communication
# Processing item: recommender systems
# Processing item: user understanding
# Processing item: explanation approaches
# Processing item: decision-making
# Processing item: intrinsic motivation
# Processing item: ai decision support
# Processing item: ai writing tools
# Processing item: design theory
# Processing item: literary concepts
# Processing item: human-ai interaction
# Processing item: design patterns
# Processing item: information exchange
# Processing item: conversational agents
# Processing item: social manipulation
# Processing item: generative ai
# Processing item: mental health
# Processing item: patient engagement
# Processing item: stakeholder collaboration
# Processing item: music synthesis
# Processing item: human-in-the-loop
# Processing item: artistic creativity
# Processing item: healthcare
# Processing item: optometry
# Processing item: clinical decision support
# Processing item: knowledge transfer
# Processing item: machine learning
# Processing item: organizational context
# Processing item: concept induction
# Processing item: text analysis
# Processing item: data coverage
# Processing item: algorithmic bias
# Processing item: text classification
# Processing item: fairness evaluation
# Processing item: large language models
# Processing item: personal assistant
# Processing item: goal achievement
# Processing item: distributive fairness
# Processing item: ai-assisted decisions
# Processing item: feature-based explanations
# Processing item: ai-assisted decision-making
# Processing item: eye gaze analysis
# Processing item: human-ai team performance
# Processing item: design fiction
# Processing item: ai creativity support
# Processing item: future speculation
# Processing item: human-computer interaction
# Processing item: human factors engineering
# Processing item: ai challenges
# Processing item: moral consideration
# Processing item: ai features
# Processing item: human-computer interaction
# Processing item: fact-checking
# Processing item: explainable ai
# Processing item: user behavior
# Processing item: game design
# Processing item: player mental models
# Processing item: adversarial ai
# Processing item: data analysis
# Processing item: ai assistance
# Processing item: verification
# Processing item: smart speakers
# Processing item: emergent users
# Processing item: user preferences
# Processing item: group decision making
# Processing item: ai assistance
# Processing item: devil's advocate
# Processing item: creative processes
# Processing item: design space exploration
# Processing item: professional writing
# Processing item: xr
# Processing item: ai-enabled experiences
# Processing item: future vision
# Processing item: critical thinking
# Processing item: ai-framed questioning
# Processing item: logical validity
# Processing item: recruitment bots
# Processing item: user experience
# Processing item: human-centered design
# Processing item: human identity
# Processing item: technology perception
# Processing item: ai interaction
# Processing item: criminal justice reform
# Processing item: recidivism risk assessment
# Processing item: organizational resistance
# Processing item: wellbeing
# Processing item: workplace
# Processing item: machine teaching
# Processing item: customer support
# Processing item: machine teaching
# Processing item: chatbot interaction
# Processing item: explainable ai
# Processing item: user-adaptive features
# Processing item: in-vehicle systems
# Processing item: watch-based human activity recognition
# Processing item: procedure tracking
# Processing item: human-in-the-loop systems
# Processing item: robotics
# Processing item: natural interaction
# Processing item: task parameters
# Processing item: human-likeness
# Processing item: 3d video game
# Processing item: turing test
# Processing item: healthcare
# Processing item: patient assessment
# Processing item: human-ai collaboration
# Processing item: music generation
# Processing item: deep learning
# Processing item: audience satisfaction
# Processing item: code generation
# Processing item: data analysis
# Processing item: user understanding
# Processing item: ride-pooling
# Processing item: passenger experience
# Processing item: human-centered design
# Processing item: creative writing
# Processing item: language models
# Processing item: writing support
# Processing item: social media
# Processing item: misinformation
# Processing item: credibility indicators
# Processing item: human–ai co-creation
# Processing item: learning supports
# Processing item: text-to-image models
# Processing item: emergency rooms
# Processing item: decision accuracy
# Processing item: time pressure
# Processing item: historical photographs
# Processing item: facial recognition
# Processing item: crowdsourcing
# Processing item: recommender systems
# Processing item: value sensitive design
# Processing item: human-centric design
# Processing item: trust in ai
# Processing item: communication theories
# Processing item: user trust judgments
# Processing item: human-ai interaction
# Processing item: generative models
# Processing item: perceived authorship
# Processing item: accessibility
# Processing item: alt text
# Processing item: scientific figures
# Processing item: informed consent
# Processing item: online studies
# Processing item: ai chatbot
# Processing item: decision-making
# Processing item: bias mitigation
# Processing item: college admissions
# Processing item: retail technology
# Processing item: fashion consulting
# Processing item: user experience
# Processing item: oil spill detection
# Processing item: crowd knowledge
# Processing item: human-ai collaboration
# Processing item: crowdsourcing
# Processing item: machine learning
# Processing item: trust building
# Processing item: machine translation
# Processing item: cross-lingual communication
# Processing item: quality assessment
# Processing item: personal autonomy
# Processing item: user experience
# Processing item: privacy concerns
# Processing item: facial recognition
# Processing item: ethical design
# Processing item: ai literacy
# Processing item: ai user experience
# Processing item: end-user design
# Processing item: recommender systems
# Processing item: large language models
# Processing item: information tasks
# Processing item: sensemaking
# Processing item: automotive adaptivity
# Processing item: driver-vehicle interaction
# Processing item: human factors challenges
# Processing item: trust in ai
# Processing item: public speaking anxiety
# Processing item: human-ai partnership
# Processing item: ai-assisted decision-making
# Processing item: heuristics
# Processing item: model performance feedback
# Processing item: accountability
# Processing item: fintech
# Processing item: global south
# Processing item: expressive arts therapy
# Processing item: family communication
# Processing item: generative ai
# Processing item: ai prototyping
# Processing item: natural language technologies
# Processing item: user experience design
# Processing item: legal advice
# Processing item: llm response strategies
# Processing item: ethical considerations
# Processing item: machine learning
# Processing item: decision-making
# Processing item: covariate shift
# Processing item: machine learning literacy
# Processing item: user tutorials
# Processing item: decision-making
# Processing item: ai blindspots
# Processing item: systematic errors
# Processing item: visual analytics
# Processing item: trust development
# Processing item: system accuracy
# Processing item: user interaction
# Processing item: healthcare
# Processing item: ai in clinical practice
# Processing item: human-ai collaboration
# Processing item: writing assistants
# Processing item: interdisciplinary workshop
# Processing item: dark sides
# Processing item: machine learning uncertainty
# Processing item: user understanding
# Processing item: classifier training
# Processing item: clinical support systems
# Processing item: endoscopic assessment
# Processing item: ai recommendations
# Processing item: fairness perceptions
# Processing item: ai-based decision systems
# Processing item: loan lending
# Processing item: smart home automation
# Processing item: remote caregiver monitoring
# Processing item: explainable ai
# Processing item: sketch recognition
# Processing item: novice users
# Processing item: interactive machine learning
# Processing item: human-ai collaboration
# Processing item: authorship
# Processing item: psychological ownership
# Processing item: human behavior
# Processing item: decision-making
# Processing item: economic expectations
# Processing item: cooperative games
# Processing item: human performance
# Processing item: ai limitations
# Processing item: spatial awareness
# Processing item: team cognition
# Processing item: emergency response
# Processing item: explainable ai
# Processing item: user-centered design
# Processing item: design practices
# Processing item: augmented reality
# Processing item: mathematics education
# Processing item: child engagement
# Processing item: data analysis
# Processing item: ai assistants
# Processing item: decision making
# Processing item: user agency
# Processing item: personalization
# Processing item: teaching-learning interaction
# Processing item: ai grading
# Processing item: learning impacts
# Processing item: feedback mechanisms
# Processing item: medical diagnostics
# Processing item: ai transparency
# Processing item: human-ai collaboration
# Processing item: aviation
# Processing item: decision making
# Processing item: trust calibration
# Processing item: music co-creation
# Processing item: user experience
# Processing item: ai tools
# Processing item: human-ai collaboration
# Processing item: personalization
# Processing item: user control
# Processing item: interactive fiction
# Processing item: narrative ai
# Processing item: defamiliarization
# Processing item: conversational agents
# Processing item: crowdsourcing
# Processing item: worker engagement
# Processing item: ai writing companions
# Processing item: human-ai co-writing
# Processing item: storywriting
# Processing item: value similarity
# Processing item: trust
# Processing item: decision making
# Processing item: explainable ai
# Processing item: social transparency
# Processing item: decision-making
# Processing item: explainable ai
# Processing item: sociotechnical gap
# Processing item: framework application
# Processing item: social ai
# Processing item: ubiquitous computing
# Processing item: human interaction
# Processing item: intelligent assistants
# Processing item: user experience
# Processing item: transparency
# Processing item: medical imaging
# Processing item: diagnostic utility
# Processing item: human-ml collaboration
# Processing item: social networking
# Processing item: audience selection
# Processing item: privacy concerns
# Processing item: autonomous agents
# Processing item: social norms
# Processing item: rule systems
# Processing item: explainable ai
# Processing item: image classification
# Processing item: user evaluation
# Processing item: creative expression
# Processing item: ai collaboration
# Processing item: game design
# Processing item: online review communities
# Processing item: content moderation
# Processing item: algorithm interaction
# Processing item: writing assistants
# Processing item: large language models
# Processing item: interdisciplinary workshop
# Processing item: rehabilitation
# Processing item: explainable ai
# Processing item: stroke recovery
# Processing item: software engineering
# Processing item: student support
# Processing item: human-ai interaction
# Processing item: generative ai
# Processing item: graphical user interfaces
# Processing item: creativity
# Processing item: ai clones
# Processing item: identity abuse
# Processing item: interpersonal relationships
# Processing item: machine learning
# Processing item: active learning
# Processing item: ai explanations
# Processing item: clinical decision support
# Processing item: therapist assessment
# Processing item: reinforcement learning
# Processing item: sustainability
# Processing item: carbon neutrality
# Processing item: human-centered tools
# Processing item: community interaction
# Processing item: ai-led decisions
# Processing item: explainable ai
# Processing item: machine learning explanations
# Processing item: user perception
# Processing item: visual domain
# Processing item: ai roles
# Processing item: perceptions
# Processing item: human involvement
# Processing item: human-ai teaming
# Processing item: perceived cooperativity
# Processing item: teaming perception
# Processing item: education
# Processing item: student perceptions
# Processing item: automated grading
# Processing item: sound design
# Processing item: generative ai
# Processing item: creative support tools
# Processing item: schizophrenia
# Processing item: relapse prediction
# Processing item: patient collaboration
# Processing item: trust in ai
# Processing item: embodied ai
# Processing item: human-ai interaction
# Processing item: user experience
# Processing item: creative collaboration
# Processing item: ai interface
# Processing item: social media
# Processing item: peer support
# Processing item: young people
# Processing item: rehabilitation
# Processing item: machine learning
# Processing item: personalized assessment
# Processing item: digital assistants
# Processing item: user interaction
# Processing item: conversational grounding
# Processing item: transparency
# Processing item: deep reinforcement learning
# Processing item: object recognition
# Processing item: explainable ai
# Processing item: human-ai interaction
# Processing item: image classification
# Processing item: software engineering
# Processing item: human-ai collaboration
# Processing item: code efficiency
# Processing item: user experience
# Processing item: playfulness
# Processing item: human-ai interaction
# Processing item: higher education
# Processing item: algorithm aversion
# Processing item: course credit equivalency
# Processing item: human-ai interaction
# Processing item: team dynamics
# Processing item: collaborative games
# Processing item: rehabilitation assessment
# Processing item: therapist collaboration
# Processing item: decision support
# Processing item: business applications
# Processing item: ai explainability
# Processing item: user understanding
# Processing item: hci history
# Processing item: human augmentation
# Processing item: inclusive design
# Processing item: conversational agents
# Processing item: empathy
# Processing item: large language models
# Processing item: clinical practice
# Processing item: ai challenges
# Processing item: human-centred ai
# Processing item: social design features
# Processing item: gender effects
# Processing item: task load conditions
# Processing item: unfair treatment
# Processing item: group dynamics
# Processing item: cooking context
# Processing item: augmented reality
# Processing item: ai-powered technologies
# Processing item: computer vision
# Processing item: collaborative decision-making
# Processing item: subjective contexts
# Processing item: subtle sexism
# Processing item: commonsense reasoning
# Processing item: explanatory dialogue
# Processing item: child development
# Processing item: co-creative systems
# Processing item: hackathon design
# Processing item: fast design thinking
# Processing item: survey methods
# Processing item: response quality
# Processing item: conversational interactivity
# Processing item: transparency
# Processing item: explainable ai
# Processing item: inclusivity
# Processing item: human-robot interaction
# Processing item: power dynamics
# Processing item: decision-making
# Processing item: human-ai collaboration
# Processing item: social perceptions
# Processing item: game interaction
# Processing item: trust development
# Processing item: ai system interaction
# Processing item: model accuracy
# Processing item: computer vision
# Processing item: social behaviors
# Processing item: human-ai interaction
# Processing item: user interfaces
# Processing item: machine learning
# Processing item: virtual reality
# Processing item: procedural content generation
# Processing item: co-creative systems
# Processing item: transfer learning
# Processing item: human-ai trust
# Processing item: interdisciplinary collaboration
# Processing item: trust measurement
# Processing item: ai authority
# Processing item: user attitudes
# Processing item: india
# Processing item: dating apps
# Processing item: sexual consent
# Processing item: lgbtqia+
# Processing item: online videos
# Processing item: ai music generation
# Processing item: creative practice
# Processing item: large language models
# Processing item: user interfaces
# Processing item: human-ai interaction
# Processing item: chatbot architecture
# Processing item: social support
# Processing item: community engagement
# Processing item: clinical decision support systems
# Processing item: rural healthcare
# Processing item: human-ai collaboration
# Processing item: explainability
# Processing item: human-centered design
# Processing item: operationalization
# Processing item: conversational agents
# Processing item: user experience
# Processing item: design guidelines
# Processing item: 3d pointing
# Processing item: real-time operation
# Processing item: personal usage applications
# Processing item: ai transparency
# Processing item: misinformation
# Processing item: media sector
# Processing item: human-ai collaboration
# Processing item: advanced visual interfaces
# Processing item: ethical dimensions
# Processing item: trust calibration
# Processing item: integrity explanations
# Processing item: ai agent
# Processing item: ai collaboration
# Processing item: human skill development
# Processing item: trust and reliance
# Processing item: symbiotic ai
# Processing item: human-centered design
# Processing item: user safety
# Processing item: software development
# Processing item: programmer productivity
# Processing item: code quality
# Processing item: cultural diversity
# Processing item: ai preferences
# Processing item: culturally responsive ai
# Processing item: ai explanations
# Processing item: human trust
# Processing item: team effectiveness
# Processing item: end-of-life planning
# Processing item: legacy
# Processing item: socio-technical practices
# Processing item: design collaboration
# Processing item: ai for design
# Processing item: creative augmentation
# Processing item: real estate investment
# Processing item: data visualization
# Processing item: time series analysis
# Processing item: trust calibration
# Processing item: human-ai collaboration
# Processing item: decision-making
# Processing item: project-based learning
# Processing item: ai usage data
# Processing item: student assessment
# Processing item: data narratives
# Processing item: racial justiceProcessing item: participatory action research
#
# Processing item: generative ai
# Processing item: design principles
# Processing item: user experience
# Processing item: electronic music
# Processing item: generative ai
# Processing item: music composition
# Processing item: public sector
# Processing item: ai procurement
# Processing item: regulatable systems
# Processing item: workplace
# Processing item: ethical design
# Processing item: ai-driven personal assistants
# Processing item: explainability
# Processing item: large language models
# Processing item: human-centered perspective
# Processing item: conversational user interfaces
# Processing item: trust and reliance
# Processing item: human-computer interaction
# Processing item: productivity
# Processing item: user experience
# Processing item: learning outcomes
# Processing item: visual storytelling
# Processing item: content creation
# Processing item: generative ai
# Processing item: llm evaluation
# Processing item: human-centered methods
# Processing item: stakeholder needs
# Processing item: human-ai teaming
# Processing item: simulated task environment
# Processing item: protocol development
# Processing item: higher education
# Processing item: chatgpt usage
# Processing item: student learning
# Processing item: ai systems
# Processing item: decision making
# Processing item: cognitive biases
# Processing item: sepsis diagnosis
# Processing item: clinical decision support
# Processing item: human-ai collaboration
# Processing item: human-machine teaming
# Processing item: radiology training
# Processing item: mutual learning
# Processing item: driver situation awareness
# Processing item: adaptive feedback
# Processing item: advanced driver assistance
# Processing item: ai-assisted writing
# Processing item: travel experience
# Processing item: user effort reduction
# Processing item: education
# Processing item: physics
# Processing item: student engagement
# Processing item: climate change
# Processing item: smart buildings
# Processing item: human-data interactions
# Processing item: machine learning tools
# Processing item: usability heuristics
# Processing item: novice users
# Processing item: cognitive biases
# Processing item: human-ai collaboration
# Processing item: bias mitigation
# Processing item: human-ai trust
# Processing item: decision-making
# Processing item: stakeholder influence
# Processing item: job satisfaction
# Processing item: human-ai collaboration
# Processing item: work meaningfulness
# Processing item: self-assessment
# Processing item: trust perception
# Processing item: ai dermatologist
# Processing item: design workflow
# Processing item: ai technology
# Processing item: foundation models
# Processing item: human-centered ai
# Processing item: creative learning
# Processing item: inclusive education
# Processing item: medical applications
# Processing item: clinician-facing systems
# Processing item: sociotechnical challenges
# Processing item: mobile sound recognition
# Processing item: deaf and hard of hearing
# Processing item: environmental awareness
# Processing item: generative ai
# Processing item: hci research
# Processing item: ethical considerations
# Processing item: privacy concerns
# Processing item: large language models
# Processing item: human-centered research
# Processing item: ai-assisted decision making
# Processing item: dunning-kruger effect
# Processing item: user cognitive biases
# Processing item: explainable ai
# Processing item: user needs
# Processing item: art historians
# Processing item: moral agents
# Processing item: behavior change
# Processing item: social and environmental sustainability
# Processing item: ai explanations
# Processing item: human decision making
# Processing item: cognitive interaction
# Processing item: human trust
# Processing item: ai-assisted decision making
# Processing item: experimental protocols
# Processing item: enterprise applications
# Processing item: ux improvement
# Processing item: ai innovation
# Processing item: incidental learning
# Processing item: nutritional decisions
# Processing item: ai explanations
# Processing item: young professionals
# Processing item: productivity perception
# Processing item: task suitability
# Processing item: child welfare
# Processing item: algorithmic decision-making
# Processing item: professional practice
# Processing item: digital agents
# Processing item: older adults
# Processing item: activity engagement
# Processing item: collaboration
# Processing item: productivity
# Processing item: remote work
# Processing item: public speaking
# Processing item: audience simulation
# Processing item: speech practice
# Processing item: ai development
# Processing item: human-centered approach
# Processing item: ai safety
# Processing item: technology design
# Processing item: policy integration
# Processing item: societal impactsProcessing item: ai transparency
#
# Processing item: ai explainability
# Processing item: trust in ai
# Processing item: human-ai teams
# Processing item: decision making
# Processing item: team efficacy
# Processing item: cultures of participation
# Processing item: human-centered design
# Processing item: ai systems
# Processing item: user trust
# Processing item: collaborative performance
# Processing item: outcome feedback
# Processing item: explainability
# Processing item: user perceptions
# Processing item: trust manipulation
# Processing item: games
# Processing item: visual question & answering
# Processing item: player experience
# Processing item: human robot interaction
# Processing item: theory of mind
# Processing item: perceived behavior recognition
# Processing item: explainable ai
# Processing item: tangible user interfaces
# Processing item: data physicalization
# Processing item: design education
# Processing item: ai curriculum
# Processing item: design challenges
# Processing item: ai in legal system
# Processing item: public defense
# Processing item: contestability
# Processing item: dance movement analysis
# Processing item: video processing
# Processing item: artistic expression
# Processing item: robot learning
# Processing item: user experience
# Processing item: learning engagement
# Processing item: computational notebooks
# Processing item: hci research
# Processing item: interface design
# Processing item: conversational agents
# Processing item: user trust
# Processing item: lexical alignment
# Processing item: scientific process
# Processing item: large language models
# Processing item: co-creation
# Processing item: foundation models
# Processing item: participatory governance
# Processing item: equitable systems
# Processing item: k-12 education
# Processing item: collaboration skills
# Processing item: ai literacy
# Processing item: user expectations
# Processing item: placebo effect
# Processing item: interactive systems
# Processing item: ai ethics
# Processing item: human-ai teaming
# Processing item: policy development
# Processing item: transparency
# Processing item: explainability
# Processing item: personalized systems
# Processing item: education
# Processing item: reading comprehension
# Processing item: instructor tools
# Processing item: stem education
# Processing item: accessibility
# Processing item: chemical annotation
# Processing item: robotics
# Processing item: large language models
# Processing item: human-robot interaction
# Processing item: social robots
# Processing item: senior well-being
# Processing item: empathy
# Processing item: text-to-image ai
# Processing item: user experience
# Processing item: prompt crafting
# Processing item: ai ethics
# Processing item: data visualization
# Processing item: ethical literacy
# Processing item: human-computer interaction
# Processing item: dialectical activities
# Processing item: computational ecosystems
# Processing item: synthetic chemistry
# Processing item: retrosynthetic route planning
# Processing item: human-ai collaboration
# Processing item: social influence
# Processing item: behavioral adaptation
# Processing item: human-ai teams
# Processing item: software development
# Processing item: problem resolution
# Processing item: prompt effectiveness
# Processing item: conflict resolution
# Processing item: automation
# Processing item: machine learning
# Processing item: human-ai collaboration
# Processing item: job automation
# Processing item: deep learning
# Processing item: user-centered design
# Processing item: middle-aged demographic
# Processing item: ai expectations
# Processing item: lgbtqia+ advocacy
# Processing item: ai simulations
# Processing item: social interactions
# Processing item: content creation
# Processing item: media consumption
# Processing item: interactive ai systems
# Processing item: human-centered ai
# Processing item: ai development practices
# Processing item: user requirements
# Processing item: neural language models
# Processing item: user experience
# Processing item: writing interfaces
# Processing item: ai design
# Processing item: wellbeing
# Processing item: interpersonal variations
# Processing item: human-ai decision making
# Processing item: empirical research
# Processing item: study design
# Processing item: student trust
# Processing item: ai bias
# Processing item: educational technology
# Processing item: ai art
# Processing item: creative practices
# Processing item: ethical tensions
# Processing item: explainable ai
# Processing item: large language models
# Processing item: human-centered design
# Processing item: physiological signals
# Processing item: interactive systems
# Processing item: cross-disciplinary discussions
# Processing item: human-ai teaming
# Processing item: human-centered ai
# Processing item: joint cognitive systems
# Processing item: internet of things
# Processing item: user interfaces
# Processing item: privacy and control
# Processing item: generative ai
# Processing item: human creativity
# Processing item: interface design
# Processing item: shadow puppetry
# Processing item: creative storytelling
# Processing item: multi-modal interaction
# Processing item: chatbot model
# Processing item: semantic awareness
# Processing item: response selection
# Processing item: healthcare
# Processing item: medical authority
# Processing item: ai-enabled health technology
# Processing item: explainable ai
# Processing item: user interfaces
# Processing item: data physicalization
# Processing item: email management
# Processing item: ai-powered reminders
# Processing item: asynchronous collaboration
# Processing item: voice user interfaces
# Processing item: hci education
# Processing item: design training
# Processing item: human-ai collaboration
# Processing item: large language models
# Processing item: temporal characteristics
# Processing item: explainable ai
# Processing item: digital arts
# Processing item: human-centred ai
# Processing item: human-autonomy teams
# Processing item: integration
# Processing item: applied industries
# Processing item: virtual reality
# Processing item: emotional engagement
# Processing item: therapy sessions
# Processing item: creative co-production
# Processing item: generative ai
# Processing item: text primacy
# Processing item: online information-seeking
# Processing item: user engagement
# Processing item: cognitive load reduction
# Processing item: algorithm aversion
# Processing item: decision-making
# Processing item: user control
# Processing item: ai competencies
# Processing item: undergraduate education
# Processing item: non-computer science students
# Processing item: gift shopping
# Processing item: fashion recommender systems
# Processing item: cold-start scenarios
# Processing item: educational ecosystem
# Processing item: career prospects
# Processing item: ethical regulations
# Processing item: critical care medicine
# Processing item: ai concept ideation
# Processing item: multidisciplinary collaboration
# Processing item: role-taking
# Processing item: participatory co-design
# Processing item: social hierarchies
# Processing item: role-taking
# Processing item: participatory co-design
# Processing item: social hierarchies
# Processing item: music therapy
# Processing item: musical ai
# Processing item: therapeutic applications
# Processing item: appropriate trust
# Processing item: human-centred ai design
# Processing item: design workshops
# Processing item: error detection
# Processing item: user interaction
# Processing item: ai system design
# Processing item: adversarial operations
# Processing item: resource allocation
# Processing item: strategy discovery
# Processing item: ux design
# Processing item: machine learning
# Processing item: user interfaces
# Processing item: crowdsourcing
# Processing item: skill improvement
# Processing item: ai co-learning
# Processing item: user experience design
# Processing item: creative professionals
# Processing item: ai collaboration
# Processing item: system administration
# Processing item: ai transparency
# Processing item: it security
# Processing item: human-ai teaming
# Processing item: decision-making
# Processing item: agile methodology
# Processing item: healthcare
# Processing item: clinical decision-making
# Processing item: adaptive communication
# Processing item: healthcare
# Processing item: covid-19
# Processing item: machine learning
# Processing item: creative problem solving
# Processing item: ai opportunity detection
# Processing item: co-creation workshops
# Processing item: text-to-image ai
# Processing item: creative workflows
# Processing item: multimodal interactions
# Processing item: party games
# Processing item: user engagement
# Processing item: playfulness
# Processing item: literacy development
# Processing item: creative expression
# Processing item: generative ai
# Processing item: critical infrastructure
# Processing item: human-machine collaboration
# Processing item: debris collection
# Processing item: smartphone overuse
# Processing item: adaptive interventions
# Processing item: user trust
# Processing item: knowledge work
# Processing item: sensemaking
# Processing item: document analysis
# Processing item: ai biases
# Processing item: explainable ai (xai)
# Processing item: user trust
# Processing item: bipolar disorder
# Processing item: suicidality prediction
# Processing item: social media analysis
# Processing item: social inclusion
# Processing item: cultural heritage
# Processing item: digital storytelling
# Processing item: code reuse
# Processing item: syntax error resolution
# Processing item: programming tasks
# Processing item: design fixation
# Processing item: human-robot interaction
# Processing item: creative ai tools
# Processing item: language models
# Processing item: user interaction
# Processing item: prompt design
# Processing item: generative ai
# Processing item: human-centered design
# Processing item: creative collaboration
# Processing item: human-ai co-creativity
# Processing item: interaction design
# Processing item: co-creative systems
# Processing item: carousel interfaces
# Processing item: recommendation systems
# Processing item: navigability
# Processing item: responsibility attribution
# Processing item: artificial autonomous agents
# Processing item: causal framework
# Processing item: ai recruitment
# Processing item: hiring practices
# Processing item: participatory design
# Processing item: social computing education
# Processing item: curriculum development
# Processing item: interdisciplinary skills
# Processing item: voice assistants
# Processing item: privacy concerns
# Processing item: ethical research
# Processing item: explainability
# Processing item: cognitive process
# Processing item: user metrics
# Processing item: affective computing
# Processing item: empathy measurement
# Processing item: interactive systems
# Processing item: public perceptions
# Processing item: cultural context
# Processing item: ai attitudes
# Processing item: climate change
# Processing item: generative ai
# Processing item: future scenarios
# Processing item: generative ai
# Processing item: creative domains
# Processing item: human-ai co-creation
# Processing item: ai design
# Processing item: innovation
# Processing item: problem-solution space
# Processing item: cs education
# Processing item: student trust
# Processing item: generative ai
# Processing item: generative ai
# Processing item: text-to-image generation
# Processing item: user experience
# Processing item: investment apps
# Processing item: user behavior
# Processing item: design guidelines
# Processing item: nlp model analysis
# Processing item: practitioner tools
# Processing item: counterfactual generation
# Processing item: responsible ai
# Processing item: ethical principles
# Processing item: system lifecycle
# Processing item: social interactions
# Processing item: agent representation
# Processing item: user autonomy
# Processing item: hospitality
# Processing item: service robots
# Processing item: guest experience
# Processing item: local government
# Processing item: public interest technology
# Processing item: community engagement
# Processing item: scientific thinking
# Processing item: intelligence
# Processing item: robot collections
# Processing item: user interaction
# Processing item: design features
# Processing item: social perception
# Processing item: moral responsibility
# Processing item: industrial setting
# Processing item: conversational agents
# Processing item: medical diagnosis
# Processing item: natural language processing
# Processing item: creative expression
# Processing item: emotional nuances
# Processing item: human-machine interaction
# Processing item: music composition
# Processing item: user agency
# Processing item: semantic control
# Processing item: human-ai decision-making
# Processing item: overreliance
# Processing item: cognitive effort discounting
# Processing item: ai transparency
# Processing item: application categories
# Processing item: automation level
# Processing item: autonomous driving
# Processing item: user experience
# Processing item: system transparency
# Processing item: trust measurement
# Processing item: psychometric evaluation
# Processing item: ai interaction
# Processing item: ai literacy
# Processing item: k-12 education
# Processing item: public policy
# Processing item: behavioral models
# Processing item: economics
# Processing item: computer science
# Processing item: interactive machine teaching
# ...
# Processing item: user preferences
# Processing item: mutual aid
# Processing item: gift economy
# Processing item: community assets
# Processing item: lgbtq+ research
# Processing item: hci
# Processing item: social justice
# Processing item: attention management
# Processing item: multitasking
# Processing item: human performance
# Processing item: language models
# Processing item: bias auditing
# Processing item: human-ai collaboration
# Processing item: batch labeling
# Processing item: data labeling efficiency
# Processing item: mechanical turk
# Processing item: complexity methods
# Processing item: human behavior
# Processing item: cognitive science
# Processing item: clinical decision support
# Processing item: large language models
# Processing item: trust
# Processing item: machine learning
# Processing item: natural language processing
# Processing item: out-of-distribution detection
# Processing item: education
# Processing item: learning
# Processing item: dialogue design
# Processing item: legal professionals
# Processing item: user behavior
# Processing item: ai-enabled tools
# Processing item: humor recognition
# Processing item: personalization
# Processing item: federated learning
# Processing item: machine learning
# Processing item: social and ethical risks
# Processing item: safety engineering
# Processing item: organizational knowledge
# Processing item: collaborative actions
# Processing item: technological innovation
# Processing item: ai startups
# Processing item: ethical ai policies
# Processing item: data access
# Processing item: mobile health
# Processing item: user engagement
# Processing item: self-monitoring
# Processing item: user experience
# Processing item: social design
# Processing item: automated systems
# Processing item: cognitive development
# Processing item: ai training
# Processing item: reinforcement learning
# Processing item: ai-assisted decision-making
# Processing item: critical use
# Processing item: social decision-making
# Processing item: conversational ux design
# Processing item: multi-channel service environments
# Processing item: collaborative work
# Processing item: autonomous vehicles
# Processing item: ai cab driver
# Processing item: speculative technology
# Processing item: ethics education
# Processing item: curriculum integration
# Processing item: responsible computing
# Processing item: adhd
# Processing item: hyperactivity detection
# Processing item: mobile sensing
# Processing item: human-ai collaboration
# Processing item: teamwork
# Processing item: multiplayer online games
# Processing item: adaptive interventions
# Processing item: visualization literacy
# Processing item: comprehension enhancement
# Processing item: patient preferences
# Processing item: ai autonomy
# Processing item: healthcare decision making
# Processing item: healthcare
# Processing item: community health workers
# Processing item: rural india
# Processing item: smartphone addiction
# Processing item: focus improvement
# Processing item: behavioral change
# Processing item: generative adversarial networks
# Processing item: image editing
# Processing item: creative work
# Processing item: fair ai
# Processing item: gender bias
# Processing item: user acceptance
# Processing item: human-robot collaboration
# Processing item: cscw
# Processing item: robotics research
# Processing item: explainable ai
# Processing item: human trust
# Processing item: ai model errors
# Processing item: social media
# Processing item: news reels
# Processing item: narrative framing
# Processing item: medical ai
# Processing item: explainable ai
# Processing item: user experience
# Processing item: human-ai collaboration
# Processing item: decision-making
# Processing item: blood vessel labeling
# Processing item: community organizations
# Processing item: qualitative data analysis
# Processing item: intercoder reliability
# Processing item: object detection
# Processing item: annotation efficiency
# Processing item: computer vision
# Processing item: ai bias mitigation
# Processing item: accountability
# Processing item: socio-technical systems
# Processing item: ethical reflection
# Processing item: model card
# Processing item: artificial intelligence design
# Processing item: ai constraints
# Processing item: education
# Processing item: user efficiency
# Processing item: human-robot interaction
# Processing item: human-animal interaction
# Processing item: design guidelines
# Processing item: audio-visual learning
# Processing item: data annotation
# Processing item: human-ai collaboration
# Processing item: machine learning
# Processing item: interpretability tools
# Processing item: cognitive factors
# Processing item: data curation
# Processing item: design practices
# Processing item: generative ai
# Processing item: hci research
# Processing item: ethical issues
# Processing item: future directions
# Processing item: decision support
# Processing item: human-ai interaction
# Processing item: user behavior
# Processing item: anthropomorphism
# Processing item: user perception
# Processing item: personal assistants
# Processing item: radiology
# Processing item: human-ai collaboration
# Processing item: diagnostic performance
# Processing item: ai explainability
# Processing item: trust in ai
# Processing item: medical ai systems
# Processing item: machine learning interpretability
# Processing item: healthcare
# Processing item: risk prediction models
# Processing item: sense of agency
# Processing item: goal pursuit
# Processing item: healthy eating
# Processing item: label set construction
# Processing item: crowdsourcing
# Processing item: machine learning
# Processing item: marginalized groups
# Processing item: hci research
# Processing item: representation
# Processing item: decision support systems
# Processing item: human behavior
# Processing item: simulation
# Processing item: image manipulation
# Processing item: multimodal generation
# Processing item: consistency reasoning
# Processing item: data labeling
# Processing item: ai assistance
# Processing item: labeler accuracy
# Processing item: chatbot design
# Processing item: user experience
# Processing item: prompting challenges
# Processing item: online research
# Processing item: machine assistance
# Processing item: sensemaking theory
# Processing item: dance
# Processing item: co-creativity
# Processing item: embodied interaction
# Processing item: security patch management
# Processing item: automation
# Processing item: healthcare
# Processing item: dating websites
# Processing item: bias reduction
# Processing item: interface design
# Processing item: ai-based design tools
# Processing item: engineering design
# Processing item: co-creation challenges
# Processing item: passive sensing
# Processing item: hybrid work
# Processing item: worker-centric approaches
# Processing item: explainable ai
# Processing item: cognitive style
# Processing item: socio-cultural factors
# Processing item: public opinion
# Processing item: responsible ai development
# Processing item: global perception
# Processing item: self-regulated learning
# Processing item: facial expression recognition
# Processing item: ethical concerns
# Processing item: rhetorical context
# Processing item: communication ethics
# Processing item: ai writing systems
# Processing item: machine learning
# Processing item: programming interactions
# Processing item: learning curve
# Processing item: design education
# Processing item: machine learning toolkit
# Processing item: ideation processes
# Processing item: ai assessment
# Processing item: bug localization
# Processing item: explainable ai
# Processing item: research question development
# Processing item: human-ai co-creation
# Processing item: interdisciplinary research
# Processing item: collaborative reinforcement learning
# Processing item: human-ai collaboration
# Processing item: efficiency improvement
# Processing item: data analysis
# Processing item: generative ai
# Processing item: information foraging
# Processing item: online research
# Processing item: machine assistance
# Processing item: browser extension
# Processing item: mental models
# Processing item: interactive virtual environments
# Processing item: cognitive behavior
# Processing item: video-sharing platforms
# Processing item: research themes
# Processing item: hci methods
# Processing item: creative writing
# Processing item: generative ai
# Processing item: social dynamics
# Processing item: transparency
# Processing item: regulatory framework
# Processing item: accountability
# Processing item: classroom dynamics
# Processing item: co-orchestration technology
# Processing item: student control
# Processing item: nlp documentation
# Processing item: non-expert analysts
# Processing item: design guidelines
# Processing item: intelligent personal assistants
# Processing item: role design
# Processing item: user experience
# Processing item: 3d design
# Processing item: ai inspiration
# Processing item: design workflows
# Processing item: human-agent interaction
# Processing item: groupware development
# Processing item: artificial teammates
# Processing item: implicit bias
# Processing item: cognitive biases
# Processing item: crowdsourcing
# Processing item: workplace wellbeing
# Processing item: remote work
# Processing item: sensing technologies
# Processing item: healthcare
# Processing item: trust
# Processing item: voice assistants
# Processing item: group decision-making
# Processing item: human-ai collaboration
# Processing item: speculative design
# Processing item: generative models
# Processing item: software engineering
# Processing item: application modernization
# Processing item: voice interfaces
# Processing item: speech recognition
# Processing item: smart speakers
# Processing item: privacy labels
# Processing item: developer tools
# Processing item: mobile apps
# Processing item: time management
# Processing item: work performance
# Processing item: protected time
# Processing item: computer science education
# Processing item: social values
# Processing item: machine learning models
# Processing item: conversational search
# Processing item: information interaction
# Processing item: future opportunities
# Processing item: ai design
# Processing item: model transparency
# Processing item: ux ideation
# Processing item: sentiment analysis
# Processing item: human-agent interaction
# Processing item: cloud services
# Processing item: web customization
# Processing item: user experience
# Processing item: natural language processing
# Processing item: media production
# Processing item: speech recognition
# Processing item: subtitling
# Processing item: risk assessment
# Processing item: child welfare
# Processing item: systemic bias
# Processing item: voice assistants
# Processing item: user feedback
# Processing item: personalized experience
# Processing item: pathology
# Processing item: workflow integration
# Processing item: collaborative diagnosis
# Processing item: ux research
# Processing item: machine learning
# Processing item: data-driven insights
# Processing item: instant messaging
# Processing item: user receptivity
# Processing item: self-presentation
# Processing item: algorithmic trade-offs
# Processing item: design methodology
# Processing item: decision making
# Processing item: ai-assisted decision-making
# Processing item: human trust calibration
# Processing item: confidence likelihood
# Processing item: shape displays
# Processing item: text-to-shape
# Processing item: user interaction
# Processing item: explainable ai
# Processing item: convolutional neural networks
# Processing item: model improvement
# Processing item: conversational information retrieval
# Processing item: social communication theories
# Processing item: human-computer interaction
# Processing item: game ai design
# Processing item: co-creativity tools
# Processing item: participatory design
# Processing item: task-oriented chatbots
# Processing item: user guidance
# Processing item: performance metrics
# Processing item: algorithmic decision review
# Processing item: human participation
# Processing item: fairness in ai
# Processing item: humanities
# Processing item: critical reflection
# Processing item: computer vision
# Processing item: medical self-diagnosis
# Processing item: user acceptance
# Processing item: ai-driven apps
# Processing item: decision-making
# Processing item: user perception
# Processing item: ai system design
# Processing item: video-based learning
# Processing item: attention refocusing
# Processing item: behavioral change
# Processing item: text simplification
# Processing item: deaf and hard-of-hearing
# Processing item: reading literacy
# Processing item: multimodal data
# Processing item: learning analytics
# Processing item: nursing simulation
# Processing item: language models
# Processing item: creative writing
# Processing item: interaction design
# Processing item: social work
# Processing item: decision support
# Processing item: child maltreatment
# Processing item: mobile ui design
# Processing item: visual search framework
# Processing item: design inspiration
# Processing item: design creativity
# Processing item: ai inspiration
# Processing item: sketching
# Processing item: explainable ai
# Processing item: augmented reality
# Processing item: design framework
# Processing item: healthcare
# Processing item: trustworthy ai
# Processing item: organisational accountability
# Processing item: ai-assisted decision making
# Processing item: trust calibration
# Processing item: explainability
# Processing item: healthcare
# Processing item: clinical documentation
# Processing item: ai collaboration
# Processing item: documentation generation
# Processing item: data science
# Processing item: machine learning
# Processing item: online learning
# Processing item: scaffolding prompts
# Processing item: knowledge graphs
# Processing item: mental models
# Processing item: cooperative games
# Processing item: ai abilities
# Processing item: human-agent collaboration
# Processing item: design guidelines
# Processing item: task delegation
# Processing item: digital comics
# Processing item: ai automation
# Processing item: creative process
# Processing item: icu
# Processing item: clinical decision support systems
# Processing item: collaboration
# Processing item: visual impairments
# Processing item: emoji entry
# Processing item: speech input
# Processing item: fact-checking
# Processing item: trust in ai
# Processing item: human-ai interaction
# Processing item: conditional delegation
# Processing item: content moderation
# Processing item: model performance
# Processing item: flow
# Processing item: cognitive science
# Processing item: video games
# Processing item: conversational agents
# Processing item: user experience
# Processing item: self-determination theory
# Processing item: self-determination theory
# Processing item: hci games research
# Processing item: theory application
# Processing item: implicature
# Processing item: human-agent collaboration
# Processing item: game performance
# Processing item: stress management
# Processing item: self-reflection
# Processing item: personal informatics
# Processing item: child-welfare
# Processing item: algorithm design
# Processing item: sociotechnical systems
# Processing item: ai literacy
# Processing item: co-creative ai
# Processing item: public spaces
# Processing item: ai literacy
# Processing item: informal learning
# Processing item: family education
# Processing item: misinformation detection
# Processing item: social media
# Processing item: user perception
# Processing item: shared control
# Processing item: design space
# Processing item: collaboration
# Processing item: causality learning
# Processing item: intelligent agents
# Processing item: experience-based framework
# Processing item: ethical governance
# Processing item: software engineering
# Processing item: safety culture
# Processing item: human-robot interaction
# Processing item: social errors
# Processing item: socio-affective competence
# Processing item: ai fitness apps
# Processing item: user experience
# Processing item: design considerations
# Processing item: digital games
# Processing item: accessibility
# Processing item: spinal cord injury rehabilitation
# Processing item: human resource management
# Processing item: stakeholder tensions
# Processing item: ai design solutions
# Processing item: remote sighted assistance
# Processing item: computer vision
# Processing item: visual impairments
# Processing item: social role
# Processing item: generational shift
# Processing item: agent voice
# Processing item: explainable ai
# Processing item: design evaluation
# Processing item: multidisciplinary research

# %%
x = pd.DataFrame({k: str(kw_embedding[k]) for k in kw_embedding}, index=[0]).T
x.to_csv("result/embedding-keywords.csv")

# %%
stmt = set(df['finding_id'].to_list())
stmt_embedding = get_concurrent_embeddings(stmt)
# Out:
# Processing item: DuetDraw enhances user satisfaction by providing detailed instructions during collaborative drawing tasks.
# Processing item: Generative AI enhances music composition by balancing authorial control with unpredictability.
# Processing item: Optometrists' risk-averse tendencies significantly influence their interpretation of AI clinical decision support system outputs.
# Processing item: Trust calibration alone is insufficient for improving AI-assisted decision making outcomes.
# Processing item: User demographics, including age and familiarity with probability, influence human-AI collaborative decision-making.
# Processing item: AI models detect hyperactivity in children with 85.2% accuracy using parent-provided activity labels.
# Processing item: AI explanations are most effective when they reveal reasons to doubt incorrect AI classifications or trust correct ones.
# Processing item: False positives in AI grading harm learning by reducing students' engagement with feedback.
# Processing item: Saliency maps produced by the LRP algorithm help users identify specific image features that CNNs are sensitive to.
# Processing item: Interactive visualization systems enable novice AI designers to understand model threshold trade-offs and fairness.
# Processing item: AdaTest++ enhances human-AI collaboration by leveraging human strengths in schematization and hypothesis testing.
# Processing item: AI applications for automated disease diagnosis are perceived by community health workers to potentially improve healthcare delivery in rural areas by enhancing diagnostic accuracy.
# Processing item: The AI system, GAM Changer, is easy to use and integrates well into existing workflows of data scientists across various domains.
# Processing item: Recruitment chatbots enhance user experience by integrating human-centered design principles.
# Processing item: Generative text-to-image models help overcome design fixation by enabling novel robot concept ideation.
# Processing item: Trust in AI is influenced by the openness level of the human annotator.
# Processing item: AI explainability enhances understanding by focusing on human-centered perspectives rather than algorithm-centered views.
# Processing item: Embodied anthropomorphism in AI personal assistants enhances perceived intelligence and likeability.
# Processing item: AI agents that adjust their autonomy based on the situation enhance team performance in shared workspaces.
# Processing item: AI-generated content acts as both an audience and critic, influencing musicians' creative processes.
# Processing item: Participants perceive AI systems as more capable but less morally trustworthy than humans.
# Processing item: IR-GAN improves consistency between visual and semantic increments in image generation.
# Processing item: The Value Cards toolkit enables students to recognize the importance of considering diverse social values in algorithmic system development.
# Processing item: Optimization using AI preferential choices lacks mechanisms to handle inconsistent human judgments.
# Processing item: The mobile silent speech interface supports on-device fine-tuning and visual keyword spotting, ensuring customizable interactions.
# Processing item: Virtual reality enhances the teleoperation of semi-autonomous robotic boats by integrating live sensor data for monitoring and control.
# Processing item: AI-based credibility indicators have limited impact on news engagement when social influence is present.
# Processing item: Users tend to explore new topics rather than revisit previously explored concepts when using Generative AI.
# Processing item: The ESCAPE system enables users to identify and address AI blindspots by facilitating the recognition of spurious associations.
# Processing item: The AI system recognizes hand gestures as main characters, dynamically adapting story plots based on character changes.
# Processing item: AI co-learning frameworks effectively improve worker skills without requiring pre-trained models.
# Processing item: Agents with higher value similarity to users increase trust levels in AI systems.
# Processing item: Participants frequently incorporate language from AI-generated text into their own explanations.
# Processing item: Participants appreciated the diverting denial style, indicating its effectiveness in managing user expectations.
# Processing item: AI products' inclusivity is influenced by whether they learn from individual or collective data.
# Processing item: PromptCharm enhances image quality by refining and optimizing initial text prompts.
# Processing item: Large Language Models improve reasoning capabilities in AI chatbots, aiding leadership growth.
# Processing item: The AI system's reliance on casenotes introduces biases, affecting the accuracy of NLP-based systems.
# Processing item: AI-framed Questioning significantly enhances human ability to discern logically flawed statements.
# Processing item: Chatbot support helps maintain reduced smartphone use.
# Processing item: Human writers experience joyful and inspirational interactions when engaging with AI-generated content.
# Processing item: Challenges such as usability, AI transparency, and data availability hinder culturally sensitive AI system design.
# Processing item: Creative AI tools reveal underlying assumptions and stereotypes about robots in design processes.
# Processing item: Graph Influence Function (GIF) enhances graph unlearning by efficiently estimating parameter changes with improved efficacy and efficiency.
# Processing item: The proposed taxonomy of social errors in Human-Robot Interaction encourages the development of user-centered systems that enhance interaction experiences.
# Processing item: Systematic use of in-situ video snippets enhances the two-way flow of cognitive information in medical training.
# Processing item: AI assistance improves labeler accuracy and speed by focusing on the most probable labels.
# Processing item: Real-time neuroimaging enables dynamic audience participation by visualizing the performer's mental state.
# Processing item: AnalogiLead users dismissed analogies 4x less often than baseline users.
# Processing item: AI systems can enhance telenurses' decision-making by suggesting questions during patient calls.
# Processing item: AI systems using personalized models can perform stylometry, predicting the player based on move patterns.
# Processing item: Interpretability tools impair understanding by reducing task accuracy by 17% and task time by a factor of 5.
# Processing item: Explainable AI facilitates trust by providing human-level explanations and can be processed affectively.
# Processing item: Text-to-image AI tools reduce design fixation by providing diverse reference images.
# Processing item: The AI-driven PCR-Chain achieves syntax error correction without requiring program analysis.
# Processing item: False negatives in AI grading harm learning primarily for students with lower engagement, highlighting the protective role of active participation.
# Processing item: Trust in AI-integrated systems is more influenced by human actors than by the system's features.
# Processing item: Fashion Recommender Systems show potential in cold-start scenarios with limited data for gift purchases.
# Processing item: Users tend to under-rely on AI systems due to overestimating their own problem-solving abilities, despite understanding system accuracy.
# Processing item: AI input offers new perspectives, expanding artistic expression avenues.
# Processing item: Stylette facilitates user experimentation with CSS by suggesting multiple alternatives for a single styling goal.
# Processing item: The Mindless Attractor intervention helps learners refocus attention by perturbing video voice without requiring conscious awareness.
# Processing item: EvalLM helps developers create more diverse criteria for prompt evaluation.
# Processing item: AnalogiLead resulted in 12x fewer decision changes compared to a baseline interface.
# Processing item: Machine learning enriches UX research by providing insights into users' emotional experiences.
# Processing item: Visual Captions improve communication by providing relevant visuals during video calls.
# Processing item: Principal component analysis identifies two dimensions of AI: human involvement and AI autonomy.
# Processing item: Participants prefer selecting from multiple AI-generated suggestions over using non-diegetic prompts.
# Processing item: A trauma-informed algorithmic tool improves outcomes when properly integrated into the agency's ecosystem.
# Processing item: Contrastive learning enhances lipreading representations, achieving an F1-score of 0.8947 for 25-command classification using only one shot.
# Processing item: Irreducible Infeasible Sets (IIS) are used by AI to generate explanations for unsolvable planning problems, demonstrating efficacy in hybrid domains.
# Processing item: Alternate translations provided by generative AI models enhance software engineers' understanding of code translation tasks.
# Processing item: Public opinion supports the responsible development and use of AI.
# Processing item: DHH adults prefer on-demand lexical simplification systems over automatic simplification.
# Processing item: Partial automation allows players with motor impairments to engage in digital games by delegating control of inaccessible inputs to an AI partner.
# Processing item: Older adults exhibited agency by choosing when to adapt to the Virtual Occupational Therapist's (VOT) actions, demonstrating autonomy in their interaction with the AI.
# Processing item: AI dance partners enhance co-creativity by facilitating dynamic improvisational interactions.
# Processing item: CLEAR platform enhances robotics usability for natural human interaction by utilizing large language models.
# Processing item: Users evaluate AI-based symptom checkers by comparing them with established medical authorities and other health technologies.
# Processing item: AI prediction algorithms enhance self-reflection by identifying stress patterns in users' daily activities.
# Processing item: Incorporating simulated users in product evaluation offers innovative yet challenging potential.
# Processing item: AI in games reveals misconceptions about AI systems by integrating interactions from other domains.
# Processing item: Musical AIs enhance therapeutic effectiveness by integrating into emotion-focused therapy sessions.
# Processing item: People are less accurate at identifying the truthfulness of synthetic face images generated by newer algorithms.
# Processing item: ChatGPT highlights the need for ethical regulations in AI use and deployment.
# Processing item: People expect developers of machines to pay higher legal damages than users for machine-caused harms.
# Processing item: AI authority results in user attitudes of faith, forgiveness, self-blame, and gratitude, leading to potential individual and societal harm.
# Processing item: Time pressure influences the effectiveness of AI assistance, making certain AI assistances more beneficial compared to no-time-pressure scenarios.
# Processing item: Generative audio research papers predominantly highlight positive impacts, with 65% acknowledging them, while less than 10% address negative impacts, indicating a significant gap in ethical considerations.
# Processing item: Users show increased reliance on conversational AI over the course of tasks, indicating automation complacency.
# Processing item: ChatGPT is suitable for comprehending broad subject domains, generating creative solutions, and uncovering new information.
# Processing item: AI development in resource-constrained environments faces tensions between privacy and ubiquity.
# Processing item: LIMEADE enhances user control, trust, and satisfaction in neural recommender systems for scientific papers.
# Processing item: AI simulations increase user empathy and understanding by simulating LGBTQIA+ 'coming out' conversations.
# Processing item: Non-human metaphorical representations of conversational agents enhance intrinsic motivation and trust among workers.
# Processing item: AI systems' warmth perception influences user choice even when competence is lacking.
# Processing item: Organizational pressures affect the use of AI-based decision support tools in child welfare.
# Processing item: AAR/AI participants were nearly six times more likely to find any particular bug compared to non-AAR/AI participants.
# Processing item: ForSense accelerates online research using neural-driven machine reading.
# Processing item: Computer-Assisted Protected Time increases self-reported performance and job resources among workers.
# Processing item: Large language models enhance Wellbeing Assessment Tools by improving natural language content processing.
# Processing item: LLM augmentation improves ease-of-use in AI-CDSS for managing upper gastrointestinal bleeding.
# Processing item: Comparative AI explanations may expose algorithm limitations, affecting user perception.
# Processing item: Participant's clinical role significantly influences perception of clinical AI support systems.
# Processing item: The AI interface Metamorpheus aids in vivid dream recall and meaningful self-reflection.
# Processing item: The AI system enables the segmentation of continuous motion capture data into distinct body actions.
# Processing item: DAPPER achieves up to 396x less computation overhead compared to baseline methods.
# Processing item: The interactive system RELIC helps users verify the reliability of text generated by Large Language Models by identifying semantic-level variations.
# Processing item: Patchview facilitates the alignment of AI model behaviors with user intentions through corrective interactions.
# Processing item: The AI-assisted method allows for the adaptation of bias tests to evolving cultural contexts.
# Processing item: Clinical Documentation Integrity Specialists improve documentation quality through flexible AI integration and human control.
# Processing item: A visual sandbox approach reduces the learning curve of programming machine learning tasks.
# Processing item: Large language models help researchers understand readers' perspectives in QA-style articles.
# Processing item: Users' perceived learning about facial recognition strengths and limitations improved after using the AI-based Civil War Twin application.
# Processing item: Participants exhibit greater agency and logical engagement in tasks, despite a tendency to adhere to initial responses.
# Processing item: AI semantic control dimensions in ReStyle-MusicVAE allow users to express personal style during music creation.
# Processing item: Fairness perceptions are complexly influenced by how AI systems treat individuals in different groups.
# Processing item: ReadingQuizMaker allows instructors to create high-quality questions by integrating NLP models into their natural workflows.
# Processing item: Peanut significantly accelerates the audio-visual data annotation process by reducing manual effort.
# Processing item: Collaborative exploration with AI empowers analysts to tackle complex, novel threats in Security Operations Centres.
# Processing item: The AI-driven HPU virtualization framework improves resource efficiency in Human-Machine Computing systems by effectively managing virtual HPU configurations.
# Processing item: Photo Steward's validation workflow encourages deliberation among users when making photo ID decisions.
# Processing item: Version control systems like SHARP provide new perspectives on the utility of versioning in live coding contexts.
# Processing item: Generative AI models like GPT-2 enable novel forms of artistic collaboration by supporting entangled authorship, which de-individualizes knowledge production.
# Processing item: Designers perceive AI tools as having potential value in their design process, depending on their desired role for the AI.
# Processing item: Generative AI systems serve as both augmenting tools and autonomous collaborators in creative co-production.
# Processing item: VIVID enables efficient selection and revision of pedagogical dialogues by instructors.
# Processing item: AI-driven self-diagnosis apps are likely to be used by more than half of the participants, particularly when integrated into general practitioner care.
# Processing item: AI dermatologist descriptions enhance user perceptions of ability and benevolence.
# Processing item: Current cloud-based sentiment analysis services are not sufficiently accurate for effective human-agent interaction.
# Processing item: AI-generated patient-specific analysis boosts therapist usage intent compared to traditional systems ($p < 0.05$).
# Processing item: Large Language Models (LLMs) can assess robot behavior similarly to human observers in Human Robot Interaction settings.
# Processing item: Creative exploration of tangible AI helps designers gain new perspectives beyond anthropomorphic forms.
# Processing item: Design concepts such as suggestion quality indicators, usage stats, and control mechanisms aid developers in making trust judgments about AI tools.
# Processing item: People demonstrate different gazing behaviors when viewing and rating real faces compared to those generated by older machine learning algorithms.
# Processing item: AI systems benefit from early error detection by employing multiple sensor layers.
# Processing item: Human responses are favored by young people when addressing sensitive topics, such as suicidal thoughts.
# Processing item: ExpressEdit enhances novice video editors' ability to express and implement editing ideas through natural language and sketching.
# Processing item: The interactive system, Luminate, enhances creative potential by enabling structured exploration of design space with large language models.
# Processing item: Players develop mental models of adversarial AI based on focus (top-down vs. bottom-up) and style (systematic vs. reactive).
# Processing item: Participants perceived human partners as more likeable, intelligent, and creative than AI partners.
# Processing item: AI bias-aware search engines enhance user awareness of algorithmic biases by providing interactive prototypes.
# Processing item: The AI system's transition graphs enhance step tracking in procedures like latte-making and wound care.
# Processing item: Design elements such as language, visual cues, and warnings facilitate interactivity and accessibility of AI model documentation.
# Processing item: Learning Engagement mechanisms, Z2O-Mode and D2O-Mode, enhance users' accurate mental models of robot learning progress.
# Processing item: AI mediators are assessed most favorably, while AI tools are assessed least favorably by laypeople.
# Processing item: AudiLens enables speakers to receive diverse feedback by simulating various audience personas using a large-language model.
# Processing item: Social computing courses require diverse skill sets from HCI, CS, Sociology, and Economics.
# Processing item: Human-like physical bodies in AI systems significantly increase moral consideration towards them.
# Processing item: AI-powered code generation tools require improved affordances for effective trust evaluation by developers.
# Processing item: AI systems enhance resource allocation efficiency in call-based maternal and child health programs.
# Processing item: Explicit metaphorical thinking scaffolds participants' use of ambiguity as a resource.
# Processing item: AI personas provide on-demand feedback that inspires text revisions by offering diverse perspectives.
# Processing item: Light and visualisation feedback in autonomous vehicles enhance user experience compared to no-feedback environments.
# Processing item: Exposure to incorrect AI predictions can decrease user accuracy in claim assessment.
# Processing item: Holistic cognitive style correlates with a preference for goal explanations in AI systems.
# Processing item: Crowdsourcing enables the creation and validation of geographically tailored bias tests.
# Processing item: The influence of AI predictions on user judgment decreases when users provide reasoning for their assessments.
# Processing item: Insufficiently designed AI explanations can decrease system acceptance among users.
# Processing item: AI products adhering to HAI guidelines are generally more inclusive of diverse problem-solving styles.
# Processing item: AI-assisted child maltreatment screening relies on workers' contextual knowledge beyond the AI model's data.
# Processing item: Human saliency maps enhance understanding of AI answers more effectively than machine saliency maps.
# Processing item: AI decision support systems enhance therapist assessment accuracy, increasing agreement from 0.66 to 0.71 F1-scores.
# Processing item: AI writing systems address rhetorical context issues, but only in basic ways.
# Processing item: AI-assisted decision-making training enhances novice performance by aligning their disagreement patterns with those of experienced workers.
# Processing item: CDSSs in ICUs must adapt their interfaces to accommodate varying user goals and contextual factors.
# Processing item: Some XAI methods increase user confidence in activity recognition accuracy, while others decrease it.
# Processing item: Stylette reduces the learning curve for web styling by enabling users to perform changes 35% faster than traditional developer tools.
# Processing item: Multimodal prompt input encourages designers to explore and express themselves more effectively.
# Processing item: Behavior Trees (BTs) generated from human video demonstrations enable robots to learn tasks without pre-programming.
# Processing item: Participatory foundation models enable marginalized communities to shape AI applications in specific domains, enhancing justice through distributed governance.
# Processing item: AI systems improve performance in rehabilitation assessments from an average F1-score of 0.8377 to 0.9116 after incorporating therapist feedback.
# Processing item: Assigned creator type, whether human or AI, did not influence the judgment of the content quality.
# Processing item: Risk assessment algorithms overlook systemic risk factors, leading to biased decision-making in child welfare.
# Processing item: Talkative AI cobots enhance team membership and sense of meaning compared to non-talkative cobots.
# Processing item: AccessMeta effectively links accessibility classes to open-source 3D augmentation designs.
# Processing item: Developers use community-shared experiences to evaluate AI tool suggestions, fostering informed trust.
# Processing item: ML-based teaching systems enable cost-effective knowledge transfer from experts to novices in organizations.
# Processing item: Chunking and recombination mechanisms in AnalogiLead led to 64% longer processing times.
# Processing item: CNN engineers using DeepFuse improved model accuracy and reasonability compared to the current state-of-the-art.
# Processing item: RUBICON achieves higher accuracy and yield rates than existing baselines in differentiating conversation quality.
# Processing item: Generative conversational AI enhances user confidence and comfort in LGBTQIA+ advocacy scenarios.
# Processing item: Users can adjust their oral movements to improve the accuracy of AI-driven voice recognition.
# Processing item: The cooperative approach delivers design outcomes comparable to an optimization process without designer input but with greater efficiency and higher designer engagement.
# Processing item: Incorporating AI explanations enhances Time2Stop's effectiveness by 53.8% in accuracy and 11.4% in receptivity.
# Processing item: Participant age and technology affinity affect trust in AI systems.
# Processing item: Non-human metaphors in conversational agents increase worker engagement in crowdsourcing tasks.
# Processing item: Defamiliarization of AI supports creative interpretation of ambiguous metaphors.
# Processing item: AI-augmented workflows increase momentum on creative tasks by utilizing text prompts.
# Processing item: Facial expression recognition in the AI tool Mirror enhances learners' understanding of their learning experiences through self-observation.
# Processing item: AI assistances exhibit varying accuracy-time tradeoffs in time-pressured settings, suggesting the need for adaptable AI assistance strategies.
# Processing item: Proposed enhancements for voice assistants include summarizing, signposting, and visualizing information to improve communication of complex tasks.
# Processing item: The GPT-creating tool uncovers unexpressed needs and expectations of middle-aged users towards conversational AI.
# Processing item: UX practitioners can identify ethical risks and challenges related to ML through interactive experimentation.
# Processing item: High-quality labeling increases perceived training data credibility.
# Processing item: Uncertainty in protocol application leads clinicians to prioritize tasks with higher certainty over adopting the "Wake Up and Breathe" protocol.
# Processing item: Analogies explaining AI system accuracy do not enhance user reliance on the AI system in loan prediction tasks.
# Processing item: Teachable machine learners enhance perceived usefulness for crowdworkers through a learning by teaching approach.
# Processing item: AI simulations improve decision-making predictions by incorporating real-world context and human behavior.
# Processing item: Reversing the order of profile information presentation reduces implicit racial biases.
# Processing item: Tutorials improve human performance in understanding machine learning patterns, both with and without real-time assistance.
# Processing item: ChatGPT alters students' attitudes towards learning and skill development in Information Technology and Computer Science.
# Processing item: AI systems provoke deep reflections by engaging users in evaluative processes.
# Processing item: AI-to-human communication enhances user engagement and collaborative experience in co-creative systems.
# Processing item: Human-machine interactions improve AI models by providing feedback and reframing machine learning tasks.
# Processing item: Both interpretability and outcome feedback have modest effects on task performance with AI.
# Processing item: DeepLens increases user confidence in detecting out-of-distribution issues by 22% through interactive features.
# Processing item: AI startups with ethical policies are more likely to invest in unconscious bias training, hire diverse programmers, and seek expert advice.
# Processing item: GP-TSM enhances reading efficiency by guiding user gaze through visual cues.
# Processing item: Current voice assistants, like Alexa, fail to surface crucial details and answer questions effectively during task guidance.
# Processing item: AI in ReelFramer suggests foundational narrative details, enhancing the coherence and relevance of scripts.
# Processing item: AI interaction guidelines must integrate banking-specific elements like customer experience principles and agent personas.
# Processing item: Users often followed LLM suggestions verbatim, even when incorrect, highlighting a gap in their ability to evaluate LLM assistance.
# Processing item: AI-driven design experiments promote reflexive practices in confronting biases within creative processes.
# Processing item: AI-based symptom checkers reshape medical authority by providing automated decisions and interaction design patterns.
# Processing item: AI-driven documentation tools remind data scientists to document code they would have ignored.
# Processing item: Pathologists adopt new strategies using AI refinement tools to understand and correct ML algorithm errors.
# Processing item: Social transparency improves human-AI trust in IT-security contexts when paired with contextual information.
# Processing item: RetroLens enhances chemists' exploration of design space, allowing broader consideration of potential synthetic routes.
# Processing item: AI interaction modalities affect the perceived role of AI in co-creative processes.
# Processing item: Interactive AI explanations increase perceived transparency and affective trust in online symptom checkers.
# Processing item: AI model reconciliation effectively explains unsolvability in hybrid planning problems by aligning human and AI domain models.
# Processing item: AI system bias negates trust benefits from high-quality labeling.
# Processing item: AI agents with moderate mentor guidance during a critical period of 1 to 2 million training steps demonstrate noticeable improvement.
# Processing item: Example-based AI explanations improve decision-makers' performance and help achieve complementary human-AI performance.
# Processing item: Interactive model cards enhance model documentation by improving understandability and interpretability for non-expert analysts.
# Processing item: Rule-based guidance after failure enhances users' learning outcomes in task-oriented chatbots.
# Processing item: Users perceive AI agents with situation-dependent autonomy as more intelligent.
# Processing item: Human-centered recruitment chatbots improve acceptability among users.
# Processing item: AI systems enhance patient treatment by analyzing patient-generated health data for risk profiling and predicting deterioration.
# Processing item: Higher participant influence on AI-generated texts increases their sense of ownership.
# Processing item: Participants leverage qualitative case narratives, unavailable to the AI, to determine when not to rely on AI predictions.
# Processing item: Explanations from simple models are more useful to humans than those from deep learning models, despite the latter's superior predictive performance.
# Processing item: Google Home's response "Sorry, I'm not sure how to help" limits user engagement by not providing feedback for subsequent questions.
# Processing item: Learning Engagement mechanisms lead to a better teaching experience for users.
# Processing item: AI-driven voice assistants raise significant privacy concerns due to their always-listening capabilities.
# Processing item: Deep learning-based tools increase the diagnostic utility of retrieved medical images by aligning them with pathologists' needs.
# Processing item: The AI tool AutoChemplete predicts chemical structures from images, facilitating accessible representation for blind and low vision students.
# Processing item: Language models enhance story development by providing varied writing suggestions that writers integrate into their narratives.
# Processing item: Human-AI collaboration in public health requires alignment of diverse stakeholder priorities.
# Processing item: Designers of AI platforms in healthcare demonstrate system effectiveness one metric at a time, leading to unintended design consequences.
# Processing item: Contextualized LLM tools improve response accuracy by integrating retrieval-based techniques.
# Processing item: Human-AI trust factors vary depending on the stakeholder involved.
# Processing item: Interactive human-AI collaboration increases job satisfaction by enhancing direct involvement and accountability.
# Processing item: PCR-Chain resolves FQNs and fixes last-mile syntax errors in 50 partial code samples from Stack Overflow with high success rates.
# Processing item: Changes in AI explanations due to model updates affect human perception and usage of AI models.
# Processing item: Narratron enhances creative storytelling by using the Claude 2 model to co-create and co-perform children's stories through shadow puppetry.
# Processing item: The cooperative approach encourages designers to explore more widely in the design space than when working without optimization assistance.
# Processing item: DynamicLabels enables better understanding and exploration of feedback through multi-aspect analysis.
# Processing item: Voice assistants introduced as learners or collaborators increase user willingness to provide feedback.
# Processing item: High model accuracy significantly increases trust and reliance on AI advice.
# Processing item: Refinement tools enhance user trust in image retrieval algorithms without compromising diagnostic accuracy.
# Processing item: AI-enabled co-orchestration technology supports dynamic student pairing during class sessions.
# Processing item: LLM-powered devil's advocates that challenge AI recommendations promote appropriate reliance on AI in group decision making.
# Processing item: Simulated task environments play a critical role in enhancing human-AI teaming activities by providing valuable insights into protocol and procedure development.
# Processing item: The hybrid AI model achieves comparable performance to a Neural Network in assessing stroke rehabilitation exercises.
# Processing item: Machine learning methods automate mundane UX research tasks, enhancing efficiency.
# Processing item: Program synthesizers requiring smaller specifications enhance learnability for novice programmers.
# Processing item: The AI system RetroLens accelerates retrosynthetic route planning by enabling faster deconstruction of complex molecules.
# Processing item: AI chatbots enhance self-reflection by offering consistent, 24/7 support in executive coaching.
# Processing item: Generative AI tools provide creative writers with an alternative support source, complementing peer and mentor assistance.
# Processing item: Conditional delegation improves model performance by allowing humans to create rules for trustworthy AI decision-making regions.
# Processing item: Feedback mechanisms in program synthesizers significantly impact novice programmers' learning experiences.
# Processing item: Combined outcome and process control does not further reduce algorithm aversion compared to each control individually.
# Processing item: The AI tool xPath improves workflow integration in pathology by aligning with pathologists' examination processes.
# Processing item: Students with special educational needs (SEN) use text-to-image AI to transform ideas into digital images, aiding those with fine motor skill challenges.
# Processing item: Most attitude changes occur during the initial query of a search session.
# Processing item: AI-driven computational notebooks increase autonomy for organizations addressing racial and social justice issues by facilitating meaningful data analysis.
# Processing item: Personalized AI models in chess improve prediction accuracy of individual player moves.
# Processing item: The Seamful XAI design process enables users to foresee AI harms and identify underlying reasons.
# Processing item: The AI Playbook encourages product teams to prioritize both ideal and failure scenarios in AI prototyping.
# Processing item: Research on AI voice assistants is predominantly conducted with participants from Western nations, indicating a lack of diversity in perspectives.
# Processing item: Token representation methods influence audience satisfaction in AI-generated music.
# Processing item: The SoundWatch app enhances environmental awareness for deaf and hard of hearing users by recognizing sounds in real-world settings.
# Processing item: AI systems must integrate cultural values to enhance acceptance and usefulness in the Global South.
# Processing item: An AI-based choreography-support system enables iterative digital dance prototyping through an interactive web-based interface.
# Processing item: AI design guidelines improve the development process of data labeling system user interfaces by providing structured guidance.
# Processing item: The AI question bank required additional questions to address explanation needs, resulting in the creation of 11 new questions.
# Processing item: AI-steering tools enhance users' trust and control over musical compositions.
# Processing item: AI-driven conversation prompts guide dating app users through discussions about consent and sexual boundaries.
# Processing item: AI-generated images influence user agency by altering perceived control over outcomes.
# Processing item: For men, talkative AI cobots increase distraction in high task load conditions.
# Processing item: Confirmation bias and search result presentation affect the number and depth of user clicks and perceived familiarity with results.
# Processing item: Social media-based personalization threatens users' identity and increases privacy concerns.
# Processing item: ChatGPT is less suitable for research tasks due to hallucinations, necessitating extensive validation.
# Processing item: LLM-generated responses with citations enhance trust in AI-CDSS among healthcare providers.
# Processing item: AI-driven recommendation quality, privacy, transparency, fairness, and trustworthiness are crucial for user satisfaction and system trust.
# Processing item: Interactive Machine Teaching systems enhance user experience by integrating human interaction deeply into AI model training.
# Processing item: The AI interventions increase transitions between key components of the visualization, such as datapoints, labels, and legend, improving comprehension.
# Processing item: AI attention management systems reduce subjective workload while increasing task-switching frequency and difficulty.
# Processing item: Users lack adequate information to assess machine translation quality, leading to potential misunderstandings.
# Processing item: Using Marco, users complete sensemaking tasks 16% more quickly without compromising accuracy.
# Processing item: Users prefer AI bots to learn through demonstration methods over sorting and categorizing.
# Processing item: AI communication direction affects perceived intelligence and game outcomes.
# Processing item: Human-AI symbiosis improves task performance by combining AI's power with human expertise.
# Processing item: EvalLM enables examination of twice as many outputs compared to manual evaluation.
# Processing item: AI heuristics successfully identify issues related to dialogue content, interaction design, and data privacy.
# Processing item: Computational tools enhance science journalists' user agency by providing contextual and collaborative notions of newsworthiness.
# Processing item: Developers hesitate to grant full autonomy to AI models, contrasting with previous studies' findings.
# Processing item: AI-generated responses are preferred by young people for topics related to relationships, self-expression, and physical health.
# Processing item: AI in HRM faces tensions due to divergent perspectives on fairness among stakeholders.
# Processing item: AutoChemplete supports multiple annotation styles, enhancing user engagement and providing skill-appropriate assistance.
# Processing item: Agreement among non-expert crowd workers further improves precision by 8% and recall by almost 5% beyond pure ML performance.
# Processing item: High spatial awareness enhances team mental model similarity in human-agent teams.
# Processing item: AI suggestions lead to less active writing but maintain a sense of authorship.
# Processing item: AI explanations reduce overreliance when the costs of engaging with them are less than the benefits, as shown in maze task experiments.
# Processing item: AI decision support systems with interactive forward reasoning improve management of output uncertainty.
# Processing item: Honesty-like integrity explanations enhance the buildup and recovery of subjective trust in AI agents.
# Processing item: Functionality issues in algorithmic systems lead to inconsistent and unreliable decisions at the street level.
# Processing item: WaitGPT increases user confidence in LLM-generated analysis by enabling real-time monitoring and control.
# Processing item: Participants perceive Generative AI as efficient tools, not true collaborators, indicating human partners reduce reliance on AI.
# Processing item: SAM enhances conversation response relevance, achieving 0.5% R10@1 improvement on the Douban Conversation Corpus.
# Processing item: AINeedsPlanner workbook improves specification clarity in AI application development, reducing misalignment and rework costs.
# Processing item: Coaches interacting with AI models show increased trust and acceptance in predictions.
# Processing item: Users in 83% of scenarios preferred natural language explanations over simple activity labels.
# Processing item: There were no differences in game outcomes such as win rate and turns to completion between human and AI partners.
# Processing item: AI and human responses together provide richer responses for emergent users.
# Processing item: Batch labeling systems reduce labeling time by applying a single action to multiple records.
# Processing item: IR-GAN uses a reasoning discriminator to ensure logical consistency in generated images.
# Processing item: Time2Stop's adaptive models improve intervention accuracy by over 32.8% and receptivity by over 8.0% compared to baseline methods.
# Processing item: HINT supports practitioners in evaluating human-AI interaction experiences before deployment.
# Processing item: A real-time procedure reduces anchoring bias and increases agreement to ground-truth by 7% in decision-making.
# Processing item: Users express concerns about integrating social features into AI conversational agents, affecting their sense of relatedness.
# Processing item: AI feedback visualizations help students improve collaboration skills and develop AI literacy.
# Processing item: Interactive LLM-powered devil’s advocates are perceived as more collaborative and of higher quality without increasing perceived workload.
# Processing item: HCI with AI-CDSS varies based on clinical expertise, influencing interaction dynamics.
# Processing item: AI explanations enhance perceived understandability and transparency in user-adaptive in-vehicle features.
# Processing item: AI algorithm traceability affects user trust and satisfaction with explanations.
# Processing item: Reinforcement learning-based attention management systems improve human performance by optimizing task-switching policies.
# Processing item: UX designers frequently work with pre-trained models but lack support for UX-led ideation.
# Processing item: UI levels of initiative and control affect perceived authorship in AI-assisted text writing.
# Processing item: AI-based decision systems significantly influence fairness perceptions based on group favoritism rather than unbiased treatment.
# Processing item: User overreliance on AI is a key predictor of behavior, affecting the choice and use of different AI assistance types.
# Processing item: Participants did not improve classifier training or outcome prediction by relying solely on uncertainty measures.
# Processing item: AI explanations enhance trust calibration in machine teaching by providing insights into the model's reasoning.
# Processing item: Beginners struggle with writing and editing prompts using AI language models, even for problems at their skill level.
# Processing item: Conversational AI increases performance for novice software engineers on 'solve'-type questions.
# Processing item: Expectations of legal damages are influenced by perceived moral wrongness and the presence of victims.
# Processing item: The availability of aggregate-level model performance data alters the impact of human-model agreement on reliance.
# Processing item: Pilots prefer AI decision support tools that provide directability and continuous support rather than focusing solely on trust calibration.
# Processing item: Thought Bubbles demonstrate that information availability influences decision-making.
# Processing item: Safety engineering frameworks identify social and ethical risks in text-to-image models by analyzing model interactions and processes.
# Processing item: AI-generated music models enhance creative exploration by allowing musicians to integrate diverse genres.
# Processing item: Simulated human input boosts the AI model's performance in recognizing procedural steps.
# Processing item: AI explanations reduce trust when justifying deceitful actions by the AI.
# Processing item: Choice in personalization approaches enhances trust by increasing user agency and lowering privacy concerns.
# Processing item: Human oversight is crucial in AI-assisted tasks involving complex problem-solving and security considerations.
# Processing item: AI explanations of stress levels assist in recalling past stress patterns, aiding in coping strategies.
# Processing item: AI-assisted systems like Florum facilitate learning by integrating automation after human effort.
# Processing item: Professional writers using Luminate reported increased inspiration and idea generation during creative tasks.
# Processing item: Fictional feature importance plots in computational notebooks highlight specific care needs in diabetes management.
# Processing item: Process control through selecting training algorithms reduces algorithm aversion.
# Processing item: AI assistants weaken social connections within teams but strengthen them across teams.
# Processing item: Learning Engagement mechanisms improve users' positive perceptions of the robot.
# Processing item: Algorithmic systems adversely impact fairness in decision-making processes at child welfare agencies.
# Processing item: Wander creates real-time interactive maps with text, images, and global coordinates based on real-world locations.
# Processing item: AI explanations foster trust when clarifying non-compliance with human commands.
# Processing item: AI systems should integrate with diverse rationalities, including cultural and faith-based practices, to better align with user behaviors in the Global South.
# Processing item: Object saliency maps enable users to visualize and understand the internal states of Deep Reinforcement Learning Networks.
# Processing item: Designing polyadic conversational agents with social boundaries, such as privacy and disclosure, is crucial for ethical interactions.
# Processing item: Users' autonomy is impacted by the flexibility of the AI conversation, personalization of experiences, and control over user data.
# Processing item: Type of medical content displayed significantly affects decision time.
# Processing item: HearHere quantifies users' political status, aiding in the reduction of political polarization.
# Processing item: Novel rule-based interfaces improve constraint quality and user efficiency by allowing non-experts to craft rules without programming.
# Processing item: Automation in security patch management reduces delays in installing security patches.
# Processing item: LLM prompts enable achieving 80% of UX goals but struggle with the remaining 20%, leading to interaction breakdowns.
# Processing item: AI processing delays enabled users to reflect on multiple research questions, increasing the quantity generated and enhancing user control.
# Processing item: PANDALens improves writing quality and travel enjoyment by transforming multimodal information into coherent narratives.
# Processing item: AI-driven Promptiverse increases prompt diversity by 40 times compared to manual methods.
# Processing item: Interactive AI explanations improve perceived usefulness and performance of human+AI teams.
# Processing item: The AI system improves symptom-disease relationship identification through a knowledge-routed graph, optimizing topic transitions in conversations.
# Processing item: AI authority influences human actions by legitimizing AI decisions without requiring evidence of system capabilities.
# Processing item: The AI-embedded smartwatch agent, VOT, required adaptation to user behaviors, highlighting the need for AI to discern between expected collaboration and user-driven autonomy.
# Processing item: The debiased AI recommender provides fairer career recommendations without losing prediction accuracy.
# Processing item: Healthcare providers desire AI to support a co-dependent collaboration, improving clinical practice through human-AI enrichment.
# Processing item: AI-powered reminders enhance asynchronous collaboration by efficiently integrating into knowledge workers' workflows.
# Processing item: Changing input factors does not mitigate algorithm aversion.
# Processing item: ExpressEdit enables more efficient video editing by interpreting and implementing multimodal edit commands.
# ...
# Processing item: Local explanations may not effectively aid AI-assisted decision making, suggesting a need for new explainability approaches.
# Processing item: Computer vision tools require intentional design to actively scaffold and support critical reflection during interaction.
# Processing item: User evaluations show that ID.8 provides a positive experience in terms of enjoyment and exploration.
# Processing item: User-initiated feedback instructions reduce perceived disruptiveness in voice assistant interactions.
# Processing item: AI agents' performance is perceived to have less variation across different types of problems.
# Processing item: Large language models reduce authors' burden by assisting in creating QA-style articles.
# Processing item: Global AI explanations alone are more efficient for identifying false positive and negative recommendations.
# Processing item: AI-assisted debiasing strategies enhance fairness in search and recommender systems by addressing both cognitive and algorithmic biases.
# Processing item: Tutorial interventions effectively help users with overestimated self-assessment to calibrate their self-assessment and facilitate appropriate reliance on AI systems.
# Processing item: AI interaction models enhance human-AI communication by structuring turn-taking and contribution types in co-creative systems.
# Processing item: ForSense enhances online research by integrating multiple stages of the process.
# Processing item: AI contributes to group decision-making but remains secondary due to its limited ability to follow dynamic discussions.
# Processing item: ChatGPT improves code generation and optimization efficiency in software engineering.
# Processing item: The Mix & Match Machine Learning toolkit enhances design students' learning and ideation by providing tangible tokens and a web interface to explore ML capabilities.
# Processing item: Casual conversational style in chatbot surveys decreases satisficing, improving response differentiation.
# Processing item: Presenting AI model uncertainty in a frequency format helps users adjust their reliance and reduces confirmation bias.
# Processing item: People with and without AI backgrounds show unwarranted faith in numerical data for different reasons.
# Processing item: The AI system's ad timing choice impacts user experience more than allowing user choice.
# Processing item: Dynamic audience selection (DAS) controls increase user confidence in content sharing by enhancing expressiveness and customizability.
# Processing item: Participants felt negatively towards content creators when AI was perceived to be involved in the creation process.
# Processing item: Participants used AI accuracy in familiar tasks to dynamically calibrate trust during unfamiliar tasks.
# Processing item: The AI-driven sensing module effectively activates the intervention without frustrating users, even with false-positive attentive state detections.
# Processing item: The LLM-based chatbot app enhances user motivation by proactively recommending actions towards personal goals based on contextual factors.
# Processing item: The PDE technique offers high robustness to hand orientation and depth variations, enhancing accuracy in personal usage applications.
# Processing item: PANDALens reduces user effort in documentation through the use of Large Language Models.
# Processing item: AI interaction guidelines enhance user experience when adhered to during optimal AI performance.
# Processing item: ChatGPT influences career prospects of IT and Computer Science graduates by affecting job automation and displacement.
# Processing item: Increasing awareness of possible performance disparities in machine learning models decreases over-reliance under covariate shift.
# Processing item: The device, using AI, increases overall playfulness and engagement during gameplay.
# Processing item: AI augments human creativity in design collaborations.
# Processing item: AAR/AI participants located significantly more bugs than non-AAR/AI participants, showing greater recall and precision.
# Processing item: User trust in AI systems remains unaffected by task complexity and uncertainty.
# Processing item: Judges and jurors often perceive AI forensic tools uncritically, complicating defense efforts to contest their reliability.
# Processing item: The architecture of generative agents significantly enhances the believability of simulated human behavior through observation, planning, and reflection.
# Processing item: Context-based notifications increase user engagement by prompting timely responses and data logging in weight maintenance apps.
# Processing item: Non-expert users improved understanding of aleatoric and epistemic uncertainty by using larger or more varied training sets.
# Processing item: Generative AI in design challenges internalized biases by highlighting societal norms and personal biases.
# Processing item: Participants are more likely to follow AI suggestions when given longer final decision time.
# Processing item: Intelligent agents using experience information achieve higher accuracy in causality understanding compared to conventional approaches.
# Processing item: Human-AI collaborative editing systems improve the efficiency of producing descriptive alt text for scientific figures.
# Processing item: Games reduce participant fatigue in AI system testing by providing engaging narrative and systems context.
# Processing item: Transparency, interpretability, and human intervention can mitigate perceived burdens of AI in human resource management.
# Processing item: LLooM's AI-generated concepts improve data coverage and quality over traditional topic models.
# Processing item: End-users personalize AI recommender systems through teaching, resisting, and repurposing to achieve desired experiences.
# Processing item: AI-generated explanations can lead to harmful manipulation of trust despite best intentions.
# Processing item: Objective performance remained unchanged between different display refresh rates.
# Processing item: Interactive AI explanations take longer to process.
# Processing item: Participants use AI-generated text-to-image tools to collaboratively develop visual depictions of speculative climate solutions, enhancing engagement in climate action discussions.
# Processing item: Social media data provided by patient participants serves as boundary objects, facilitating stakeholder collaboration in mental health AI research.
# Processing item: Query policy significantly influences an analyst's perception of AI system capabilities.
# Processing item: The framework enhances precision in designing and comparing user studies.
# Processing item: AI agents that sincerely apologize and accept blame for errors are perceived as more intelligent and likeable.
# Processing item: PSAI is deemed appropriate by workers when it respects job consequences and work-life boundaries.
# Processing item: AI fact-checking systems enhance user accuracy when model predictions are correct.
# Processing item: The AI assistant in Marco reduces cognitive costs by enabling users to extract and structure information efficiently.
# Processing item: The AI system models analysts' intent and supports incremental formalism for narrative maps.
# Processing item: First-person expressions of uncertainty in AI responses decrease user confidence and agreement with the AI, while increasing user accuracy.
# Processing item: Groups exhibit higher confidence in overturning incorrect AI recommendations.
# Processing item: Participants in interdependent teams are more willing to disclose personality traits such as Emotionality and Extraversion unconditionally.
# Processing item: XAI explanations are used by end-users for tasks such as calibrating trust, improving skills, and giving feedback.
# Processing item: Interactive elements in interpretability tools do not enhance deliberative thinking or engagement.
# Processing item: Generative AI accelerates project cycles in HCI research by enhancing reproducibility and inclusivity.
# Processing item: AI-driven classroom solutions reveal design implications for personalized smart classrooms.
# Processing item: Local and global AI explanations together enhance user understanding of how to improve recommendations.
# Processing item: AI recommendations and explanations improve decision-making but do not facilitate learning.
# Processing item: AI's accuracy is a significant concern in HRM, impacting trust and usability.
# Processing item: AI-assisted batch labeling interfaces increase labeling accuracy compared to single-item interfaces.
# Processing item: Generative agents autonomously coordinate social events, such as a Valentine's Day party, by spreading invitations and arranging attendance.
# Processing item: ML ethics disclosures in mental health prediction are increasing but will take eight years to reach 75% coverage.
# Processing item: Contextual insensitivity in automated systems can lead to messages being perceived as rude or invasive, such as embarrassing users in public or expressing false personalized care.
# Processing item: Participants adapted their behaviors to complement the behaviors of different types of AI teammates.
# Processing item: The web-based tool effectively surfaces implicit user biases on custom themes.
# Processing item: Clinicians engage in a negotiation process with AI recommendations, selectively following, rejecting, or delaying them.
# Processing item: AI visual markers in colonoscopy enhance polyp detection by providing clear visual cues for clinicians.
# Processing item: Despite low ratings in predictability and controllability, users enjoy interacting with the AI during creative tasks.
# Processing item: Workers assign social perception and moral responsibility to AI counterparts in industrial settings.
# Processing item: Requiring provisional decisions before AI assistance reduces agreement with AI recommendations, regardless of their accuracy.
# Processing item: AI-enabled tools influence legal professionals to adapt their interaction behaviors over time.
# Processing item: AI-driven data storytelling prototypes highlight concerns about accountability and automated insights discovery in educational settings.
# Processing item: Seamful XAI improves user agency by leveraging seamful information to enhance explainability.
# Processing item: Stakeholder dynamics within companies are crucial for effective AI interaction design.
# Processing item: AI platform enables human-AI and AI-AI interactions in Hex game competitions.
# Processing item: The AI system's explanations did not meet user needs, revealing gaps in the existing XAI Question Bank.
# Processing item: Generative AI workflows increase perceived utility post-familiarization phase.
# Processing item: Creating AI clones threatens cohesive self-perception and unique individuality.
# Processing item: Different levels of anthropomorphism influence the perceived pragmatic qualities of AI personal assistants.
# Processing item: AI systems foster learning and reflection by allowing experimentation and supporting sensemaking.
# Processing item: AI's perceived competence and embodiment congruence to the environment enhance acceptance.
# Processing item: Power users trust AI systems more when framed as help-seekers.
# Processing item: The AI design of Civil War Twin successfully met users' ethical standards, enhancing transparency and inclusivity.
# Processing item: Low-performing individuals' reliance on ML models remains unchanged despite the presence or type of AI tutorial.
# Processing item: DeepLens enables users to identify nearly twice as many out-of-distribution issues in text corpora accurately.
# Processing item: Metrics and label suggestions in DynamicLabels aid in spotting conflicts and edge cases.
# Processing item: Thought Bubbles reveal how disruption location affects mental model development.
# Processing item: Text-to-image AI interaction enhances students' ability to convey ideas in writing and develop conceptualization skills.
# Processing item: PromptCharm improves user satisfaction by aligning generated images more closely with user expectations through model attention adjustments.
# Processing item: The setting-specific "tutor" model of NewtBot provides the highest user experience ratings among secondary school students.
# Processing item: Experienced UX designers view GenAI as an assistive tool, enhancing originality and creativity while maintaining human agency.
# Processing item: AI design guidelines assist developers in creating user interfaces for data labeling systems that align with Nielsen's heuristics.
# Processing item: Computational notebooks enable multidisciplinary learning by providing interactive data visualizations.
# Processing item: AI-empowered co-creative tools predominantly support the generation and execution of ideas in creative processes.
# Processing item: All participants preferred Voicemoji over the Apple iOS keyboard for emoji entry.
# Processing item: AI counterfactual generation isolates important model components for detailed analysis.
# Processing item: Making fair AI explainable is crucial for increasing its adoption among users.
# Processing item: The AI conversational agent enhances medical dialogue by integrating a knowledge graph and fine-tuned GPT-3 for natural and context-aware responses.
# Processing item: AI automation in FlatMagic identifies and addresses flatting as a bottleneck in the comic creation process.
# Processing item: LLM-powered conversational search increases user engagement in biased information querying.
# Processing item: Effective developer prompts enhance AI-driven problem resolution.
# Processing item: Generative AI tools help participants build consensus by facilitating discussions on prompting strategies.
# Processing item: Logic units-based explanations do not improve users' calibration of competence or facilitate appropriate reliance on AI systems.
# Processing item: People expect AI agents' performance to be significantly better on average than human performance.
# Processing item: GP-TSM enables coherent skimming and revisiting of skipped details during reading.
# Processing item: AI-DEC supports workers in designing explanations that meet performance and autonomy needs.
# Processing item: AI-generated text reduces users' sense of authorship and ownership, known as the AI Ghostwriter Effect.
# Processing item: Communicating ML uncertainty information encourages analytical thinking and reduces over-reliance on decision support systems by lay decision-makers.
# Processing item: The number of HCI papers focusing on LGBTQ+ people has grown linearly since 2014, while mentions have increased exponentially.
# Processing item: Participants who frequently win the cooperative word guessing game have more accurate estimates of the AI agent's abilities.
# Processing item: AI professionals face limitations in bias mitigation due to technical understanding and organizational factors.
# Processing item: AI systems outperforming humans lead to feelings of inferiority and reduced agency.
# Processing item: AI-generated tools accurately transcribe emotional nuances in artistic images by analyzing eye-tracking data and color patterns.
# Processing item: Generative AI platforms with shortcut features reduce user exploration of novel concepts.
# Processing item: AI development practices often separate Human-Centered AI work from technical development, hindering integration.
# Processing item: Generative AI enhances data analysis by improving information foraging and sensemaking processes.
# Processing item: Current HCI education inadequately prepares designers for VUI design challenges.
# Processing item: Grad-CAM attribution maps may not be as beneficial for end users in decision-making contexts.
# Processing item: Vision-language models effectively answer visual questions in radiology, such as identifying nodules in chest X-rays.
# Processing item: Human-agent teams outperform human-only teams in emergency response tasks.

# %%
x = pd.DataFrame({k: str(stmt_embedding[k]) for k in stmt_embedding}, index=[0]).T
x.to_csv("result/embedding-stmt.csv")
